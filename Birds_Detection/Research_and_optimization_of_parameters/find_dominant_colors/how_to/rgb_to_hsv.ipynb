# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
import colorsys

# %%
image_path='/home/marcpozzo/Desktop/c3po/Images_aquises/Rec_images_bigger/DSCF0029_ground_1.JPG'

# %%
image_rgb=cv2.imread(image_path)
hsvA=cv2.cvtColor(image_rgb, cv2.COLOR_BGR2HSV)
plt.imshow(image_rgb);

# %%
print(np.median(image_rgb[:,:,0]))
print(np.median(image_rgb[:,:,1]))
print(np.median(image_rgb[:,:,2]))

print("/////")
print(np.median(hsvA[:,:,0]))
print(np.median(hsvA[:,:,1]))
print(np.median(hsvA[:,:,2]))
# Out:
# 215.0
# 188.0
# 159.0
# /////
# 16.0
# 66.0
# 215.0

# %%
print("/////")
print(np.median(hsvA[:,:,0]))
print(np.median(hsvA[:,:,1]))
print(np.median(hsvA[:,:,2]))
# Out:
# /////
# 105.0
# 66.0
# 215.0

# %%
import colorsys
print(colorsys.rgb_to_hsv(0.2, 0.4, 0.4))

print(colorsys.hsv_to_rgb(0.5, 0.5, 0.4))
https://docs.python.org/2/library/colorsys.html
# Out:
#   File "<ipython-input-23-f2d5999cd6e1>", line 5
#     https://docs.python.org/2/library/colorsys.html
#            ^
# SyntaxError: invalid syntax

# %%
image_rgb[0,0]
# Out:
# array([223, 191, 162], dtype=uint8)

# %%
colorsys.rgb_to_hsv(223, 191, 162)
# Out:
# (0.07923497267759562, 0.273542600896861, 223)

# %%
    #https://www.lifewire.com/what-is-hsv-in-design-1078068

    Red falls between 0 and 60 degrees.
    Yellow falls between 61 and 120 degrees.
    Green falls between 121 and 180 degrees.
    Cyan falls between 181 and 240 degrees.
    Blue falls between 241 and 300 degrees.
    Magenta falls between 301 and 360 degrees.
# Out:
#   File "<ipython-input-26-c3d41d7c1b43>", line 3
#     Red falls between 0 and 60 degrees.
#             ^
# SyntaxError: invalid syntax

# %%
print(colorsys.rgb_to_hsv(124, 112, 140))
# Out:
# (0.7380952380952381, 0.2, 140)

# %%
colorsys.rgb_to_hsv(210, 211, 0)
# Out:
# (0.16745655608214852, 1.0, 211)

# %%
colorsys.rgb_to_hsv(211, 210, 0)
# Out:
# (0.16587677725118483, 1.0, 211)

# %%
print(colorsys.rgb_to_hsv( 225,0, 0))
print(colorsys.rgb_to_hsv(0, 225, 0))
print(colorsys.rgb_to_hsv(0, 0,225))
# Out:
# (0.0, 1.0, 225)
# (0.3333333333333333, 1.0, 225)
# (0.6666666666666666, 1.0, 225)

# %%
#range_color equal first column *360

print(colorsys.rgb_to_hsv(124, 112, 140)[0]*360)
# Out:
# 265.7142857142857

# %%
image_rgb_reshape=(image_rgb.reshape(-1,3))
print(colorsys.rgb_to_hsv(image_rgb_reshape[0])[0]*360)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-17c33e993778> in <module>
#       1 image_rgb_reshape=(image_rgb.reshape(-1,3))
# ----> 2 print(colorsys.rgb_to_hsv(image_rgb_reshape[0])[0]*360)
#
# TypeError: rgb_to_hsv() missing 2 required positional arguments: 'g' and 'b'

# %%
colorsys.rgb_to_hsv(0, 255, 0)
# Out:
# (0.3333333333333333, 1.0, 255)

# %%
colorsys.rgb_to_hsv(image_rgb_reshape[0][0],image_rgb_reshape[0][1],image_rgb_reshape[0][2])
# Out:
# (0.07923497756322224, 0.2735426, 223)

# %%
color_range_liste=[]

for i in range(len(image_rgb_reshape)):
    pixel=image_rgb_reshape[i]
    red=pixel[0]
    green=pixel[1]
    blue=pixel[2]
    hsv=colorsys.rgb_to_hsv(red,green,blue)
    color_range=hsv[0]*360
    color_range_liste.append(color_range)

plt.hist(color_range_liste)
# Out:
# (array([  51.,   40.,   51.,  372., 1421., 3017., 2702., 1074.,  419.,
#           69.]),
#  array([16.07142806, 18.64285648, 21.2142849 , 23.78571332, 26.35714173,
#         28.92857015, 31.49999857, 34.07142699, 36.64285541, 39.21428382,
#         41.78571224]),
#  <a list of 10 Patch objects>)

# %%
import os
path_imagettes="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/pictures/imagettes_colors/"
liste_images=os.listdir(path_imagettes)
image_rgb=cv2.imread(path_imagettes+liste_images[9])
image_rgb_reshape=(image_rgb.reshape(-1,3))




color_range_liste=[]

for i in range(len(image_rgb_reshape)):
    pixel=image_rgb_reshape[i]
    red=pixel[0]
    green=pixel[1]
    blue=pixel[2]
    hsv=colorsys.rgb_to_hsv(red,green,blue)
    color_range=hsv[0]*360
    color_range_liste.append(color_range)

plt.hist(color_range_liste)
# Out:
# (array([  1.,  10.,  36.,  47., 116., 121., 138., 125.,  80., 110.]),
#  array([181.875     , 184.2589286 , 186.64285719, 189.02678579,
#         191.41071439, 193.79464298, 196.17857158, 198.56250018,
#         200.94642878, 203.33035737, 205.71428597]),
#  <a list of 10 Patch objects>)

# %%
 name_test
Out[111]: 'image_2019-04-30_18-26-25.jpg'

# %%
image_rgb_reshape=(image_rgb.reshape(-1,3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-7578acdbed99> in <module>
#       2 liste_images=os.listdir("/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/pictures/imagettes_colors/")
#       3 image_rgb=cv2.imread(liste_images[0])
# ----> 4 image_rgb_reshape=(image_rgb.reshape(-1,3))
#
# AttributeError: 'NoneType' object has no attribute 'reshape'

# %%
image_rgb=cv2.imread("/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_0/image_2019-04-30_18-26-25.jpg")
image_rgb_reshape=(image_rgb.reshape(-1,3))




color_range_liste=[]

for i in range(len(image_rgb_reshape)):
    pixel=image_rgb_reshape[i]
    red=pixel[0]
    green=pixel[1]
    blue=pixel[2]
    hsv=colorsys.rgb_to_hsv(red,green,blue)
    color_range=hsv[0]*360
    color_range_liste.append(color_range)

plt.hist(color_range_liste)
# Out:
# (array([2.46052e+05, 3.50240e+04, 7.37000e+02, 5.40000e+01, 1.88100e+03,
#         5.82253e+05, 1.92980e+04, 2.55600e+03, 4.87800e+03, 2.88670e+04]),
#  array([  0.        ,  35.66666651,  71.33333302, 106.99999952,
#         142.66666603, 178.33333254, 213.99999905, 249.66666555,
#         285.33333206, 320.99999857, 356.66666508]),
#  <a list of 10 Patch objects>)

# %%
path_imagettes="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/pictures/imagettes_colors/"
liste_images=os.listdir(path_imagettes)



plt.figure(figsize=(20,20))

for image_num in range(len(liste_images)):
    color_range_liste=[]
    image_rgb=cv2.imread(path_imagettes+liste_images[image_num])
    image_rgb_reshape=(image_rgb.reshape(-1,3))

    for i in range(len(image_rgb_reshape)):
        pixel=image_rgb_reshape[i]
        red=pixel[0]
        green=pixel[1]
        blue=pixel[2]
        hsv=colorsys.rgb_to_hsv(red,green,blue)
        color_range=hsv[0]*360
        color_range_liste.append(color_range)


    plt.subplot(4,4,image_num+1)
    plt.hist(color_range_liste)

# %%
len(liste_images)
# Out:
# 16

# %%
liste_images
# Out:
# ['image_2019-04-30_18-26-25_113_95_5.jpg',
#  'image_2019-04-30_18-26-25_14_56_5.jpg',
#  'image_2019-04-30_18-26-25_152_0_5.jpg',
#  'image_2019-04-30_18-26-25_157_0_5.jpg',
#  'image_2019-04-30_18-26-25_173_0_5.jpg',
#  'image_2019-04-30_18-26-25_193_54_0.jpg',
#  'image_2019-04-30_18-26-25_198_94_5.jpg',
#  'image_2019-04-30_18-26-25_228_81_5.jpg',
#  'image_2019-04-30_18-26-25_267_99_5.jpg',
#  'image_2019-04-30_18-26-25_357_0_5.jpg',
#  'image_2019-04-30_18-26-25_359_77_5.jpg',
#  'image_2019-04-30_18-26-25_447_0_5.jpg',
#  'image_2019-04-30_18-26-25_519_88_5.jpg',
#  'image_2019-04-30_18-26-25_85_83_5.jpg',
#  'image_2019-04-30_18-26-25_91_92_5.jpg',
#  'image_2019-04-30_18-26-25_9_98_5.jpg']

# %%
path_imagettes="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/pictures/imagettes_colors/"
liste_images=os.listdir(path_imagettes)



plt.figure(figsize=(20,20))

for image_num in range(len(liste_images)):
    color_range_liste=[]
    
    image_rgb=cv2.imread(path_imagettes+liste_images[image_num])
    image_rgb_reshape=(image_rgb.reshape(-1,3))

    for i in range(len(image_rgb_reshape)):
        pixel=image_rgb_reshape[i]
        red=pixel[0]
        green=pixel[1]
        blue=pixel[2]
        hsv=colorsys.rgb_to_hsv(red,green,blue)
        color_range=hsv[0]*360
        color_range_liste.append(color_range)
        
    print(liste_images[image_num],np.mean(color_range))

    plt.subplot(4,4,image_num+1)
    plt.title(liste_images[image_num])
    plt.hist(color_range_liste)
# Out:
# arbre.jpg 195.51724076271057
# arbre2.jpg 202.72727251052856
# arbre3.jpg 184.8979590833187
# incertain1.jpg 212.9032266139984
# incertain2.jpg 196.4705890417099
# incertain3.jpg 204.76190507411957
# oiseau.jpg 206.05263233184814
# oiseau2.jpg 209.1176462173462
# oiseau3.jpg 207.42857158184052
# oiseau4.jpg 209.5652174949646
# pierre1.jpg 206.75675690174103
# terre1.jpg 204.79999959468842
# terre2.jpg 207.40740716457367
# terre3.jpg 213.65853667259216
# terre4.jpg 210.0
# terre5.jpg 213.07692289352417

# %%
image_rgb=cv2.imread("/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_0/image_2019-04-30_18-26-25.jpg")
image_rgb_reshape=(image_rgb.reshape(-1,3))




color_range_liste=[]

for i in range(len(image_rgb_reshape)):
    pixel=image_rgb_reshape[i]
    red=pixel[0]
    green=pixel[1]
    blue=pixel[2]
    hsv=colorsys.rgb_to_hsv(red,green,blue)
    color_range=hsv[0]*360
    color_range_liste.append(color_range)
plt.figure(figsize=(12,12))
plt.hist(color_range_liste,bins=40)
# Out:
# (array([6.33080e+04, 3.47830e+04, 7.60930e+04, 7.18680e+04, 2.18030e+04,
#         7.28100e+03, 5.85800e+03, 8.20000e+01, 1.81000e+02, 0.00000e+00,
#         5.53000e+02, 3.00000e+00, 6.00000e+00, 0.00000e+00, 3.00000e+00,
#         4.50000e+01, 3.90000e+01, 2.40000e+01, 1.69000e+02, 1.64900e+03,
#         4.16050e+04, 7.90420e+04, 5.27550e+04, 4.08851e+05, 1.68060e+04,
#         1.32100e+03, 9.54000e+02, 2.17000e+02, 4.61000e+02, 4.86000e+02,
#         1.30700e+03, 3.02000e+02, 1.01500e+03, 1.68300e+03, 4.87000e+02,
#         1.69300e+03, 2.91000e+02, 1.29200e+03, 1.28900e+03, 2.59950e+04]),
#  array([  0.        ,   8.91666663,  17.83333325,  26.74999988,
#          35.66666651,  44.58333313,  53.49999976,  62.41666639,
#          71.33333302,  80.24999964,  89.16666627,  98.0833329 ,
#         106.99999952, 115.91666615, 124.83333278, 133.7499994 ,
#         142.66666603, 151.58333266, 160.49999928, 169.41666591,
#         178.33333254, 187.24999917, 196.16666579, 205.08333242,
# ...
