# %%
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import numpy as np
import numpy
from PIL import Image, ImageDraw
from numpy import savetxt
from numpy import load
from numpy import save

# %%
## coordonnee reajustées

# %%
def op_x(coord):
    x=coord[0]

    y=720-coord[1]

    n_coord=(x,y)
    
    return n_coord

random_image_path="/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_2/image_2019-04-10_10-54-59.jpg"
random_image=cv2.imread(random_image_path)

print(random_image.shape)





liste_coord=[[937,719],[798,707],[686,696],[316,671],[7,630],[3,284],[4,226],[0,1],[1278,4],[1280,202],[1281,716],[937,719]]

liste_coord=[[1278,4],[1280,202],[1281,716],[937,719],[798,707],[686,696],[316,671],[7,630],[3,284],[4,226],[0,1]]

liste_coord=[[0,0],[1280,0],[1280,720],[937,720],[798,707],[316,671],[0,630]]
liste_coord=[[0,0],[1280,0],[1280,720],[1100,720],[798,687],[316,660],[0,630]]



coord_1=[liste_coord[0][0],liste_coord[0][1]]
coord_2=[liste_coord[1][0],liste_coord[1][1]]
coord_3=[liste_coord[2][0],liste_coord[2][1]]
coord_4=[liste_coord[3][0],liste_coord[3][1]]
coord_5=[liste_coord[4][0],liste_coord[4][1]]
coord_6=[liste_coord[5][0],liste_coord[5][1]]
coord_7=[liste_coord[6][0],liste_coord[6][1]]
#coord_8=[liste_coord[7][0],liste_coord[7][1]]



x1= op_x(coord_1)
x2=op_x(coord_2)
x3=op_x(coord_3)
x4=op_x(coord_4)
x5=op_x(coord_5)
x6=op_x(coord_6)
x7=op_x(coord_7)
#x8=op_x(coord_8)


polygon=[x1,x2,x3,x4,x5,x6,x7]

random_image=cv2.imread(random_image_path)
n_random_image=cv2.imread(random_image_path)
height = 720
width = 1280
img_1 = Image.new('L', (width, height), 0)
ImageDraw.Draw(img_1).polygon(polygon, outline=1, fill=1)
mask1D = numpy.array(img_1)




mask3D = np.zeros((720,1280,3))
mask3D[:,:,0]=mask1D
mask3D[:,:,1]=mask1D
mask3D[:,:,2]=mask1D

out_arr_1 = np.multiply(mask3D, random_image) 

#Image initiale
plt.figure(figsize=(25,25))
plt.subplot(1,4,1)
plt.imshow(random_image)

#Masque seul
plt.subplot(1,4,2)
plt.imshow(mask3D)

#Image masquée
plt.subplot(1,4,3)
out_arr= np.multiply(mask3D, random_image) 
out_arr=out_arr.astype(int)
n_random_image=n_random_image.astype(int)
plt.imshow(out_arr )
# Out:
# (720, 1280, 3)

# %%
save('mask_2.npy', mask3D)

# %%
mask_download=load('mask_2.npy')
out_arr_1 = np.multiply(mask_download, random_image) 

#Image initiale
plt.figure(figsize=(25,25))
plt.subplot(1,4,1)
plt.imshow(random_image)

#Masque seul
plt.subplot(1,4,2)
plt.imshow(mask3D)

#Image masquée
plt.subplot(1,4,3)
out_arr= np.multiply(mask3D, random_image) 
out_arr=out_arr.astype(int)
n_random_image=n_random_image.astype(int)
plt.imshow(out_arr )

# %%
import os
os.getcwd()
# Out:
# '/mnt/VegaSlowDataDisk/c3po_interface_mark/find_dominant_colors/how_to/masque'
