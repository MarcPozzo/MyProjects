# %%
"Refaire avec le grand écran"
import numpy as np # Pour la manipulation de tableaux
from keras.applications import  resnet50
from sklearn import metrics 
import os

import pandas as pd # Pour manipuler des DataFrames pandas

import matplotlib.pyplot as plt # Pour l'affichage d'images
from matplotlib import cm # Pour importer de nouvelles cartes de couleur
# %matplotlib inline

from keras.models import Sequential # Pour construire un réseau de neurones
from keras.layers import Dense, Conv2D # Pour instancier une couche dense
from keras.utils import np_utils

from keras.models import Sequential
from keras.layers import Dense, Activation,GlobalAveragePooling2D, MaxPooling2D
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.models import Model
import cv2
import keras
from numpy.random import seed
import tensorflow

from keras.preprocessing.image import ImageDataGenerator
import itertools # Pour créer des iterateurs

from sklearn import linear_model, preprocessing 



# %matplotlib inline
import numpy as np

import matplotlib.pyplot as plt
import time, cv2
import seaborn as sns

import pandas as pd
from sklearn.model_selection import train_test_split

from keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.models import Model, Sequential
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras import backend as K
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.applications.vgg16 import preprocess_input
# Out:
# Using TensorFlow backend.

# %%
#Paramètres
base_img_paths="/home/marcpozzo/Desktop/c3po/Images_aquises/"
generateur_path='/mnt/VegaSlowDataDisk/c3po/Images_aquises/generateur_bigger.csv'
#generateur_path='/mnt/VegaSlowDataDisk/c3po/Chaine_de_traitement/Train_imagettes_annotées/type_oiseau/Materiel/generateur.csv'
test_size=0.1
epochs=200
batch_size = 600
zoom_range = 1.25
horizontal_flip = True
Minimum_Number_Class=100
dropout_rate=0.1
#steps_per_epoch=len(data_train)//batch_size
steps_per_epoch=1
#validation_steps=len(data_test)//batch_size
validation_steps=1

# %%
#df=pd.read_csv("/home/marcpozzo/Desktop/c3po/Images_aquises/generateur.csv")
df=pd.read_csv(generateur_path)
df.drop('labels',inplace=True,axis=1)
df.shape
df[df["img_paths"]=='Rec_images_bigger/EK000414_3_pigeon_178.JPG']
# Out:
# Empty DataFrame
# Columns: [class, img_paths]
# Index: []

# %%
df["class"].unique()
for c in df:
    print(''+c+':',len(df[c].unique()))
df["class"].unique()
# Out:
# class: 13
# img_paths: 6220
# array(['oiseau', 'autre', 'corneille', 'pigeon', 'pie', 'chat', 'abeille',
#        'chevreuil', 'lapin', 'faisan', 'w', 'sanglier', 'cheval'],
#       dtype=object)

# %%
All_Unique=df["class"].unique()
Utilisable=[]
for i in df["class"].unique():
    if df["class"][df["class"]==i].count()>Minimum_Number_Class:
        Utilisable.append(i)
Utilisable
Non_Utilisable=set(All_Unique)-set(Utilisable)
Non_Utilisable
for i in Non_Utilisable:
    df=df[df["class"]!=i]
df=df[df["class"]!="oiseau"]  
df["class"].unique()
# Out:
# array(['autre', 'corneille', 'pigeon', 'chevreuil', 'lapin', 'faisan'],
#       dtype=object)

# %%
for i in range(len(df["class"])):
    image_name=df["img_paths"].iloc[i]
    df["img_paths"].iloc[i]=os.path.join(base_img_paths,image_name)
    
df.shape
df[df["img_paths"]=='/home/marcpozzo/Desktop/c3po/Images_aquises/Rec_images_bigger/EK000414_3_pigeon_178.JPG']
# Out:
# Empty DataFrame
# Columns: [class, img_paths]
# Index: []

# %%
df["class"].unique()
# Out:
# array(['autre', 'corneille', 'pigeon', 'chevreuil', 'lapin', 'faisan'],
#       dtype=object)

# %%
seed(1)
tensorflow.random.set_seed(2)

data_train,data_test= train_test_split(df,stratify=df["class"], test_size=test_size,random_state=42)
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        rotation_range = 10,
        zoom_range = zoom_range,
        horizontal_flip = horizontal_flip
        )

test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)




train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)


test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)
print(5369+597)
# Out:
# Found 5369 validated image filenames belonging to 6 classes.
# Found 597 validated image filenames belonging to 6 classes.
# 5966

# %%
lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = dropout_rate)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 6,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation

# %%
gen=test_generator[0]

x_train=gen[0]
y_train=gen[1]

lenet.fit(x_train,y_train)
# Out:
# Epoch 1/1
# 597/597 [==============================] - 0s 265us/step - loss: 0.9485 - accuracy: 0.7002

# %%
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)
datagen.fit(x_train)

# fits the model on batches with real-time data augmentation:
#lenet.fit_generator(datagen.flow(x_train, y_train, batch_size=32),
#                    steps_per_epoch=len(x_train) / 32, epochs=epochs)

# here's a more "manual" example
for e in range(epochs):
    print('Epoch', e)
    batches = 0
    for x_batch, y_batch in datagen.flow(x_train, y_train, batch_size=32):
        lenet.fit(x_batch, y_batch)
        batches += 1
        if batches >= len(x_train) / 32:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break
# Out:
# Epoch 1/200
# 19/18 [==============================] - 0s 19ms/step - loss: 1.7007 - accuracy: 0.6097
# Epoch 2/200
# 19/18 [==============================] - 0s 17ms/step - loss: 1.6009 - accuracy: 0.5930
# Epoch 3/200
# 19/18 [==============================] - 0s 18ms/step - loss: 1.4053 - accuracy: 0.5829
# Epoch 4/200
# 19/18 [==============================] - 0s 18ms/step - loss: 1.2348 - accuracy: 0.5829
# Epoch 5/200
# 19/18 [==============================] - 0s 19ms/step - loss: 1.1464 - accuracy: 0.6181
# Epoch 6/200
# 19/18 [==============================] - 0s 18ms/step - loss: 1.0847 - accuracy: 0.6399
# Epoch 7/200
# 19/18 [==============================] - 0s 19ms/step - loss: 1.0512 - accuracy: 0.6549
# Epoch 8/200
# 19/18 [==============================] - 0s 19ms/step - loss: 1.0152 - accuracy: 0.6549
# Epoch 9/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.9814 - accuracy: 0.6834
# Epoch 10/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.9801 - accuracy: 0.6600
# Epoch 11/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.9171 - accuracy: 0.6901
# Epoch 12/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.9201 - accuracy: 0.6851
# Epoch 13/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.8978 - accuracy: 0.6901
# Epoch 14/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.9244 - accuracy: 0.6700
# Epoch 15/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.8976 - accuracy: 0.6817
# Epoch 16/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.8525 - accuracy: 0.7035
# Epoch 17/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.8461 - accuracy: 0.6951
# Epoch 18/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.8327 - accuracy: 0.7102
# Epoch 19/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.8534 - accuracy: 0.6951
# Epoch 20/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.8204 - accuracy: 0.7035
# Epoch 21/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.8032 - accuracy: 0.7102
# Epoch 22/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.8116 - accuracy: 0.7186
# Epoch 23/200
# 19/18 [==============================] - 0s 16ms/step - loss: 0.8318 - accuracy: 0.6985
# Epoch 24/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.7939 - accuracy: 0.7152
# Epoch 25/200
# 19/18 [==============================] - 0s 21ms/step - loss: 0.7254 - accuracy: 0.7521
# Epoch 26/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.7457 - accuracy: 0.7404
# Epoch 27/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.7587 - accuracy: 0.7404
# Epoch 28/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.7185 - accuracy: 0.7471
# Epoch 29/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.7157 - accuracy: 0.7454
# Epoch 30/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.6903 - accuracy: 0.7471
# Epoch 31/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.7314 - accuracy: 0.7504
# Epoch 32/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.6981 - accuracy: 0.7437
# Epoch 33/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.7086 - accuracy: 0.7471
# Epoch 34/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.6919 - accuracy: 0.7655
# Epoch 35/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.6877 - accuracy: 0.7554
# Epoch 36/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.6408 - accuracy: 0.7772
# Epoch 37/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.6333 - accuracy: 0.7973
# Epoch 38/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.6554 - accuracy: 0.7739
# Epoch 39/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.6203 - accuracy: 0.7822
# Epoch 40/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.6095 - accuracy: 0.7923
# Epoch 41/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.6445 - accuracy: 0.7705
# Epoch 42/200
# 19/18 [==============================] - 0s 16ms/step - loss: 0.6026 - accuracy: 0.7873
# Epoch 43/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.6176 - accuracy: 0.7873
# Epoch 44/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.5598 - accuracy: 0.8124
# Epoch 45/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.6008 - accuracy: 0.7940
# Epoch 46/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.5779 - accuracy: 0.7973
# Epoch 47/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.5994 - accuracy: 0.7923
# Epoch 48/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.5920 - accuracy: 0.7889
# Epoch 49/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.5182 - accuracy: 0.8208
# Epoch 50/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.5002 - accuracy: 0.8174
# Epoch 51/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4886 - accuracy: 0.8476
# Epoch 52/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.5227 - accuracy: 0.8141
# Epoch 53/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.5165 - accuracy: 0.8141
# Epoch 54/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.5573 - accuracy: 0.8090
# Epoch 55/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.5351 - accuracy: 0.7906
# Epoch 56/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.5606 - accuracy: 0.8107
# Epoch 57/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.4948 - accuracy: 0.8258
# Epoch 58/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.4941 - accuracy: 0.8409
# Epoch 59/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4704 - accuracy: 0.8409
# Epoch 60/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.4911 - accuracy: 0.8375
# Epoch 61/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4869 - accuracy: 0.8291
# Epoch 62/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4699 - accuracy: 0.8459
# Epoch 63/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.4609 - accuracy: 0.8392
# Epoch 64/200
# 19/18 [==============================] - 0s 16ms/step - loss: 0.4671 - accuracy: 0.8476
# Epoch 65/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4892 - accuracy: 0.8291
# Epoch 66/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.4292 - accuracy: 0.8459
# Epoch 67/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.4770 - accuracy: 0.8358
# Epoch 68/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4544 - accuracy: 0.8459
# Epoch 69/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4443 - accuracy: 0.8442
# Epoch 70/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4885 - accuracy: 0.8509
# Epoch 71/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4212 - accuracy: 0.8576
# Epoch 72/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.4409 - accuracy: 0.8476
# Epoch 73/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.4075 - accuracy: 0.8643
# Epoch 74/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.4533 - accuracy: 0.8509
# Epoch 75/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.4359 - accuracy: 0.8559
# Epoch 76/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4078 - accuracy: 0.8559
# Epoch 77/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4103 - accuracy: 0.8610
# Epoch 78/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4887 - accuracy: 0.8358
# Epoch 79/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.4296 - accuracy: 0.8559
# Epoch 80/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.4365 - accuracy: 0.8559
# Epoch 81/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.4091 - accuracy: 0.8509
# Epoch 82/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3609 - accuracy: 0.8727
# Epoch 83/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.4319 - accuracy: 0.8442
# Epoch 84/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.4249 - accuracy: 0.8509
# Epoch 85/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3969 - accuracy: 0.8777
# Epoch 86/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3986 - accuracy: 0.8643
# Epoch 87/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4299 - accuracy: 0.8509
# Epoch 88/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.4079 - accuracy: 0.8710
# Epoch 89/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3643 - accuracy: 0.8811
# Epoch 90/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3926 - accuracy: 0.8744
# Epoch 91/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.3632 - accuracy: 0.8777
# Epoch 92/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3831 - accuracy: 0.8610
# Epoch 93/200
# 19/18 [==============================] - 0s 21ms/step - loss: 0.3376 - accuracy: 0.8794
# Epoch 94/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3631 - accuracy: 0.8727
# Epoch 95/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3636 - accuracy: 0.8827
# Epoch 96/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3445 - accuracy: 0.8811
# Epoch 97/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3763 - accuracy: 0.8677
# Epoch 98/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3317 - accuracy: 0.8811
# Epoch 99/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3401 - accuracy: 0.8995
# Epoch 100/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3580 - accuracy: 0.8727
# Epoch 101/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3532 - accuracy: 0.8794
# Epoch 102/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3246 - accuracy: 0.8710
# Epoch 103/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3662 - accuracy: 0.8744
# Epoch 104/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3759 - accuracy: 0.8760
# Epoch 105/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3332 - accuracy: 0.8894
# Epoch 106/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3364 - accuracy: 0.8878
# Epoch 107/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.2717 - accuracy: 0.9213
# Epoch 108/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3121 - accuracy: 0.8911
# Epoch 109/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3221 - accuracy: 0.8894
# Epoch 110/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3179 - accuracy: 0.8827
# Epoch 111/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3106 - accuracy: 0.8794
# Epoch 112/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.3243 - accuracy: 0.8811
# Epoch 113/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2939 - accuracy: 0.8928
# Epoch 114/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3536 - accuracy: 0.8693
# Epoch 115/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3664 - accuracy: 0.8811
# Epoch 116/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.2969 - accuracy: 0.8978
# Epoch 117/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.3517 - accuracy: 0.8777
# Epoch 118/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3389 - accuracy: 0.8844
# Epoch 119/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.3271 - accuracy: 0.8727
# Epoch 120/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.3033 - accuracy: 0.8995
# Epoch 121/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.2659 - accuracy: 0.9095
# Epoch 122/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3044 - accuracy: 0.9028
# Epoch 123/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2421 - accuracy: 0.9146
# Epoch 124/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2759 - accuracy: 0.9112
# Epoch 125/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3561 - accuracy: 0.8878
# Epoch 126/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2897 - accuracy: 0.8894
# Epoch 127/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2710 - accuracy: 0.9095
# Epoch 128/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.2883 - accuracy: 0.8995
# Epoch 129/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2962 - accuracy: 0.8978
# Epoch 130/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2577 - accuracy: 0.9028
# Epoch 131/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2810 - accuracy: 0.8945
# Epoch 132/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3225 - accuracy: 0.8660
# Epoch 133/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2791 - accuracy: 0.9079
# Epoch 134/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.2761 - accuracy: 0.9062
# Epoch 135/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3007 - accuracy: 0.8995
# Epoch 136/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.3061 - accuracy: 0.8995
# Epoch 137/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2930 - accuracy: 0.9045
# Epoch 138/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2753 - accuracy: 0.9045
# Epoch 139/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2721 - accuracy: 0.9095
# Epoch 140/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2244 - accuracy: 0.9229
# Epoch 141/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2827 - accuracy: 0.9062
# Epoch 142/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2544 - accuracy: 0.9079
# Epoch 143/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2404 - accuracy: 0.9162
# Epoch 144/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.2629 - accuracy: 0.9129
# Epoch 145/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2430 - accuracy: 0.9162
# Epoch 146/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2678 - accuracy: 0.9179
# Epoch 147/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2573 - accuracy: 0.9079
# Epoch 148/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.2552 - accuracy: 0.8911
# Epoch 149/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2345 - accuracy: 0.9162
# Epoch 150/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2369 - accuracy: 0.9296
# Epoch 151/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.2714 - accuracy: 0.9045
# Epoch 152/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2618 - accuracy: 0.9028
# Epoch 153/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2205 - accuracy: 0.9162
# Epoch 154/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2208 - accuracy: 0.9196
# Epoch 155/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2078 - accuracy: 0.9129
# Epoch 156/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.2266 - accuracy: 0.9129
# Epoch 157/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2429 - accuracy: 0.9095
# Epoch 158/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2740 - accuracy: 0.9112
# Epoch 159/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.2331 - accuracy: 0.9162
# Epoch 160/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.2184 - accuracy: 0.9313
# Epoch 161/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2281 - accuracy: 0.9196
# Epoch 162/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2227 - accuracy: 0.9213
# Epoch 163/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2205 - accuracy: 0.9296
# Epoch 164/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.1856 - accuracy: 0.9414
# Epoch 165/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.1987 - accuracy: 0.9330
# Epoch 166/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.2174 - accuracy: 0.9280
# Epoch 167/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2181 - accuracy: 0.9213
# Epoch 168/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2089 - accuracy: 0.9196
# Epoch 169/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2588 - accuracy: 0.9079
# Epoch 170/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2991 - accuracy: 0.9028
# Epoch 171/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.2532 - accuracy: 0.9280
# Epoch 172/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2478 - accuracy: 0.9028
# Epoch 173/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2482 - accuracy: 0.9112
# Epoch 174/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2091 - accuracy: 0.9447
# Epoch 175/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.2265 - accuracy: 0.9196
# Epoch 176/200
# 19/18 [==============================] - 0s 16ms/step - loss: 0.2431 - accuracy: 0.9129
# Epoch 177/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.1969 - accuracy: 0.9330
# Epoch 178/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.1863 - accuracy: 0.9347
# Epoch 179/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.1847 - accuracy: 0.9313
# Epoch 180/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2417 - accuracy: 0.9196
# Epoch 181/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2850 - accuracy: 0.9079
# Epoch 182/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.2335 - accuracy: 0.9179
# Epoch 183/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.1872 - accuracy: 0.9380
# Epoch 184/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2231 - accuracy: 0.9296
# Epoch 185/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.1923 - accuracy: 0.9363
# Epoch 186/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.1921 - accuracy: 0.9263
# Epoch 187/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2022 - accuracy: 0.9246
# Epoch 188/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2700 - accuracy: 0.8961
# Epoch 189/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2739 - accuracy: 0.9028
# Epoch 190/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2049 - accuracy: 0.9363
# Epoch 191/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.2351 - accuracy: 0.9213
# Epoch 192/200
# 19/18 [==============================] - 0s 20ms/step - loss: 0.2086 - accuracy: 0.9313
# Epoch 193/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2441 - accuracy: 0.9179
# Epoch 194/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2088 - accuracy: 0.9280
# Epoch 195/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.1885 - accuracy: 0.9296
# Epoch 196/200
# 19/18 [==============================] - 0s 17ms/step - loss: 0.2137 - accuracy: 0.9330
# Epoch 197/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2007 - accuracy: 0.9263
# Epoch 198/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.1691 - accuracy: 0.9447
# Epoch 199/200
# 19/18 [==============================] - 0s 19ms/step - loss: 0.1953 - accuracy: 0.9313
# Epoch 200/200
# 19/18 [==============================] - 0s 18ms/step - loss: 0.2124 - accuracy: 0.9246
# Epoch 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-480b77e1b7af> in <module>
#      20     batches = 0
#      21     for x_batch, y_batch in datagen.flow(x_train, y_train, batch_size=32):
# ---> 22         model.fit(x_batch, y_batch)
#      23         batches += 1
#      24         if batches >= len(x_train) / 32:
#
# NameError: name 'model' is not defined
