# %%
import numpy as np # Pour la manipulation de tableaux
from keras.applications import  resnet50

import pandas as pd # Pour manipuler des DataFrames pandas

import matplotlib.pyplot as plt # Pour l'affichage d'images
from matplotlib import cm # Pour importer de nouvelles cartes de couleur
# %matplotlib inline

from keras.models import Sequential # Pour construire un réseau de neurones
from keras.layers import Dense, Conv2D # Pour instancier une couche dense
from keras.utils import np_utils

from keras.models import Sequential
from keras.layers import Dense, Activation,GlobalAveragePooling2D, MaxPooling2D
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.models import Model
import cv2
import keras

from keras.preprocessing.image import ImageDataGenerator
import itertools # Pour créer des iterateurs

from sklearn import linear_model, preprocessing 



# %matplotlib inline
import numpy as np

import matplotlib.pyplot as plt
import time, cv2
import seaborn as sns

import pandas as pd
from sklearn.model_selection import train_test_split

from keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.models import Model, Sequential
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras import backend as K
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.applications.vgg16 import preprocess_input

# %%
df=pd.read_csv("generateur_num.csv",index_col=0)
#(df["class"])=np_utils.to_categorical(df["class"])
df["class"] = df["class"].astype(str)
data_train=df.iloc[:800]
data_test=df.iloc[800:]

# %%
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        zoom_range = 1.1,
        horizontal_flip = False
        )

test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)

batch_size = 400


train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)


test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)


lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = 0.2)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 2,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)

lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation


#lenet.summary()


history=lenet.fit_generator( train_generator,
                           steps_per_epoch=len(data_train)//batch_size,
                           epochs=100,
                           workers=-1,
                           validation_data=test_generator,
                           validation_steps=len(data_test)//batch_size)


plt.figure(figsize=(16,12))
plt.plot(history.history['val_accuracy']);
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title("Accuracy en fonction du nombre d'epoch");
# Out:
# Found 800 validated image filenames belonging to 2 classes.
# Found 245 validated image filenames belonging to 2 classes.
# Epoch 1/100
# 2/2 [==============================] - 12s 6s/step - loss: 17.0199 - accuracy: 0.5263 - val_loss: 17.3117 - val_accuracy: 0.5347
# Epoch 2/100
# 2/2 [==============================] - 2s 849ms/step - loss: 10.8210 - accuracy: 0.5487 - val_loss: 4.4940 - val_accuracy: 0.5959
# Epoch 3/100
# 2/2 [==============================] - 2s 798ms/step - loss: 8.2703 - accuracy: 0.5400 - val_loss: 2.3705 - val_accuracy: 0.6653
# Epoch 4/100
# 2/2 [==============================] - 1s 628ms/step - loss: 3.8369 - accuracy: 0.5900 - val_loss: 3.8894 - val_accuracy: 0.5633
# Epoch 5/100
# 2/2 [==============================] - 1s 586ms/step - loss: 2.7182 - accuracy: 0.6050 - val_loss: 2.1196 - val_accuracy: 0.6000
# Epoch 6/100
# 2/2 [==============================] - 1s 606ms/step - loss: 1.7026 - accuracy: 0.6250 - val_loss: 2.2961 - val_accuracy: 0.7102
# Epoch 7/100
# 2/2 [==============================] - 1s 709ms/step - loss: 1.7884 - accuracy: 0.6237 - val_loss: 0.6533 - val_accuracy: 0.6939
# Epoch 8/100
# 2/2 [==============================] - 1s 660ms/step - loss: 1.0427 - accuracy: 0.6538 - val_loss: 0.6124 - val_accuracy: 0.7061
# Epoch 9/100
# 2/2 [==============================] - 1s 658ms/step - loss: 0.7699 - accuracy: 0.6650 - val_loss: 0.6433 - val_accuracy: 0.7429
# Epoch 10/100
# 2/2 [==============================] - 1s 684ms/step - loss: 0.6171 - accuracy: 0.6662 - val_loss: 0.7739 - val_accuracy: 0.6531
# Epoch 11/100
# 2/2 [==============================] - 1s 665ms/step - loss: 0.6796 - accuracy: 0.6475 - val_loss: 0.7873 - val_accuracy: 0.6612
# Epoch 12/100
# 2/2 [==============================] - 1s 728ms/step - loss: 0.5941 - accuracy: 0.6600 - val_loss: 0.7071 - val_accuracy: 0.7102
# Epoch 13/100
# 2/2 [==============================] - 1s 707ms/step - loss: 0.6087 - accuracy: 0.6737 - val_loss: 0.6098 - val_accuracy: 0.7837
# Epoch 14/100
# 2/2 [==============================] - 2s 833ms/step - loss: 0.5529 - accuracy: 0.7462 - val_loss: 0.5322 - val_accuracy: 0.8000
# Epoch 15/100
# 2/2 [==============================] - 1s 653ms/step - loss: 0.5476 - accuracy: 0.7387 - val_loss: 0.4979 - val_accuracy: 0.7429
# Epoch 16/100
# 2/2 [==============================] - 1s 655ms/step - loss: 0.5086 - accuracy: 0.7550 - val_loss: 0.4951 - val_accuracy: 0.8571
# Epoch 17/100
# 2/2 [==============================] - 1s 742ms/step - loss: 0.5206 - accuracy: 0.7887 - val_loss: 0.4813 - val_accuracy: 0.8204
# Epoch 18/100
# 2/2 [==============================] - 1s 732ms/step - loss: 0.5369 - accuracy: 0.7538 - val_loss: 0.4853 - val_accuracy: 0.8286
# Epoch 19/100
# 2/2 [==============================] - 1s 697ms/step - loss: 0.4843 - accuracy: 0.7825 - val_loss: 0.4860 - val_accuracy: 0.8449
# Epoch 20/100
# 2/2 [==============================] - 2s 772ms/step - loss: 0.4436 - accuracy: 0.7862 - val_loss: 0.5521 - val_accuracy: 0.6980
# Epoch 21/100
# 2/2 [==============================] - 1s 730ms/step - loss: 0.5795 - accuracy: 0.7163 - val_loss: 0.5982 - val_accuracy: 0.7020
# Epoch 22/100
# 2/2 [==============================] - 2s 758ms/step - loss: 0.5666 - accuracy: 0.7538 - val_loss: 0.5613 - val_accuracy: 0.7020
# Epoch 23/100
# 2/2 [==============================] - 1s 667ms/step - loss: 0.4901 - accuracy: 0.7212 - val_loss: 0.4932 - val_accuracy: 0.8245
# Epoch 24/100
# 2/2 [==============================] - 1s 654ms/step - loss: 0.4798 - accuracy: 0.7638 - val_loss: 0.4895 - val_accuracy: 0.7633
# Epoch 25/100
# 2/2 [==============================] - 2s 859ms/step - loss: 0.4914 - accuracy: 0.7000 - val_loss: 0.4739 - val_accuracy: 0.7510
# Epoch 26/100
# 2/2 [==============================] - 1s 622ms/step - loss: 0.4880 - accuracy: 0.6900 - val_loss: 0.4670 - val_accuracy: 0.7429
# Epoch 27/100
# 2/2 [==============================] - 1s 579ms/step - loss: 0.4838 - accuracy: 0.7013 - val_loss: 0.4665 - val_accuracy: 0.7388
# Epoch 28/100
# 2/2 [==============================] - 2s 813ms/step - loss: 0.4951 - accuracy: 0.6963 - val_loss: 0.4735 - val_accuracy: 0.7347
# Epoch 29/100
# 2/2 [==============================] - 2s 852ms/step - loss: 0.4559 - accuracy: 0.7150 - val_loss: 0.4889 - val_accuracy: 0.7224
# Epoch 30/100
# 2/2 [==============================] - 1s 727ms/step - loss: 0.4433 - accuracy: 0.7125 - val_loss: 0.5053 - val_accuracy: 0.7143
# Epoch 31/100
# 2/2 [==============================] - 1s 567ms/step - loss: 0.4527 - accuracy: 0.7075 - val_loss: 0.5214 - val_accuracy: 0.7102
# Epoch 32/100
# 2/2 [==============================] - 1s 722ms/step - loss: 0.4717 - accuracy: 0.7088 - val_loss: 0.5032 - val_accuracy: 0.7143
# Epoch 33/100
# 2/2 [==============================] - 1s 614ms/step - loss: 0.4594 - accuracy: 0.7125 - val_loss: 0.4595 - val_accuracy: 0.7347
# Epoch 34/100
# 2/2 [==============================] - 1s 577ms/step - loss: 0.4685 - accuracy: 0.7088 - val_loss: 0.4374 - val_accuracy: 0.7347
# Epoch 76/100
# 2/2 [==============================] - 1s 594ms/step - loss: 0.3948 - accuracy: 0.8037 - val_loss: 0.3658 - val_accuracy: 0.8327
# Epoch 77/100
# 2/2 [==============================] - 1s 707ms/step - loss: 0.3911 - accuracy: 0.7887 - val_loss: 0.3797 - val_accuracy: 0.8408
# Epoch 78/100
# 2/2 [==============================] - 2s 835ms/step - loss: 0.3486 - accuracy: 0.8138 - val_loss: 0.4346 - val_accuracy: 0.8408
# Epoch 79/100
# 2/2 [==============================] - 1s 724ms/step - loss: 0.3567 - accuracy: 0.8512 - val_loss: 0.4471 - val_accuracy: 0.8367
# Epoch 80/100
# 2/2 [==============================] - 1s 648ms/step - loss: 0.3541 - accuracy: 0.8450 - val_loss: 0.4060 - val_accuracy: 0.8939
# Epoch 81/100
# 2/2 [==============================] - 1s 699ms/step - loss: 0.3359 - accuracy: 0.8450 - val_loss: 0.3689 - val_accuracy: 0.9102
# Epoch 82/100
# 2/2 [==============================] - 1s 664ms/step - loss: 0.3273 - accuracy: 0.8550 - val_loss: 0.3604 - val_accuracy: 0.9224
# Epoch 83/100
# 2/2 [==============================] - 1s 532ms/step - loss: 0.3053 - accuracy: 0.8750 - val_loss: 0.3710 - val_accuracy: 0.9224
# Epoch 84/100
# 2/2 [==============================] - 1s 486ms/step - loss: 0.3250 - accuracy: 0.8788 - val_loss: 0.3873 - val_accuracy: 0.9306
# Epoch 85/100
# 2/2 [==============================] - 1s 474ms/step - loss: 0.3086 - accuracy: 0.8712 - val_loss: 0.3741 - val_accuracy: 0.9388
# Epoch 86/100
# 2/2 [==============================] - 1s 746ms/step - loss: 0.3385 - accuracy: 0.8675 - val_loss: 0.3750 - val_accuracy: 0.9265
# Epoch 87/100
# 2/2 [==============================] - 2s 776ms/step - loss: 0.3231 - accuracy: 0.8750 - val_loss: 0.3564 - val_accuracy: 0.9306
# Epoch 88/100
# 2/2 [==============================] - 1s 750ms/step - loss: 0.2934 - accuracy: 0.8700 - val_loss: 0.3655 - val_accuracy: 0.9388
# Epoch 89/100
# 2/2 [==============================] - 2s 818ms/step - loss: 0.3102 - accuracy: 0.8600 - val_loss: 0.4126 - val_accuracy: 0.9061
# Epoch 90/100
# 2/2 [==============================] - 2s 788ms/step - loss: 0.3046 - accuracy: 0.9013 - val_loss: 0.3694 - val_accuracy: 0.9347
# Epoch 91/100
# 2/2 [==============================] - 1s 736ms/step - loss: 0.3103 - accuracy: 0.8487 - val_loss: 0.3537 - val_accuracy: 0.9388
# Epoch 92/100
# 2/2 [==============================] - 1s 475ms/step - loss: 0.3127 - accuracy: 0.8525 - val_loss: 0.3911 - val_accuracy: 0.9061
# Epoch 93/100
# 2/2 [==============================] - 1s 529ms/step - loss: 0.3144 - accuracy: 0.8875 - val_loss: 0.3559 - val_accuracy: 0.9306
# Epoch 94/100
# 2/2 [==============================] - 1s 602ms/step - loss: 0.3351 - accuracy: 0.8438 - val_loss: 0.3336 - val_accuracy: 0.9429
# Epoch 95/100
# 2/2 [==============================] - 1s 519ms/step - loss: 0.3051 - accuracy: 0.8562 - val_loss: 0.3765 - val_accuracy: 0.9102
# Epoch 96/100
# 2/2 [==============================] - 1s 554ms/step - loss: 0.3310 - accuracy: 0.8600 - val_loss: 0.3893 - val_accuracy: 0.9265
# Epoch 97/100
# 2/2 [==============================] - 2s 859ms/step - loss: 0.2782 - accuracy: 0.8775 - val_loss: 0.3445 - val_accuracy: 0.9469
# Epoch 98/100
# 2/2 [==============================] - 2s 804ms/step - loss: 0.2902 - accuracy: 0.8725 - val_loss: 0.3738 - val_accuracy: 0.9265
# Epoch 99/100
# 2/2 [==============================] - 2s 761ms/step - loss: 0.3146 - accuracy: 0.8763 - val_loss: 0.4006 - val_accuracy: 0.9224
# Epoch 100/100
# 2/2 [==============================] - 1s 714ms/step - loss: 0.3072 - accuracy: 0.8863 - val_loss: 0.3473 - val_accuracy: 0.9306

# %%
#lenet.predict(test_generator)
#lenet.predict_generator(test_generator)




train_generator1 = train_data_generator.flow_from_dataframe(dataframe=data_train[0:20],
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)

(lenet.predict_generator(train_generator1))
# Out:
# Found 20 validated image filenames belonging to 2 classes.
# array([[7.7677925e-26, 1.0000000e+00],
#        [7.2793374e-03, 9.9272072e-01],
#        [1.5631009e-02, 9.8436892e-01],
#        [5.2527601e-01, 4.7472408e-01],
#        [1.4827282e-03, 9.9851733e-01],
#        [7.4930317e-03, 9.9250692e-01],
#        [9.7919697e-01, 2.0802988e-02],
#        [4.7744342e-09, 1.0000000e+00],
#        [9.9992704e-01, 7.2942348e-05],
#        [6.5472186e-01, 3.4527811e-01],
#        [9.9855667e-01, 1.4433565e-03],
#        [2.1149802e-04, 9.9978846e-01],
#        [9.8952031e-01, 1.0479722e-02],
#        [8.6696726e-01, 1.3303269e-01],
#        [8.2285690e-01, 1.7714314e-01],
#        [5.0401217e-01, 4.9598789e-01],
#        [7.2213632e-01, 2.7786362e-01],
#        [2.7290739e-02, 9.7270930e-01],
#        [7.0624086e-19, 1.0000000e+00],
#        [9.3291962e-01, 6.7080423e-02]], dtype=float32)

# %%
import pickle
#lm=pickle.loads(lenet_model) 
#f = open("output/log_model.pickle", "wb")
f = open("lenet_model", "wb")

# %%
#print("[INFO] saving model...")
f = open("output/modelddddddd.pickle", "wb")
#f.write(pickle.dumps(log))
#f.close()
f
# Out:
# <_io.BufferedWriter name='output/modelddddddd.pickle'>

# %%
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        zoom_range = 1.1,
        horizontal_flip = False
        )

test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)

batch_size = 400


train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)


test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)


lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = 0.2)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 2,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)

lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation


#lenet.summary()


history=lenet.fit_generator( train_generator,
                           steps_per_epoch=len(data_train)//batch_size,
                           epochs=50,
                           workers=-1,
                           validation_data=test_generator,
                           validation_steps=len(data_test)//batch_size)
# Out:
# Found 1045 validated image filenames belonging to 2 classes.
# Found 245 validated image filenames belonging to 2 classes.
# Epoch 1/50
# 2/2 [==============================] - 1s 472ms/step - loss: 9.0147 - accuracy: 0.5000 - val_loss: 4.3542 - val_accuracy: 0.4857
# Epoch 2/50
# 2/2 [==============================] - 1s 327ms/step - loss: 3.7547 - accuracy: 0.5473 - val_loss: 2.7918 - val_accuracy: 0.5388
# Epoch 3/50
# 2/2 [==============================] - 1s 336ms/step - loss: 3.0409 - accuracy: 0.5473 - val_loss: 2.7296 - val_accuracy: 0.5551
# Epoch 4/50
# 2/2 [==============================] - 1s 436ms/step - loss: 2.3329 - accuracy: 0.5512 - val_loss: 1.2396 - val_accuracy: 0.6122
# Epoch 5/50
# 2/2 [==============================] - 1s 382ms/step - loss: 1.0142 - accuracy: 0.6419 - val_loss: 0.5899 - val_accuracy: 0.8041
# Epoch 6/50
# 2/2 [==============================] - 1s 383ms/step - loss: 0.7174 - accuracy: 0.6760 - val_loss: 0.5835 - val_accuracy: 0.7184
# Epoch 7/50
# 2/2 [==============================] - 1s 422ms/step - loss: 0.7878 - accuracy: 0.6762 - val_loss: 0.5835 - val_accuracy: 0.7592
# Epoch 8/50
# 2/2 [==============================] - 1s 377ms/step - loss: 0.6269 - accuracy: 0.6605 - val_loss: 0.5864 - val_accuracy: 0.7265
# Epoch 9/50
# 2/2 [==============================] - 1s 362ms/step - loss: 0.5928 - accuracy: 0.6992 - val_loss: 0.5651 - val_accuracy: 0.7184
# Epoch 10/50
# 2/2 [==============================] - 1s 453ms/step - loss: 0.5835 - accuracy: 0.7050 - val_loss: 0.5054 - val_accuracy: 0.7469
# Epoch 11/50
# 2/2 [==============================] - 1s 389ms/step - loss: 0.5128 - accuracy: 0.7039 - val_loss: 0.4653 - val_accuracy: 0.7469
# Epoch 12/50
# 2/2 [==============================] - 1s 373ms/step - loss: 0.5107 - accuracy: 0.7333 - val_loss: 0.5004 - val_accuracy: 0.7265
# Epoch 13/50
# 2/2 [==============================] - 1s 474ms/step - loss: 0.5476 - accuracy: 0.7237 - val_loss: 0.4275 - val_accuracy: 0.7592
# Epoch 14/50
# 2/2 [==============================] - 1s 362ms/step - loss: 0.5392 - accuracy: 0.7364 - val_loss: 0.4187 - val_accuracy: 0.8000
# Epoch 15/50
# 2/2 [==============================] - 1s 372ms/step - loss: 0.4829 - accuracy: 0.7457 - val_loss: 0.4570 - val_accuracy: 0.7429
# Epoch 16/50
# 2/2 [==============================] - 1s 466ms/step - loss: 0.5014 - accuracy: 0.7275 - val_loss: 0.4213 - val_accuracy: 0.8082
# Epoch 17/50
# 2/2 [==============================] - 1s 353ms/step - loss: 0.4732 - accuracy: 0.7643 - val_loss: 0.4152 - val_accuracy: 0.8286
# Epoch 18/50
# 2/2 [==============================] - 1s 336ms/step - loss: 0.4566 - accuracy: 0.7876 - val_loss: 0.4028 - val_accuracy: 0.8408
# Epoch 19/50
# 2/2 [==============================] - 1s 442ms/step - loss: 0.5027 - accuracy: 0.7625 - val_loss: 0.4023 - val_accuracy: 0.8245
# Epoch 20/50
# 2/2 [==============================] - 1s 352ms/step - loss: 0.4806 - accuracy: 0.7550 - val_loss: 0.3844 - val_accuracy: 0.8408
# Epoch 21/50
# 2/2 [==============================] - 1s 359ms/step - loss: 0.4425 - accuracy: 0.8000 - val_loss: 0.3439 - val_accuracy: 0.8571
# Epoch 22/50
# 2/2 [==============================] - 1s 431ms/step - loss: 0.4666 - accuracy: 0.7775 - val_loss: 0.3581 - val_accuracy: 0.8367
# Epoch 23/50
# 2/2 [==============================] - 1s 371ms/step - loss: 0.4707 - accuracy: 0.7364 - val_loss: 0.4152 - val_accuracy: 0.7592
# Epoch 24/50
# 2/2 [==============================] - 1s 368ms/step - loss: 0.5131 - accuracy: 0.7054 - val_loss: 0.4151 - val_accuracy: 0.7429
# Epoch 25/50
# 2/2 [==============================] - 1s 420ms/step - loss: 0.5029 - accuracy: 0.7025 - val_loss: 0.4084 - val_accuracy: 0.7592
# Epoch 26/50
# 2/2 [==============================] - 1s 355ms/step - loss: 0.4912 - accuracy: 0.6837 - val_loss: 0.4039 - val_accuracy: 0.7592
# Epoch 27/50
# 2/2 [==============================] - 1s 347ms/step - loss: 0.4987 - accuracy: 0.7116 - val_loss: 0.4015 - val_accuracy: 0.7633
# Epoch 28/50
# 2/2 [==============================] - 1s 446ms/step - loss: 0.5120 - accuracy: 0.6812 - val_loss: 0.4001 - val_accuracy: 0.7592
# Epoch 29/50
# 2/2 [==============================] - 1s 381ms/step - loss: 0.4914 - accuracy: 0.6899 - val_loss: 0.3924 - val_accuracy: 0.7592
# Epoch 30/50
# 2/2 [==============================] - 1s 378ms/step - loss: 0.4760 - accuracy: 0.7101 - val_loss: 0.3898 - val_accuracy: 0.7551
# Epoch 31/50
# 2/2 [==============================] - 1s 447ms/step - loss: 0.4680 - accuracy: 0.7150 - val_loss: 0.3902 - val_accuracy: 0.7551
# Epoch 32/50
# 2/2 [==============================] - 1s 338ms/step - loss: 0.4841 - accuracy: 0.7054 - val_loss: 0.3952 - val_accuracy: 0.7551
# Epoch 33/50
# 2/2 [==============================] - 1s 376ms/step - loss: 0.4740 - accuracy: 0.7132 - val_loss: 0.4017 - val_accuracy: 0.7551
# Epoch 34/50
# 2/2 [==============================] - 1s 470ms/step - loss: 0.4518 - accuracy: 0.7250 - val_loss: 0.4004 - val_accuracy: 0.7592
# Epoch 35/50
# 2/2 [==============================] - 1s 416ms/step - loss: 0.4407 - accuracy: 0.7147 - val_loss: 0.3932 - val_accuracy: 0.7633
# Epoch 36/50
# 2/2 [==============================] - 1s 426ms/step - loss: 0.5033 - accuracy: 0.7070 - val_loss: 0.3817 - val_accuracy: 0.7755
# Epoch 37/50
# 2/2 [==============================] - 1s 470ms/step - loss: 0.4511 - accuracy: 0.7400 - val_loss: 0.3688 - val_accuracy: 0.8204
# Epoch 38/50
# 2/2 [==============================] - 1s 399ms/step - loss: 0.4472 - accuracy: 0.7519 - val_loss: 0.3615 - val_accuracy: 0.8327
# Epoch 39/50
# 2/2 [==============================] - 1s 400ms/step - loss: 0.4463 - accuracy: 0.8000 - val_loss: 0.3520 - val_accuracy: 0.7551
# Epoch 40/50
# 2/2 [==============================] - 1s 487ms/step - loss: 0.4482 - accuracy: 0.7100 - val_loss: 0.3595 - val_accuracy: 0.7592
# Epoch 41/50
# 2/2 [==============================] - 1s 391ms/step - loss: 0.4326 - accuracy: 0.7209 - val_loss: 0.3540 - val_accuracy: 0.7633
# Epoch 42/50
# 2/2 [==============================] - 1s 441ms/step - loss: 0.4605 - accuracy: 0.7256 - val_loss: 0.3503 - val_accuracy: 0.7673
# Epoch 43/50
# 2/2 [==============================] - 1s 424ms/step - loss: 0.4334 - accuracy: 0.7275 - val_loss: 0.3497 - val_accuracy: 0.7714
# Epoch 44/50
# 2/2 [==============================] - 1s 342ms/step - loss: 0.4321 - accuracy: 0.7411 - val_loss: 0.3503 - val_accuracy: 0.7796
# Epoch 45/50
# 2/2 [==============================] - 1s 387ms/step - loss: 0.4667 - accuracy: 0.7054 - val_loss: 0.3549 - val_accuracy: 0.7796
# Epoch 46/50
# 2/2 [==============================] - 1s 454ms/step - loss: 0.4400 - accuracy: 0.7113 - val_loss: 0.3545 - val_accuracy: 0.7796
# Epoch 47/50
# 2/2 [==============================] - 1s 362ms/step - loss: 0.4521 - accuracy: 0.7504 - val_loss: 0.3545 - val_accuracy: 0.7796
# Epoch 48/50
# 2/2 [==============================] - 1s 383ms/step - loss: 0.4475 - accuracy: 0.7023 - val_loss: 0.3513 - val_accuracy: 0.7796
# Epoch 49/50
# 2/2 [==============================] - 1s 433ms/step - loss: 0.4263 - accuracy: 0.7275 - val_loss: 0.3483 - val_accuracy: 0.7796
# Epoch 50/50
# 2/2 [==============================] - 1s 379ms/step - loss: 0.4332 - accuracy: 0.7380 - val_loss: 0.3442 - val_accuracy: 0.7796

# %%
plt.figure(figsize=(16,12))
plt.plot(history.history['val_accuracy']);
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title("Accuracy en fonction du nombre d'epoch");

# %%
def convert_image(X):
    X_img=[]
    for image in X:
        # Load image
        img=cv2.imread(image)
        # Resize image
        img=cv2.resize(img,(28,28))
        # for the black and white image
        if img.shape==(28, 28):
            img=img.reshape([28,28,1])
            img=np.concatenate([img,img,img],axis=2)
        # cv2 load the image BGR sequence color (not RGB)
        X_img.append(img[...,::-1])
    return np.array(X_img)

# Load the images train
X_train_img = convert_image(data_train.img_paths)
Y_train = data_train['class']

# Load the images test
X_test_img = convert_image(data_test.img_paths)
Y_test = data_test['class']

# %% [raw]
# # Insérez votre code ici
# from sklearn.svm import SVC
# intermediate_layer_model = Model(input=lenet.input, output=lenet.layers[-1].output)
# #print(intermediate_layer_model)
# X_train_features = intermediate_layer_model.predict(preprocess_input(X_train_img))
# #print("X_train_features",X_train_features)
# #print("X_train_features_shape",X_train_features.shape)
# X_test_features = intermediate_layer_model.predict(preprocess_input(X_test_img))
# #print("X_test_features",X_test_features)
#
# from sklearn import metrics
# y_train=df["class"].iloc[:800]
# y_test=df["class"].iloc[800:]
#
# lg = linear_model.LogisticRegression(C = 1.0)
# lg.fit(X_train_features, y_train);
# y_predict=lg.predict(X_test_features)
# print(lg.score(X_test_features, y_test))
# print(metrics.classification_report(y_test, y_predict))

# %%
intermediate_layer_model = Model(input=lenet.input, output=lenet.layers[-2].output)
#print(intermediate_layer_model)
X_train_features = intermediate_layer_model.predict(preprocess_input(X_train_img))
#print("X_train_features",X_train_features)
#print("X_train_features_shape",X_train_features.shape)
X_test_features = intermediate_layer_model.predict(preprocess_input(X_test_img))
#print("X_test_features",X_test_features)

y_train=df["class"].iloc[:800]
y_test=df["class"].iloc[800:]

lg = linear_model.LogisticRegression(C = 1.0)
lg.fit(X_train_features, y_train);
y_predict=lg.predict(X_test_features)
print(lg.score(X_test_features, y_test))
print(metrics.classification_report(y_test, y_predict))
# Out:
# 0.9551020408163265
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95       114
#            1       0.95      0.96      0.96       131
#
#     accuracy                           0.96       245
#    macro avg       0.96      0.95      0.95       245
# weighted avg       0.96      0.96      0.96       245
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("co..., outputs=Tensor("de...)`
#   """Entry point for launching an IPython kernel.
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
intermediate_layer_model = Model(input=lenet.input, output=lenet.layers[-1].output)
#print(intermediate_layer_model)
X_train_features = intermediate_layer_model.predict(preprocess_input(X_train_img))
#print("X_train_features",X_train_features)
#print("X_train_features_shape",X_train_features.shape)
X_test_features = intermediate_layer_model.predict(preprocess_input(X_test_img))
#print("X_test_features",X_test_features)

y_train=df["class"].iloc[:800]
y_test=df["class"].iloc[800:]

lg = linear_model.LogisticRegression(C = 1.0)
lg.fit(X_train_features, y_train);
y_predict=lg.predict(X_test_features)
print(lg.score(X_test_features, y_test))
print(metrics.classification_report(y_test, y_predict))
# Out:
# 0.9551020408163265
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95       114
#            1       0.95      0.96      0.96       131
#
#     accuracy                           0.96       245
#    macro avg       0.96      0.95      0.95       245
# weighted avg       0.96      0.96      0.96       245
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("co..., outputs=Tensor("de...)`
#   """Entry point for launching an IPython kernel.
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
