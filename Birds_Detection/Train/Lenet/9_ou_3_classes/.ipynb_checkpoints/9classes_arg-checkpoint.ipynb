# %%
import numpy as np # Pour la manipulation de tableaux
from keras.applications import  resnet50
from sklearn import metrics 
import os

import pandas as pd # Pour manipuler des DataFrames pandas

import matplotlib.pyplot as plt # Pour l'affichage d'images
from matplotlib import cm # Pour importer de nouvelles cartes de couleur
# %matplotlib inline

from keras.models import Sequential # Pour construire un réseau de neurones
from keras.layers import Dense, Conv2D # Pour instancier une couche dense
from keras.utils import np_utils

from keras.models import Sequential
from keras.layers import Dense, Activation,GlobalAveragePooling2D, MaxPooling2D
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.models import Model
import cv2
import keras
from numpy.random import seed
import tensorflow

from keras.preprocessing.image import ImageDataGenerator
import itertools # Pour créer des iterateurs

from sklearn import linear_model, preprocessing 



# %matplotlib inline
import numpy as np

import matplotlib.pyplot as plt
import time, cv2
import seaborn as sns

import pandas as pd
from sklearn.model_selection import train_test_split

from keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.models import Model, Sequential
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras import backend as K
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.applications.vgg16 import preprocess_input
# Out:
# Using TensorFlow backend.

# %%
#Paramètres
base_img_paths="/home/marcpozzo/Desktop/c3po/Images_aquises/"
generateur_path='/mnt/VegaSlowDataDisk/c3po/Chaine_de_traitement/Train_imagettes_annotées/type_oiseau/generateur.csv'
test_size=0.2
epochs=200
batch_size = 600
class_mode="sparse"
zoom_range = 1.1
horizontal_flip = False
Minimum_Number_Class=100
dropout_rate=0

#steps_per_epoch=1

#validation_steps=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ad690db19156> in <module>
#      10 Minimum_Number_Class=100
#      11 dropout_rate=0
# ---> 12 steps_per_epoch=len(data_train)//batch_size
#      13 #steps_per_epoch=1
#      14 validation_steps=len(data_test)//batch_size
#
# NameError: name 'data_train' is not defined

# %%
#df=pd.read_csv("/home/marcpozzo/Desktop/c3po/Images_aquises/generateur.csv")
df=pd.read_csv(generateur_path)
print(pd.isnull(df).sum())
#df.drop('labels',inplace=True,axis=1)
for i in df["labels"].unique():
    print(i,len(df["labels"][df["labels"]==i]))

# %%
Non_utilisable=['Abeille',
                'chat','leaf','shadow','sanglier', 'rock','other', 'plastic','autre', 'ciel', 'ombre','cheval','avion']

for i in Non_utilisable:
    df=df[df["labels"]!=i]
df["labels"].unique()
# Out:
# array(['incertain', 'ground', 'corneille', 'pigeon', 'pie', 'chevreuil',
#        'Corneille', 'Lapin', 'lapin', 'dirt', 'crow', 'faisan', 'oiseau',
#        'flying crow', 'voiture', 'tracteur'], dtype=object)

# %%
df.head()
# Out:
#       labels      class                            img_paths
# 0  incertain     oiseau  Rec_images/DSCF0029_incertain_0.JPG
# 1     ground      autre     Rec_images/DSCF0029_ground_1.JPG
# 2  corneille  corneille  Rec_images/DSCF0180_corneille_2.JPG
# 3  corneille  corneille  Rec_images/DSCF0180_corneille_3.JPG
# 4     pigeon     pigeon     Rec_images/DSCF0258_pigeon_4.JPG

# %%
df["class"]=df["class"].replace("pie","oiseau")
df["class"][df["labels"]=="voiture"]="voiture"
df["class"][df["labels"]=="tracteur"]="tracteur"
print(len(df["class"].unique()))
df
# Out:
# 9
#          labels      class                                          img_paths
# 0     incertain     oiseau                Rec_images/DSCF0029_incertain_0.JPG
# 1        ground      autre                   Rec_images/DSCF0029_ground_1.JPG
# 2     corneille  corneille                Rec_images/DSCF0180_corneille_2.JPG
# 3     corneille  corneille                Rec_images/DSCF0180_corneille_3.JPG
# 4        pigeon     pigeon                   Rec_images/DSCF0258_pigeon_4.JPG
# ...         ...        ...                                                ...
# 6215     ground      autre  Rec_images/image_2019-04-30_18-55-20_ground_62...
# 6216     pigeon     pigeon  Rec_images/image_2019-04-30_18-55-20_pigeon_62...
# 6217     ground      autre  Rec_images/image_2019-04-30_18-55-20_ground_62...
# 6218     pigeon     pigeon  Rec_images/image_2019-04-30_18-55-20_pigeon_62...
# 6219     ground      autre  Rec_images/image_2019-04-30_18-55-20_ground_62...
#
# [6117 rows x 3 columns]

# %%
df["class"].unique()
to_change=['chat','abeille','sanglier','cheval']
df["class"]=df["class"].replace(to_change,"autre_animaux")
len(df[df["class"]=="autre_animaux"])
df1=df[df["class"]!="autre_animaux"]
df1["labels"].unique()
# Out:
# array(['incertain', 'ground', 'corneille', 'pigeon', 'pie', 'chevreuil',
#        'Corneille', 'Lapin', 'lapin', 'dirt', 'crow', 'faisan', 'oiseau',
#        'flying crow', 'voiture', 'tracteur'], dtype=object)

# %%
df["class"].unique()
for c in df:
    print(''+c+':',len(df[c].unique()))
df["labels"].unique()
# Out:
# labels: 16
# class: 9
# img_paths: 6117
# array(['incertain', 'ground', 'corneille', 'pigeon', 'pie', 'chevreuil',
#        'Corneille', 'Lapin', 'lapin', 'dirt', 'crow', 'faisan', 'oiseau',
#        'flying crow', 'voiture', 'tracteur'], dtype=object)

# %%
All_Unique=df["labels"].unique()
Utilisable=[]
for i in df["labels"].unique():
    if df["labels"][df["labels"]==i].count()>Minimum_Number_Class:
        Utilisable.append(i)
Utilisable
Non_Utilisable=set(All_Unique)-set(Utilisable)
Non_Utilisable
for i in Non_Utilisable:
    df=df[df["labels"]!=i]
#df=df[df["class"]!="oiseau"]  
df["labels"].unique()
for i in df["labels"].unique():
    print(i,len(df["labels"][df["labels"]==i]))
# Out:
# incertain 216
# ground 2975
# corneille 1044
# pigeon 828
# chevreuil 136
# lapin 176
# faisan 335
# voiture 133
# tracteur 141

# %%
for i in range(len(df["class"])):
    image_name=df["img_paths"].iloc[i]
    df["img_paths"].iloc[i]=os.path.join(base_img_paths,image_name)
    
df.head()
# Out:
#       labels      class                                          img_paths
# 0  incertain     oiseau  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 1     ground      autre  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 2  corneille  corneille  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 3  corneille  corneille  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 4     pigeon     pigeon  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...

# %%
#df["labels"][df["class"]=="autre"].unique()
data_train,data_test= train_test_split(df,stratify=df["class"], test_size=test_size,random_state=42)

# %%
validation_steps=len(data_test)//batch_size
steps_per_epoch=len(data_train)//batch_size

epochs=200
seed(1)
tensorflow.random.set_seed(2)
class_mode="sparse"

data_train,data_test= train_test_split(df,stratify=df["class"], test_size=test_size,random_state=42)
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        zoom_range = zoom_range,
        horizontal_flip = horizontal_flip
        )

test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)




train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode =class_mode,
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)


test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode =class_mode,
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)



lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = dropout_rate)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 9,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation




history=lenet.fit_generator( train_generator,
                           steps_per_epoch=len(data_train)//batch_size,
                           epochs=epochs,
                           workers=-1,
                           validation_data=test_generator,
                           validation_steps=len(data_test)//batch_size)
# Out:
# Found 4787 validated image filenames belonging to 9 classes.
# Found 1197 validated image filenames belonging to 9 classes.
# Epoch 1/200
# 7/7 [==============================] - 5s 698ms/step - loss: 8.5428 - accuracy: 0.2988 - val_loss: 2.9756 - val_accuracy: 0.2467
# Epoch 2/200
# 7/7 [==============================] - 5s 669ms/step - loss: 2.5195 - accuracy: 0.3805 - val_loss: 2.0770 - val_accuracy: 0.5025
# Epoch 3/200
# 7/7 [==============================] - 5s 657ms/step - loss: 1.7674 - accuracy: 0.5293 - val_loss: 1.4476 - val_accuracy: 0.5783
# Epoch 4/200
# 7/7 [==============================] - 4s 640ms/step - loss: 1.4744 - accuracy: 0.5663 - val_loss: 1.4712 - val_accuracy: 0.5946
# Epoch 5/200
# 7/7 [==============================] - 4s 624ms/step - loss: 1.3447 - accuracy: 0.6004 - val_loss: 1.2757 - val_accuracy: 0.6533
# Epoch 6/200
# 7/7 [==============================] - 5s 646ms/step - loss: 1.2178 - accuracy: 0.6191 - val_loss: 1.1403 - val_accuracy: 0.6717
# Epoch 7/200
# 7/7 [==============================] - 5s 661ms/step - loss: 1.1875 - accuracy: 0.6403 - val_loss: 1.0647 - val_accuracy: 0.7083
# Epoch 8/200
# 7/7 [==============================] - 5s 652ms/step - loss: 1.1011 - accuracy: 0.6570 - val_loss: 1.0674 - val_accuracy: 0.7002
# Epoch 9/200
# 7/7 [==============================] - 5s 667ms/step - loss: 1.0588 - accuracy: 0.6721 - val_loss: 0.9719 - val_accuracy: 0.7300
# Epoch 10/200
# 7/7 [==============================] - 4s 608ms/step - loss: 1.0326 - accuracy: 0.6857 - val_loss: 0.9850 - val_accuracy: 0.7303
# Epoch 11/200
# 7/7 [==============================] - 4s 631ms/step - loss: 1.0130 - accuracy: 0.6909 - val_loss: 0.9554 - val_accuracy: 0.7600
# Epoch 12/200
# 7/7 [==============================] - 5s 672ms/step - loss: 0.9738 - accuracy: 0.7079 - val_loss: 0.8894 - val_accuracy: 0.7504
# Epoch 13/200
# 7/7 [==============================] - 5s 666ms/step - loss: 0.9314 - accuracy: 0.7194 - val_loss: 0.9147 - val_accuracy: 0.7517
# Epoch 14/200
# 7/7 [==============================] - 5s 647ms/step - loss: 0.9303 - accuracy: 0.7148 - val_loss: 0.8108 - val_accuracy: 0.7839
# Epoch 15/200
# 7/7 [==============================] - 5s 671ms/step - loss: 0.9101 - accuracy: 0.7270 - val_loss: 0.8101 - val_accuracy: 0.7750
# Epoch 16/200
# 7/7 [==============================] - 5s 652ms/step - loss: 0.9056 - accuracy: 0.7311 - val_loss: 0.8301 - val_accuracy: 0.7822
# Epoch 17/200
# 7/7 [==============================] - 5s 663ms/step - loss: 0.8897 - accuracy: 0.7243 - val_loss: 0.8731 - val_accuracy: 0.7850
# Epoch 18/200
# 7/7 [==============================] - 5s 681ms/step - loss: 0.8423 - accuracy: 0.7466 - val_loss: 0.7004 - val_accuracy: 0.7990
# Epoch 19/200
# 7/7 [==============================] - 4s 634ms/step - loss: 0.8425 - accuracy: 0.7433 - val_loss: 0.6982 - val_accuracy: 0.8017
# Epoch 20/200
# 7/7 [==============================] - 4s 632ms/step - loss: 0.8500 - accuracy: 0.7356 - val_loss: 0.8497 - val_accuracy: 0.7906
# Epoch 21/200
# 7/7 [==============================] - 5s 665ms/step - loss: 0.8605 - accuracy: 0.7382 - val_loss: 0.8321 - val_accuracy: 0.7967
# Epoch 22/200
# 7/7 [==============================] - 5s 684ms/step - loss: 0.8242 - accuracy: 0.7476 - val_loss: 0.7199 - val_accuracy: 0.8074
# Epoch 23/200
# 7/7 [==============================] - 5s 665ms/step - loss: 0.8200 - accuracy: 0.7571 - val_loss: 0.7110 - val_accuracy: 0.8233
# Epoch 24/200
# 7/7 [==============================] - 4s 623ms/step - loss: 0.7865 - accuracy: 0.7698 - val_loss: 0.7233 - val_accuracy: 0.7956
# Epoch 25/200
# 7/7 [==============================] - 4s 626ms/step - loss: 0.7435 - accuracy: 0.7771 - val_loss: 0.7047 - val_accuracy: 0.8250
# Epoch 26/200
# 7/7 [==============================] - 5s 645ms/step - loss: 0.7471 - accuracy: 0.7812 - val_loss: 0.6452 - val_accuracy: 0.8157
# Epoch 27/200
# 7/7 [==============================] - 4s 612ms/step - loss: 0.7205 - accuracy: 0.7822 - val_loss: 0.6431 - val_accuracy: 0.8267
# Epoch 28/200
# 7/7 [==============================] - 4s 632ms/step - loss: 0.7405 - accuracy: 0.7765 - val_loss: 0.6836 - val_accuracy: 0.8141
# Epoch 29/200
# 7/7 [==============================] - 4s 615ms/step - loss: 0.7166 - accuracy: 0.7874 - val_loss: 0.6471 - val_accuracy: 0.8283
# Epoch 30/200
# 7/7 [==============================] - 4s 642ms/step - loss: 0.7072 - accuracy: 0.7886 - val_loss: 0.6449 - val_accuracy: 0.8157
# Epoch 31/200
# 7/7 [==============================] - 4s 619ms/step - loss: 0.6553 - accuracy: 0.8027 - val_loss: 0.5840 - val_accuracy: 0.8417
# Epoch 32/200
# 7/7 [==============================] - 4s 619ms/step - loss: 0.7062 - accuracy: 0.7779 - val_loss: 0.6899 - val_accuracy: 0.8141
# Epoch 33/200
# 7/7 [==============================] - 5s 645ms/step - loss: 0.7183 - accuracy: 0.7819 - val_loss: 0.5928 - val_accuracy: 0.8400
# Epoch 34/200
# 7/7 [==============================] - 4s 610ms/step - loss: 0.6694 - accuracy: 0.7977 - val_loss: 0.6287 - val_accuracy: 0.8342
# Epoch 35/200
# 7/7 [==============================] - 5s 670ms/step - loss: 0.6646 - accuracy: 0.7932 - val_loss: 0.5878 - val_accuracy: 0.8350
# Epoch 36/200
# 7/7 [==============================] - 4s 639ms/step - loss: 0.6926 - accuracy: 0.7936 - val_loss: 0.6184 - val_accuracy: 0.8358
# Epoch 37/200
# 7/7 [==============================] - 4s 636ms/step - loss: 0.6503 - accuracy: 0.8070 - val_loss: 0.6078 - val_accuracy: 0.8400
# Epoch 38/200
# 7/7 [==============================] - 4s 637ms/step - loss: 0.6803 - accuracy: 0.7951 - val_loss: 0.5508 - val_accuracy: 0.8425
# Epoch 39/200
# 7/7 [==============================] - 4s 643ms/step - loss: 0.6714 - accuracy: 0.7960 - val_loss: 0.5469 - val_accuracy: 0.8483
# Epoch 40/200
# 7/7 [==============================] - 5s 650ms/step - loss: 0.6660 - accuracy: 0.7968 - val_loss: 0.6271 - val_accuracy: 0.8308
# Epoch 41/200
# 7/7 [==============================] - 4s 632ms/step - loss: 0.6497 - accuracy: 0.8014 - val_loss: 0.5630 - val_accuracy: 0.8533
# Epoch 42/200
# 7/7 [==============================] - 4s 626ms/step - loss: 0.6469 - accuracy: 0.7996 - val_loss: 0.5873 - val_accuracy: 0.8509
# Epoch 43/200
# 7/7 [==============================] - 5s 663ms/step - loss: 0.6283 - accuracy: 0.8039 - val_loss: 0.5385 - val_accuracy: 0.8600
# Epoch 44/200
# 7/7 [==============================] - 5s 647ms/step - loss: 0.6207 - accuracy: 0.8139 - val_loss: 0.5965 - val_accuracy: 0.8409
# Epoch 45/200
# 7/7 [==============================] - 4s 634ms/step - loss: 0.6002 - accuracy: 0.8171 - val_loss: 0.5190 - val_accuracy: 0.8483
# Epoch 46/200
# 7/7 [==============================] - 5s 652ms/step - loss: 0.6018 - accuracy: 0.8147 - val_loss: 0.6221 - val_accuracy: 0.8425
# Epoch 47/200
# 7/7 [==============================] - 5s 655ms/step - loss: 0.5745 - accuracy: 0.8276 - val_loss: 0.5563 - val_accuracy: 0.8667
# Epoch 48/200
# 7/7 [==============================] - 4s 625ms/step - loss: 0.5751 - accuracy: 0.8271 - val_loss: 0.5547 - val_accuracy: 0.8409
# Epoch 49/200
# 7/7 [==============================] - 4s 628ms/step - loss: 0.5772 - accuracy: 0.8212 - val_loss: 0.5321 - val_accuracy: 0.8600
# Epoch 50/200
# 7/7 [==============================] - 5s 645ms/step - loss: 0.5883 - accuracy: 0.8278 - val_loss: 0.6112 - val_accuracy: 0.8425
# Epoch 51/200
# 7/7 [==============================] - 5s 658ms/step - loss: 0.6099 - accuracy: 0.8125 - val_loss: 0.5426 - val_accuracy: 0.8467
# Epoch 52/200
# 7/7 [==============================] - 4s 640ms/step - loss: 0.5820 - accuracy: 0.8233 - val_loss: 0.5627 - val_accuracy: 0.8643
# Epoch 53/200
# 7/7 [==============================] - 5s 667ms/step - loss: 0.5737 - accuracy: 0.8266 - val_loss: 0.6340 - val_accuracy: 0.8533
# Epoch 54/200
# 7/7 [==============================] - 5s 643ms/step - loss: 0.5630 - accuracy: 0.8304 - val_loss: 0.5234 - val_accuracy: 0.8593
# Epoch 55/200
# 7/7 [==============================] - 4s 642ms/step - loss: 0.5699 - accuracy: 0.8331 - val_loss: 0.6080 - val_accuracy: 0.8450
# Epoch 56/200
# 7/7 [==============================] - 4s 602ms/step - loss: 0.5591 - accuracy: 0.8319 - val_loss: 0.5084 - val_accuracy: 0.8677
# Epoch 57/200
# 7/7 [==============================] - 4s 611ms/step - loss: 0.5481 - accuracy: 0.8383 - val_loss: 0.6077 - val_accuracy: 0.8550
# Epoch 58/200
# 7/7 [==============================] - 4s 590ms/step - loss: 0.5240 - accuracy: 0.8457 - val_loss: 0.4329 - val_accuracy: 0.8710
# Epoch 59/200
# 7/7 [==============================] - 4s 618ms/step - loss: 0.5395 - accuracy: 0.8393 - val_loss: 0.5799 - val_accuracy: 0.8367
# Epoch 60/200
# 7/7 [==============================] - 4s 617ms/step - loss: 0.5581 - accuracy: 0.8290 - val_loss: 0.5028 - val_accuracy: 0.8727
# Epoch 61/200
# 7/7 [==============================] - 4s 631ms/step - loss: 0.5603 - accuracy: 0.8331 - val_loss: 0.4855 - val_accuracy: 0.8583
# Epoch 62/200
# 7/7 [==============================] - 4s 594ms/step - loss: 0.5653 - accuracy: 0.8335 - val_loss: 0.5167 - val_accuracy: 0.8811
# Epoch 63/200
# 7/7 [==============================] - 4s 607ms/step - loss: 0.5475 - accuracy: 0.8319 - val_loss: 0.4655 - val_accuracy: 0.8683
# Epoch 64/200
# 7/7 [==============================] - 4s 623ms/step - loss: 0.5592 - accuracy: 0.8333 - val_loss: 0.5395 - val_accuracy: 0.8593
# Epoch 65/200
# 7/7 [==============================] - 4s 605ms/step - loss: 0.5228 - accuracy: 0.8405 - val_loss: 0.5267 - val_accuracy: 0.8550
# Epoch 66/200
# 7/7 [==============================] - 4s 603ms/step - loss: 0.5285 - accuracy: 0.8426 - val_loss: 0.5221 - val_accuracy: 0.8727
# Epoch 67/200
# 7/7 [==============================] - 4s 628ms/step - loss: 0.5115 - accuracy: 0.8428 - val_loss: 0.5183 - val_accuracy: 0.8633
# Epoch 68/200
# 7/7 [==============================] - 4s 590ms/step - loss: 0.5070 - accuracy: 0.8374 - val_loss: 0.5270 - val_accuracy: 0.8526
# Epoch 69/200
# 7/7 [==============================] - 4s 622ms/step - loss: 0.4832 - accuracy: 0.8543 - val_loss: 0.5353 - val_accuracy: 0.8533
# Epoch 70/200
# 7/7 [==============================] - 4s 633ms/step - loss: 0.4671 - accuracy: 0.8622 - val_loss: 0.4708 - val_accuracy: 0.8777
# Epoch 71/200
# 7/7 [==============================] - 4s 595ms/step - loss: 0.4611 - accuracy: 0.8617 - val_loss: 0.5490 - val_accuracy: 0.8600
# Epoch 72/200
# 7/7 [==============================] - 4s 590ms/step - loss: 0.4801 - accuracy: 0.8538 - val_loss: 0.4684 - val_accuracy: 0.8878
# Epoch 73/200
# 7/7 [==============================] - 4s 604ms/step - loss: 0.4956 - accuracy: 0.8502 - val_loss: 0.3977 - val_accuracy: 0.8833
# Epoch 74/200
# 7/7 [==============================] - 4s 625ms/step - loss: 0.5453 - accuracy: 0.8221 - val_loss: 0.5352 - val_accuracy: 0.8626
# Epoch 75/200
# 7/7 [==============================] - 4s 602ms/step - loss: 0.5770 - accuracy: 0.8309 - val_loss: 0.5281 - val_accuracy: 0.8300
# Epoch 76/200
# 7/7 [==============================] - 4s 595ms/step - loss: 0.5447 - accuracy: 0.8309 - val_loss: 0.4270 - val_accuracy: 0.8827
# Epoch 77/200
# 7/7 [==============================] - 4s 634ms/step - loss: 0.5405 - accuracy: 0.8412 - val_loss: 0.4709 - val_accuracy: 0.8817
# Epoch 78/200
# 7/7 [==============================] - 4s 631ms/step - loss: 0.5199 - accuracy: 0.8400 - val_loss: 0.5228 - val_accuracy: 0.8509
# Epoch 79/200
# 7/7 [==============================] - 4s 617ms/step - loss: 0.5033 - accuracy: 0.8462 - val_loss: 0.4732 - val_accuracy: 0.8683
# Epoch 80/200
# 7/7 [==============================] - 4s 615ms/step - loss: 0.4915 - accuracy: 0.8526 - val_loss: 0.4831 - val_accuracy: 0.8626
# Epoch 81/200
# 7/7 [==============================] - 4s 619ms/step - loss: 0.5006 - accuracy: 0.8510 - val_loss: 0.4880 - val_accuracy: 0.8633
# Epoch 82/200
# 7/7 [==============================] - 4s 631ms/step - loss: 0.4436 - accuracy: 0.8653 - val_loss: 0.5290 - val_accuracy: 0.8727
# Epoch 83/200
# 7/7 [==============================] - 4s 624ms/step - loss: 0.4780 - accuracy: 0.8529 - val_loss: 0.4568 - val_accuracy: 0.8750
# Epoch 84/200
# 7/7 [==============================] - 4s 610ms/step - loss: 0.4496 - accuracy: 0.8648 - val_loss: 0.4580 - val_accuracy: 0.8861
# Epoch 85/200
# 7/7 [==============================] - 4s 596ms/step - loss: 0.4674 - accuracy: 0.8584 - val_loss: 0.5334 - val_accuracy: 0.8667
# Epoch 86/200
# 7/7 [==============================] - 4s 600ms/step - loss: 0.4717 - accuracy: 0.8548 - val_loss: 0.4305 - val_accuracy: 0.8744
# Epoch 87/200
# 7/7 [==============================] - 4s 619ms/step - loss: 0.4563 - accuracy: 0.8608 - val_loss: 0.4442 - val_accuracy: 0.8850
# Epoch 88/200
# 7/7 [==============================] - 4s 588ms/step - loss: 0.4640 - accuracy: 0.8522 - val_loss: 0.5381 - val_accuracy: 0.8610
# Epoch 89/200
# 7/7 [==============================] - 4s 615ms/step - loss: 0.4541 - accuracy: 0.8624 - val_loss: 0.4449 - val_accuracy: 0.8800
# Epoch 90/200
# 7/7 [==============================] - 4s 621ms/step - loss: 0.4488 - accuracy: 0.8636 - val_loss: 0.4622 - val_accuracy: 0.8827
# Epoch 91/200
# 7/7 [==============================] - 4s 600ms/step - loss: 0.4313 - accuracy: 0.8694 - val_loss: 0.4516 - val_accuracy: 0.8833
# Epoch 92/200
# 7/7 [==============================] - 4s 609ms/step - loss: 0.4620 - accuracy: 0.8596 - val_loss: 0.4828 - val_accuracy: 0.8693
# Epoch 93/200
# 7/7 [==============================] - 4s 576ms/step - loss: 0.4592 - accuracy: 0.8634 - val_loss: 0.4824 - val_accuracy: 0.8683
# Epoch 94/200
# 7/7 [==============================] - 4s 641ms/step - loss: 0.4436 - accuracy: 0.8562 - val_loss: 0.4513 - val_accuracy: 0.8811
# Epoch 95/200
# 7/7 [==============================] - 4s 621ms/step - loss: 0.4518 - accuracy: 0.8651 - val_loss: 0.4305 - val_accuracy: 0.8750
# Epoch 96/200
# 7/7 [==============================] - 4s 603ms/step - loss: 0.4600 - accuracy: 0.8593 - val_loss: 0.5125 - val_accuracy: 0.8777
# Epoch 97/200
# 7/7 [==============================] - 4s 642ms/step - loss: 0.4418 - accuracy: 0.8669 - val_loss: 0.4261 - val_accuracy: 0.8883
# Epoch 98/200
# 7/7 [==============================] - 5s 654ms/step - loss: 0.4463 - accuracy: 0.8620 - val_loss: 0.4678 - val_accuracy: 0.8760
# Epoch 99/200
# 7/7 [==============================] - 4s 635ms/step - loss: 0.4296 - accuracy: 0.8677 - val_loss: 0.4732 - val_accuracy: 0.8683
# Epoch 100/200
# 7/7 [==============================] - 4s 643ms/step - loss: 0.4647 - accuracy: 0.8581 - val_loss: 0.4769 - val_accuracy: 0.8978
# Epoch 101/200
# 7/7 [==============================] - 5s 661ms/step - loss: 0.4257 - accuracy: 0.8706 - val_loss: 0.4501 - val_accuracy: 0.8783
# Epoch 102/200
# 7/7 [==============================] - 5s 645ms/step - loss: 0.4291 - accuracy: 0.8684 - val_loss: 0.4857 - val_accuracy: 0.8928
# Epoch 103/200
# 7/7 [==============================] - 4s 624ms/step - loss: 0.4192 - accuracy: 0.8715 - val_loss: 0.4018 - val_accuracy: 0.8950
# Epoch 104/200
# 7/7 [==============================] - 4s 598ms/step - loss: 0.4371 - accuracy: 0.8706 - val_loss: 0.5014 - val_accuracy: 0.8827
# Epoch 105/200
# 7/7 [==============================] - 4s 642ms/step - loss: 0.4258 - accuracy: 0.8679 - val_loss: 0.4913 - val_accuracy: 0.8883
# Epoch 106/200
# 7/7 [==============================] - 4s 622ms/step - loss: 0.4129 - accuracy: 0.8741 - val_loss: 0.4213 - val_accuracy: 0.8878
# Epoch 107/200
# 7/7 [==============================] - 4s 603ms/step - loss: 0.3894 - accuracy: 0.8794 - val_loss: 0.5327 - val_accuracy: 0.8683
# Epoch 108/200
# 7/7 [==============================] - 4s 598ms/step - loss: 0.4269 - accuracy: 0.8672 - val_loss: 0.3909 - val_accuracy: 0.9045
# Epoch 109/200
# 7/7 [==============================] - 4s 590ms/step - loss: 0.3829 - accuracy: 0.8796 - val_loss: 0.4504 - val_accuracy: 0.8867
# Epoch 110/200
# 7/7 [==============================] - 4s 618ms/step - loss: 0.4064 - accuracy: 0.8746 - val_loss: 0.4694 - val_accuracy: 0.8727
# Epoch 111/200
# 7/7 [==============================] - 4s 639ms/step - loss: 0.4123 - accuracy: 0.8763 - val_loss: 0.4075 - val_accuracy: 0.9017
# Epoch 112/200
# 7/7 [==============================] - 4s 598ms/step - loss: 0.3985 - accuracy: 0.8787 - val_loss: 0.4909 - val_accuracy: 0.8878
# Epoch 113/200
# 7/7 [==============================] - 4s 636ms/step - loss: 0.4215 - accuracy: 0.8714 - val_loss: 0.4599 - val_accuracy: 0.8767
# Epoch 114/200
# 7/7 [==============================] - 4s 611ms/step - loss: 0.3888 - accuracy: 0.8803 - val_loss: 0.4714 - val_accuracy: 0.8827
# Epoch 115/200
# 7/7 [==============================] - 4s 611ms/step - loss: 0.4002 - accuracy: 0.8813 - val_loss: 0.4345 - val_accuracy: 0.8850
# Epoch 116/200
# 7/7 [==============================] - 4s 636ms/step - loss: 0.3964 - accuracy: 0.8765 - val_loss: 0.5002 - val_accuracy: 0.8760
# Epoch 117/200
# 7/7 [==============================] - 4s 627ms/step - loss: 0.3962 - accuracy: 0.8758 - val_loss: 0.4186 - val_accuracy: 0.8967
# Epoch 118/200
# 7/7 [==============================] - 4s 619ms/step - loss: 0.3464 - accuracy: 0.8928 - val_loss: 0.5502 - val_accuracy: 0.8760
# Epoch 119/200
# 7/7 [==============================] - 4s 639ms/step - loss: 0.4119 - accuracy: 0.8780 - val_loss: 0.3815 - val_accuracy: 0.9033
# Epoch 120/200
# 7/7 [==============================] - 4s 613ms/step - loss: 0.3887 - accuracy: 0.8834 - val_loss: 0.5537 - val_accuracy: 0.8811
# Epoch 121/200
# 7/7 [==============================] - 4s 607ms/step - loss: 0.3857 - accuracy: 0.8798 - val_loss: 0.3764 - val_accuracy: 0.9067
# Epoch 122/200
# 7/7 [==============================] - 4s 607ms/step - loss: 0.3714 - accuracy: 0.8875 - val_loss: 0.5508 - val_accuracy: 0.8777
# Epoch 123/200
# 7/7 [==============================] - 4s 596ms/step - loss: 0.4067 - accuracy: 0.8744 - val_loss: 0.4741 - val_accuracy: 0.8683
# Epoch 124/200
# 7/7 [==============================] - 4s 618ms/step - loss: 0.3744 - accuracy: 0.8784 - val_loss: 0.4331 - val_accuracy: 0.8978
# Epoch 125/200
# 7/7 [==============================] - 4s 631ms/step - loss: 0.3842 - accuracy: 0.8823 - val_loss: 0.4960 - val_accuracy: 0.8883
# Epoch 126/200
# 7/7 [==============================] - 4s 594ms/step - loss: 0.3507 - accuracy: 0.8937 - val_loss: 0.4304 - val_accuracy: 0.8978
# Epoch 127/200
# 7/7 [==============================] - 4s 620ms/step - loss: 0.3895 - accuracy: 0.8806 - val_loss: 0.5594 - val_accuracy: 0.8617
# Epoch 128/200
# 7/7 [==============================] - 4s 614ms/step - loss: 0.3785 - accuracy: 0.8823 - val_loss: 0.4258 - val_accuracy: 0.8945
# Epoch 129/200
# 7/7 [==============================] - 4s 609ms/step - loss: 0.4013 - accuracy: 0.8845 - val_loss: 0.4085 - val_accuracy: 0.9050
# Epoch 130/200
# 7/7 [==============================] - 4s 617ms/step - loss: 0.3946 - accuracy: 0.8727 - val_loss: 0.5572 - val_accuracy: 0.8710
# Epoch 131/200
# 7/7 [==============================] - 5s 646ms/step - loss: 0.3988 - accuracy: 0.8827 - val_loss: 0.4893 - val_accuracy: 0.8817
# Epoch 132/200
# 7/7 [==============================] - 4s 642ms/step - loss: 0.3761 - accuracy: 0.8885 - val_loss: 0.4490 - val_accuracy: 0.8861
# Epoch 133/200
# 7/7 [==============================] - 4s 603ms/step - loss: 0.4012 - accuracy: 0.8758 - val_loss: 0.4467 - val_accuracy: 0.8850
# Epoch 134/200
# 7/7 [==============================] - 4s 608ms/step - loss: 0.3504 - accuracy: 0.8887 - val_loss: 0.4792 - val_accuracy: 0.8827
# Epoch 135/200
# 7/7 [==============================] - 4s 610ms/step - loss: 0.3695 - accuracy: 0.8940 - val_loss: 0.4103 - val_accuracy: 0.8950
# Epoch 136/200
# 7/7 [==============================] - 4s 619ms/step - loss: 0.3752 - accuracy: 0.8866 - val_loss: 0.4864 - val_accuracy: 0.8911
# Epoch 137/200
# 7/7 [==============================] - 4s 614ms/step - loss: 0.3668 - accuracy: 0.8869 - val_loss: 0.4411 - val_accuracy: 0.8967
# Epoch 138/200
# 7/7 [==============================] - 4s 607ms/step - loss: 0.3801 - accuracy: 0.8834 - val_loss: 0.4903 - val_accuracy: 0.8894
# Epoch 139/200
# 7/7 [==============================] - 4s 632ms/step - loss: 0.3738 - accuracy: 0.8856 - val_loss: 0.4537 - val_accuracy: 0.8900
# Epoch 140/200
# 7/7 [==============================] - 4s 604ms/step - loss: 0.3869 - accuracy: 0.8846 - val_loss: 0.4765 - val_accuracy: 0.8945
# Epoch 141/200
# 7/7 [==============================] - 4s 609ms/step - loss: 0.3648 - accuracy: 0.8854 - val_loss: 0.4541 - val_accuracy: 0.8933
# Epoch 142/200
# 7/7 [==============================] - 4s 638ms/step - loss: 0.3705 - accuracy: 0.8892 - val_loss: 0.4841 - val_accuracy: 0.8961
# Epoch 143/200
# 7/7 [==============================] - 4s 633ms/step - loss: 0.3722 - accuracy: 0.8858 - val_loss: 0.5185 - val_accuracy: 0.8733
# Epoch 144/200
# 7/7 [==============================] - 4s 618ms/step - loss: 0.3716 - accuracy: 0.8842 - val_loss: 0.3750 - val_accuracy: 0.9062
# Epoch 145/200
# 7/7 [==============================] - 4s 636ms/step - loss: 0.3664 - accuracy: 0.8905 - val_loss: 0.4238 - val_accuracy: 0.8950
# Epoch 146/200
# 7/7 [==============================] - 4s 594ms/step - loss: 0.3422 - accuracy: 0.8952 - val_loss: 0.4713 - val_accuracy: 0.8827
# Epoch 147/200
# 7/7 [==============================] - 4s 622ms/step - loss: 0.3474 - accuracy: 0.8932 - val_loss: 0.5059 - val_accuracy: 0.8950
# Epoch 148/200
# 7/7 [==============================] - 4s 636ms/step - loss: 0.3531 - accuracy: 0.8904 - val_loss: 0.4276 - val_accuracy: 0.8911
# Epoch 149/200
# 7/7 [==============================] - 4s 639ms/step - loss: 0.3369 - accuracy: 0.8992 - val_loss: 0.4618 - val_accuracy: 0.9033
# Epoch 150/200
# 7/7 [==============================] - 4s 592ms/step - loss: 0.3341 - accuracy: 0.8973 - val_loss: 0.4075 - val_accuracy: 0.8894
# Epoch 151/200
# 7/7 [==============================] - 5s 644ms/step - loss: 0.3390 - accuracy: 0.9009 - val_loss: 0.6550 - val_accuracy: 0.8750
# Epoch 152/200
# 7/7 [==============================] - 4s 639ms/step - loss: 0.3576 - accuracy: 0.8897 - val_loss: 0.3467 - val_accuracy: 0.8911
# Epoch 153/200
# 7/7 [==============================] - 4s 605ms/step - loss: 0.3581 - accuracy: 0.8938 - val_loss: 0.4966 - val_accuracy: 0.9000
# Epoch 154/200
# 7/7 [==============================] - 4s 623ms/step - loss: 0.3435 - accuracy: 0.8959 - val_loss: 0.4002 - val_accuracy: 0.8911
# Epoch 155/200
# 7/7 [==============================] - 4s 623ms/step - loss: 0.3308 - accuracy: 0.8975 - val_loss: 0.4983 - val_accuracy: 0.8750
# Epoch 156/200
# 7/7 [==============================] - 4s 620ms/step - loss: 0.3471 - accuracy: 0.8937 - val_loss: 0.3566 - val_accuracy: 0.9095
# Epoch 157/200
# 7/7 [==============================] - 4s 607ms/step - loss: 0.3893 - accuracy: 0.8866 - val_loss: 0.4396 - val_accuracy: 0.8950
# Epoch 158/200
# 7/7 [==============================] - 4s 591ms/step - loss: 0.3965 - accuracy: 0.8803 - val_loss: 0.4898 - val_accuracy: 0.8760
# Epoch 159/200
# 7/7 [==============================] - 4s 622ms/step - loss: 0.3748 - accuracy: 0.8849 - val_loss: 0.4494 - val_accuracy: 0.8867
# Epoch 160/200
# 7/7 [==============================] - 4s 616ms/step - loss: 0.3704 - accuracy: 0.8830 - val_loss: 0.5053 - val_accuracy: 0.8794
# Epoch 161/200
# 7/7 [==============================] - 4s 615ms/step - loss: 0.3655 - accuracy: 0.8860 - val_loss: 0.3815 - val_accuracy: 0.9067
# Epoch 162/200
# 7/7 [==============================] - 4s 621ms/step - loss: 0.3580 - accuracy: 0.8873 - val_loss: 0.4622 - val_accuracy: 0.8844
# Epoch 163/200
# 7/7 [==============================] - 4s 592ms/step - loss: 0.3439 - accuracy: 0.8980 - val_loss: 0.5336 - val_accuracy: 0.8883
# Epoch 164/200
# 7/7 [==============================] - 4s 582ms/step - loss: 0.3558 - accuracy: 0.8930 - val_loss: 0.3970 - val_accuracy: 0.8928
# Epoch 165/200
# 7/7 [==============================] - 4s 589ms/step - loss: 0.3434 - accuracy: 0.8930 - val_loss: 0.4725 - val_accuracy: 0.8900
# Epoch 166/200
# 7/7 [==============================] - 4s 631ms/step - loss: 0.3378 - accuracy: 0.9035 - val_loss: 0.4817 - val_accuracy: 0.8777
# Epoch 167/200
# 7/7 [==============================] - 4s 620ms/step - loss: 0.3294 - accuracy: 0.8925 - val_loss: 0.4646 - val_accuracy: 0.8767
# Epoch 168/200
# 7/7 [==============================] - 4s 626ms/step - loss: 0.3142 - accuracy: 0.9004 - val_loss: 0.4172 - val_accuracy: 0.8978
# Epoch 169/200
# 7/7 [==============================] - 4s 603ms/step - loss: 0.3352 - accuracy: 0.8995 - val_loss: 0.4812 - val_accuracy: 0.9000
# Epoch 170/200
# 7/7 [==============================] - 4s 591ms/step - loss: 0.3358 - accuracy: 0.9009 - val_loss: 0.4075 - val_accuracy: 0.8945
# Epoch 171/200
# 7/7 [==============================] - 4s 590ms/step - loss: 0.3537 - accuracy: 0.8940 - val_loss: 0.3993 - val_accuracy: 0.8983
# Epoch 172/200
# 7/7 [==============================] - 4s 595ms/step - loss: 0.3339 - accuracy: 0.8961 - val_loss: 0.5370 - val_accuracy: 0.8777
# Epoch 173/200
# 7/7 [==============================] - 4s 607ms/step - loss: 0.3331 - accuracy: 0.8961 - val_loss: 0.5100 - val_accuracy: 0.8983
# Epoch 174/200
# 7/7 [==============================] - 4s 617ms/step - loss: 0.3476 - accuracy: 0.8949 - val_loss: 0.3916 - val_accuracy: 0.8978
# Epoch 175/200
# 7/7 [==============================] - 4s 571ms/step - loss: 0.3512 - accuracy: 0.8880 - val_loss: 0.4943 - val_accuracy: 0.8867
# Epoch 176/200
# 7/7 [==============================] - 4s 607ms/step - loss: 0.3242 - accuracy: 0.9033 - val_loss: 0.4449 - val_accuracy: 0.8928
# Epoch 177/200
# 7/7 [==============================] - 4s 618ms/step - loss: 0.3337 - accuracy: 0.8952 - val_loss: 0.5054 - val_accuracy: 0.8800
# Epoch 178/200
# 7/7 [==============================] - 4s 641ms/step - loss: 0.3199 - accuracy: 0.9054 - val_loss: 0.3917 - val_accuracy: 0.8961
# Epoch 179/200
# 7/7 [==============================] - 4s 638ms/step - loss: 0.3135 - accuracy: 0.9026 - val_loss: 0.4933 - val_accuracy: 0.9050
# Epoch 180/200
# 7/7 [==============================] - 4s 616ms/step - loss: 0.3341 - accuracy: 0.9040 - val_loss: 0.4175 - val_accuracy: 0.8894
# Epoch 181/200
# 7/7 [==============================] - 4s 632ms/step - loss: 0.3250 - accuracy: 0.9018 - val_loss: 0.5365 - val_accuracy: 0.8683
# Epoch 182/200
# 7/7 [==============================] - 4s 596ms/step - loss: 0.3286 - accuracy: 0.8995 - val_loss: 0.3713 - val_accuracy: 0.9062
# Epoch 183/200
# 7/7 [==============================] - 4s 603ms/step - loss: 0.3246 - accuracy: 0.9016 - val_loss: 0.3332 - val_accuracy: 0.9167
# Epoch 184/200
# 7/7 [==============================] - 4s 625ms/step - loss: 0.3320 - accuracy: 0.8973 - val_loss: 0.5945 - val_accuracy: 0.8626
# Epoch 185/200
# 7/7 [==============================] - 4s 600ms/step - loss: 0.3971 - accuracy: 0.8814 - val_loss: 0.5145 - val_accuracy: 0.8783
# Epoch 186/200
# 7/7 [==============================] - 4s 596ms/step - loss: 0.4465 - accuracy: 0.8710 - val_loss: 0.4603 - val_accuracy: 0.8794
# Epoch 187/200
# 7/7 [==============================] - 4s 615ms/step - loss: 0.4386 - accuracy: 0.8722 - val_loss: 0.3743 - val_accuracy: 0.9000
# Epoch 188/200
# 7/7 [==============================] - 4s 603ms/step - loss: 0.3843 - accuracy: 0.8811 - val_loss: 0.5283 - val_accuracy: 0.8744
# Epoch 189/200
# 7/7 [==============================] - 4s 605ms/step - loss: 0.3591 - accuracy: 0.8906 - val_loss: 0.4953 - val_accuracy: 0.8767
# Epoch 190/200
# 7/7 [==============================] - 4s 609ms/step - loss: 0.3532 - accuracy: 0.8932 - val_loss: 0.5036 - val_accuracy: 0.8811
# Epoch 191/200
# 7/7 [==============================] - 4s 588ms/step - loss: 0.3615 - accuracy: 0.8870 - val_loss: 0.5352 - val_accuracy: 0.8600
# Epoch 192/200
# 7/7 [==============================] - 4s 614ms/step - loss: 0.3411 - accuracy: 0.8913 - val_loss: 0.4427 - val_accuracy: 0.8995
# Epoch 193/200
# 7/7 [==============================] - 4s 586ms/step - loss: 0.3286 - accuracy: 0.8957 - val_loss: 0.4739 - val_accuracy: 0.8917
# Epoch 194/200
# 7/7 [==============================] - 4s 598ms/step - loss: 0.3185 - accuracy: 0.9059 - val_loss: 0.5075 - val_accuracy: 0.8861
# Epoch 195/200
# 7/7 [==============================] - 4s 637ms/step - loss: 0.3362 - accuracy: 0.8975 - val_loss: 0.4596 - val_accuracy: 0.8967
# Epoch 196/200
# 7/7 [==============================] - 4s 613ms/step - loss: 0.3461 - accuracy: 0.8947 - val_loss: 0.4331 - val_accuracy: 0.8961
# Epoch 197/200
# 7/7 [==============================] - 4s 622ms/step - loss: 0.3454 - accuracy: 0.8937 - val_loss: 0.4168 - val_accuracy: 0.8900
# Epoch 198/200
# 7/7 [==============================] - 4s 577ms/step - loss: 0.3169 - accuracy: 0.9047 - val_loss: 0.4506 - val_accuracy: 0.9079
# Epoch 199/200
# 7/7 [==============================] - 4s 601ms/step - loss: 0.3186 - accuracy: 0.9026 - val_loss: 0.4136 - val_accuracy: 0.9083
# Epoch 200/200
# 7/7 [==============================] - 4s 603ms/step - loss: 0.3129 - accuracy: 0.9004 - val_loss: 0.4039 - val_accuracy: 0.8911

# %%
def convert_image(X):
    X_img=[]
    for image in X:
        # Load image
        img=cv2.imread(image)
        # Resize image
        img=cv2.resize(img,(28,28))
        # for the black and white image
        if img.shape==(28, 28):
            img=img.reshape([28,28,1])
            img=np.concatenate([img,img,img],axis=2)
        # cv2 load the image BGR sequence color (not RGB)
        X_img.append(img[...,::-1])
    return np.array(X_img)

# Load the images train
X_train_img = convert_image(data_train.img_paths)
Y_train = data_train['class']

# Load the images test
X_test_img = convert_image(data_test.img_paths)
Y_test = data_test['class']

# %%
prediction_train=lenet.predict_classes(X_train_img)
prediction_test=lenet.predict_classes(X_test_img)

# %%
dictionnaire=train_generator.class_indices
dictionnaire
# Out:
# {'autre': 0,
#  'chevreuil': 1,
#  'corneille': 2,
#  'faisan': 3,
#  'lapin': 4,
#  'oiseau': 5,
#  'pigeon': 6,
#  'tracteur': 7,
#  'voiture': 8}

# %%
dictionnaire_inv = {v: k for k, v in dictionnaire.items()}
dictionnaire_inv
# Out:
# {0: 'autre',
#  1: 'chevreuil',
#  2: 'corneille',
#  3: 'faisan',
#  4: 'lapin',
#  5: 'oiseau',
#  6: 'pigeon',
#  7: 'tracteur',
#  8: 'voiture'}

# %%
arr=range(0,9)
df=pd.DataFrame({"int_cat": arr})
df["str_cat"]="None"
for i in range(9):
    df["str_cat"].iloc[i]=dictionnaire_inv[df["int_cat"].iloc[i]]
df.to_csv("conversion_cat_generator.csv",index=False)

# %%
a=pd.read_csv("conversion_cat_generator.csv")
# Out:
#    int_cat    str_cat
# 0        0      autre
# 1        1  chevreuil
# 2        2  corneille
# 3        3     faisan
# 4        4      lapin
# 5        5     oiseau
# 6        6     pigeon
# 7        7   tracteur
# 8        8    voiture

# %%
Keys=[]
Values=[]

for i in range(len(prediction_train)):
    Keys.append(prediction_train[i])
    Values.append(dictionnaire_inv[prediction_train[i]])

# %%
print(metrics.classification_report(Y_train, Values))
# Out:
#               precision    recall  f1-score   support
#
#        autre       0.62      0.88      0.73      2380
#    chevreuil       0.00      0.00      0.00       109
#    corneille       0.42      0.02      0.04       835
#       faisan       0.04      0.00      0.01       268
#        lapin       0.00      0.00      0.00       141
#       oiseau       0.06      0.37      0.10       173
#       pigeon       0.01      0.00      0.00       662
#     tracteur       0.00      0.00      0.00       113
#      voiture       0.00      0.00      0.00       106
#
#     accuracy                           0.46      4787
#    macro avg       0.13      0.14      0.10      4787
# weighted avg       0.39      0.46      0.37      4787

# %%
#Avec argmax ....
intermediate_layer_model = Model(input=lenet.input, output=lenet.layers[-1].output)

X_train_features = intermediate_layer_model.predict(preprocess_input(X_train_img))
arg_predict=X_train_features.argmax(axis=1)

Values=[]

for i in range(len(arg_predict)) :
    Keys.append(arg_predict[i])
    Values.append(dictionnaire_inv[arg_predict[i]])

print(metrics.classification_report(Y_train, Values))
# Out:
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("co..., outputs=Tensor("de...)`
#               precision    recall  f1-score   support
#
#        autre       0.98      0.96      0.97      2380
#    chevreuil       0.98      0.98      0.98       109
#    corneille       0.91      0.96      0.93       835
#       faisan       0.96      0.96      0.96       268
#        lapin       0.84      0.90      0.87       141
#       oiseau       0.84      0.69      0.76       173
#       pigeon       0.93      0.97      0.95       662
#     tracteur       0.96      0.99      0.97       113
#      voiture       1.00      0.99      1.00       106
#
#     accuracy                           0.95      4787
#    macro avg       0.93      0.93      0.93      4787
# weighted avg       0.95      0.95      0.95      4787

# %%
#Avec argmax ....
intermediate_layer_model = Model(input=lenet.input, output=lenet.layers[-1].output)

X_test_features = intermediate_layer_model.predict(preprocess_input(X_test_img))
arg_predict=X_test_features.argmax(axis=1)

Values=[]

for i in range(len(arg_predict)) :
    Keys.append(arg_predict[i])
    Values.append(dictionnaire_inv[arg_predict[i]])

print(metrics.classification_report(Y_test, Values))
# Out:
#               precision    recall  f1-score   support
#
#        autre       0.95      0.96      0.95       595
#    chevreuil       0.89      0.89      0.89        27
#    corneille       0.85      0.89      0.87       209
#       faisan       0.84      0.78      0.81        67
#        lapin       0.62      0.66      0.64        35
#       oiseau       0.42      0.33      0.37        43
#       pigeon       0.91      0.89      0.90       166
#     tracteur       0.90      0.93      0.91        28
#      voiture       1.00      1.00      1.00        27
#
#     accuracy                           0.89      1197
#    macro avg       0.82      0.81      0.82      1197
# weighted avg       0.89      0.89      0.89      1197
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("co..., outputs=Tensor("de...)`
