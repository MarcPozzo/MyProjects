# %%
import numpy as np # Pour la manipulation de tableaux
from keras.applications import  resnet50
from sklearn import metrics 
import os

import pandas as pd # Pour manipuler des DataFrames pandas

import matplotlib.pyplot as plt # Pour l'affichage d'images
from matplotlib import cm # Pour importer de nouvelles cartes de couleur
# %matplotlib inline

from keras.models import Sequential # Pour construire un réseau de neurones
from keras.layers import Dense, Conv2D # Pour instancier une couche dense
from keras.utils import np_utils

from keras.models import Sequential
from keras.layers import Dense, Activation,GlobalAveragePooling2D, MaxPooling2D
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.models import Model
import cv2
import keras
from numpy.random import seed
import tensorflow

from keras.preprocessing.image import ImageDataGenerator
import itertools # Pour créer des iterateurs

from sklearn import linear_model, preprocessing 



# %matplotlib inline
import numpy as np

import matplotlib.pyplot as plt
import time, cv2
import seaborn as sns

import pandas as pd
from sklearn.model_selection import train_test_split

from keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.models import Model, Sequential
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras import backend as K
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.applications.vgg16 import preprocess_input

# %%
#Paramètres
base_img_paths="/mnt/BigFast/VegaFastExtension/Rpackages/c3po_all/c3po/Images_aquises/"
generateur_path='/mnt/VegaSlowDataDisk/Backups/VegaFastExtension/Rpackages/c3po_all/c3po/Images_aquises/generateur_bigger.csv'
#generateur_path='/mnt/VegaSlowDataDisk/c3po/Chaine_de_traitement/Train_imagettes_annotées/type_oiseau/Materiel/generateur.csv'
test_size=0.1
epochs=200
batch_size = 600
zoom_range = 1.25
horizontal_flip = True
Minimum_Number_Class=100
dropout_rate=0.5
#steps_per_epoch=len(data_train)//batch_size
steps_per_epoch=1
#validation_steps=len(data_test)//batch_size
validation_steps=1

# %%
df=pd.read_csv(generateur_path)
df.drop('labels',inplace=True,axis=1)
for c in df:
    print(''+c+':',len(df[c].unique()))
# Out:
# class: 13
# img_paths: 6220

# %%
All_Unique=df["class"].unique()
Utilisable=[]
for i in df["class"].unique():
    if df["class"][df["class"]==i].count()>Minimum_Number_Class:
        Utilisable.append(i)

Non_Utilisable=set(All_Unique)-set(Utilisable)

for i in Non_Utilisable:
    df=df[df["class"]!=i]
df=df[df["class"]!="oiseau"]  

data_train.iloc[0][1]
# Out:
# 'mnt/BigFast/VegaFastExtension/Rpackages/c3po_all/c3po/Images_aquises/Rec_images_bigger/image_2019-04-19_10-23-47_tracteur_3501.JPG'

# %%
for i in range(len(df["class"])):
    image_name=df["img_paths"].iloc[i]
    df["img_paths"].iloc[i]=os.path.join(base_img_paths,image_name)

# %%
seed(1)
tensorflow.random.set_seed(2)

data_train,data_test= train_test_split(df,stratify=df["class"], test_size=test_size,random_state=42)
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        rotation_range = 10,
        zoom_range = zoom_range,
        horizontal_flip = horizontal_flip
        )

test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)




train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)


test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)
# Out:
# Found 5369 validated image filenames belonging to 6 classes.
# Found 597 validated image filenames belonging to 6 classes.

# %%
lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = dropout_rate)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 6,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation




history=lenet.fit_generator( train_generator,
                           steps_per_epoch=len(data_train)//batch_size,
                           epochs=epochs,
                           workers=-1,
                           validation_data=test_generator,
                           validation_steps=len(data_test)//batch_size)
                          


plt.figure(figsize=(16,12))

plt.plot(history.history['accuracy'],label="train");
plt.plot(history.history['val_accuracy'],label="test");
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title("Accuracy en fonction du nombre d'epoch");
plt.legend();
#lenet.save("drop_out.50")
# Out:
# Epoch 1/200
# 8/8 [==============================] - 12s 2s/step - loss: 9.0428 - accuracy: 0.3371 - val_loss: 2.0752 - val_accuracy: 0.5913
# Epoch 2/200
# 8/8 [==============================] - 9s 1s/step - loss: 2.1338 - accuracy: 0.3997 - val_loss: 1.4816 - val_accuracy: 0.5360
# Epoch 3/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.5515 - accuracy: 0.4718 - val_loss: 1.3574 - val_accuracy: 0.5360
# Epoch 4/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.4374 - accuracy: 0.5290 - val_loss: 1.3439 - val_accuracy: 0.5494
# Epoch 5/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.3675 - accuracy: 0.5546 - val_loss: 1.2825 - val_accuracy: 0.5611
# Epoch 6/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.3165 - accuracy: 0.5704 - val_loss: 1.2300 - val_accuracy: 0.5863
# Epoch 7/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.2858 - accuracy: 0.5620 - val_loss: 1.1695 - val_accuracy: 0.6231
# Epoch 8/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.2433 - accuracy: 0.5792 - val_loss: 1.1448 - val_accuracy: 0.6097
# Epoch 9/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.2233 - accuracy: 0.5838 - val_loss: 1.1248 - val_accuracy: 0.6231
# Epoch 10/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.2022 - accuracy: 0.5915 - val_loss: 1.0819 - val_accuracy: 0.6348
# Epoch 11/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.1660 - accuracy: 0.5987 - val_loss: 1.0590 - val_accuracy: 0.6583
# Epoch 12/200
# 8/8 [==============================] - 8s 1s/step - loss: 1.1575 - accuracy: 0.6054 - val_loss: 1.0243 - val_accuracy: 0.6817
# Epoch 13/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.1196 - accuracy: 0.6257 - val_loss: 0.9798 - val_accuracy: 0.6650
# Epoch 14/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.1494 - accuracy: 0.6238 - val_loss: 1.0076 - val_accuracy: 0.7119
# Epoch 15/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.1138 - accuracy: 0.6207 - val_loss: 0.9555 - val_accuracy: 0.7119
# Epoch 16/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.0989 - accuracy: 0.6414 - val_loss: 0.9170 - val_accuracy: 0.7186
# Epoch 17/200
# 8/8 [==============================] - 8s 1s/step - loss: 1.0647 - accuracy: 0.6536 - val_loss: 0.8997 - val_accuracy: 0.7186
# Epoch 18/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.0725 - accuracy: 0.6477 - val_loss: 0.9078 - val_accuracy: 0.7186
# Epoch 19/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.0471 - accuracy: 0.6513 - val_loss: 0.8918 - val_accuracy: 0.7203
# Epoch 20/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.0636 - accuracy: 0.6626 - val_loss: 0.8311 - val_accuracy: 0.7353
# Epoch 21/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.0639 - accuracy: 0.6590 - val_loss: 0.8352 - val_accuracy: 0.7353
# Epoch 22/200
# 8/8 [==============================] - 9s 1s/step - loss: 1.0238 - accuracy: 0.6637 - val_loss: 0.8283 - val_accuracy: 0.7370
# Epoch 23/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.9861 - accuracy: 0.6735 - val_loss: 0.8488 - val_accuracy: 0.7253
# Epoch 24/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.9988 - accuracy: 0.6729 - val_loss: 0.8301 - val_accuracy: 0.7320
# Epoch 25/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.9990 - accuracy: 0.6779 - val_loss: 0.7954 - val_accuracy: 0.7437
# Epoch 26/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.9667 - accuracy: 0.6884 - val_loss: 0.7503 - val_accuracy: 0.7454
# Epoch 27/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.9556 - accuracy: 0.6886 - val_loss: 0.7905 - val_accuracy: 0.7504
# Epoch 28/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.9442 - accuracy: 0.6919 - val_loss: 0.7548 - val_accuracy: 0.7538
# Epoch 29/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.9347 - accuracy: 0.7006 - val_loss: 0.7507 - val_accuracy: 0.7588
# Epoch 30/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.9147 - accuracy: 0.7052 - val_loss: 0.7338 - val_accuracy: 0.7538
# Epoch 31/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8987 - accuracy: 0.7077 - val_loss: 0.7151 - val_accuracy: 0.7504
# Epoch 32/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.9508 - accuracy: 0.6997 - val_loss: 0.6719 - val_accuracy: 0.7772
# Epoch 33/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.9072 - accuracy: 0.6939 - val_loss: 0.7089 - val_accuracy: 0.7454
# Epoch 34/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8758 - accuracy: 0.7196 - val_loss: 0.6469 - val_accuracy: 0.7806
# Epoch 35/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8719 - accuracy: 0.7165 - val_loss: 0.6603 - val_accuracy: 0.7822
# Epoch 36/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8704 - accuracy: 0.7178 - val_loss: 0.6262 - val_accuracy: 0.7839
# Epoch 37/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.8707 - accuracy: 0.7088 - val_loss: 0.6431 - val_accuracy: 0.7889
# Epoch 38/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8709 - accuracy: 0.7167 - val_loss: 0.6510 - val_accuracy: 0.7789
# Epoch 39/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8528 - accuracy: 0.7308 - val_loss: 0.6053 - val_accuracy: 0.7772
# Epoch 40/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8534 - accuracy: 0.7205 - val_loss: 0.6635 - val_accuracy: 0.7940
# Epoch 41/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8261 - accuracy: 0.7299 - val_loss: 0.6244 - val_accuracy: 0.7688
# Epoch 42/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8331 - accuracy: 0.7289 - val_loss: 0.6136 - val_accuracy: 0.8023
# Epoch 43/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8575 - accuracy: 0.7247 - val_loss: 0.6216 - val_accuracy: 0.7990
# Epoch 44/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8399 - accuracy: 0.7293 - val_loss: 0.6006 - val_accuracy: 0.7973
# Epoch 45/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8316 - accuracy: 0.7333 - val_loss: 0.6313 - val_accuracy: 0.7990
# Epoch 46/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8131 - accuracy: 0.7421 - val_loss: 0.5975 - val_accuracy: 0.8174
# Epoch 47/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.8022 - accuracy: 0.7442 - val_loss: 0.5922 - val_accuracy: 0.7923
# Epoch 48/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8357 - accuracy: 0.7287 - val_loss: 0.6187 - val_accuracy: 0.7990
# Epoch 49/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8071 - accuracy: 0.7341 - val_loss: 0.5806 - val_accuracy: 0.8023
# Epoch 50/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.8214 - accuracy: 0.7398 - val_loss: 0.6345 - val_accuracy: 0.7806
# Epoch 51/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8045 - accuracy: 0.7410 - val_loss: 0.5767 - val_accuracy: 0.8040
# Epoch 52/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.8141 - accuracy: 0.7324 - val_loss: 0.6015 - val_accuracy: 0.7789
# Epoch 53/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.8390 - accuracy: 0.7310 - val_loss: 0.5978 - val_accuracy: 0.7973
# Epoch 54/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7985 - accuracy: 0.7410 - val_loss: 0.5697 - val_accuracy: 0.8040
# Epoch 55/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7779 - accuracy: 0.7498 - val_loss: 0.5616 - val_accuracy: 0.7990
# Epoch 56/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.7780 - accuracy: 0.7442 - val_loss: 0.5732 - val_accuracy: 0.8057
# Epoch 57/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7762 - accuracy: 0.7519 - val_loss: 0.5649 - val_accuracy: 0.8040
# Epoch 58/200
# 8/8 [==============================] - 8s 996ms/step - loss: 0.7883 - accuracy: 0.7488 - val_loss: 0.5440 - val_accuracy: 0.8157
# Epoch 59/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7553 - accuracy: 0.7568 - val_loss: 0.5752 - val_accuracy: 0.8107
# Epoch 60/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7750 - accuracy: 0.7473 - val_loss: 0.5618 - val_accuracy: 0.8057
# Epoch 61/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7646 - accuracy: 0.7521 - val_loss: 0.5669 - val_accuracy: 0.8208
# Epoch 62/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.7472 - accuracy: 0.7521 - val_loss: 0.5264 - val_accuracy: 0.8208
# Epoch 63/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.7577 - accuracy: 0.7528 - val_loss: 0.5232 - val_accuracy: 0.8241
# Epoch 64/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7396 - accuracy: 0.7548 - val_loss: 0.5469 - val_accuracy: 0.8141
# Epoch 65/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7543 - accuracy: 0.7513 - val_loss: 0.5488 - val_accuracy: 0.7956
# Epoch 66/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7714 - accuracy: 0.7490 - val_loss: 0.5479 - val_accuracy: 0.8174
# Epoch 67/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7361 - accuracy: 0.7612 - val_loss: 0.5371 - val_accuracy: 0.8208
# Epoch 68/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.7633 - accuracy: 0.7547 - val_loss: 0.5360 - val_accuracy: 0.8275
# Epoch 69/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.7194 - accuracy: 0.7631 - val_loss: 0.5168 - val_accuracy: 0.8308
# Epoch 70/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7142 - accuracy: 0.7704 - val_loss: 0.5236 - val_accuracy: 0.8275
# Epoch 71/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7279 - accuracy: 0.7662 - val_loss: 0.5155 - val_accuracy: 0.8241
# Epoch 72/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7380 - accuracy: 0.7551 - val_loss: 0.5710 - val_accuracy: 0.8107
# Epoch 73/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7525 - accuracy: 0.7527 - val_loss: 0.5774 - val_accuracy: 0.7839
# Epoch 74/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.7641 - accuracy: 0.7465 - val_loss: 0.5364 - val_accuracy: 0.8208
# Epoch 75/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7404 - accuracy: 0.7637 - val_loss: 0.5224 - val_accuracy: 0.8342
# Epoch 76/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7076 - accuracy: 0.7714 - val_loss: 0.4990 - val_accuracy: 0.8308
# Epoch 77/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.7082 - accuracy: 0.7752 - val_loss: 0.5223 - val_accuracy: 0.8275
# Epoch 78/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7152 - accuracy: 0.7721 - val_loss: 0.5115 - val_accuracy: 0.8275
# Epoch 79/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6986 - accuracy: 0.7664 - val_loss: 0.5211 - val_accuracy: 0.8275
# Epoch 80/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7152 - accuracy: 0.7639 - val_loss: 0.5024 - val_accuracy: 0.8241
# Epoch 81/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6982 - accuracy: 0.7735 - val_loss: 0.5014 - val_accuracy: 0.8291
# Epoch 82/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7153 - accuracy: 0.7625 - val_loss: 0.5036 - val_accuracy: 0.8258
# Epoch 83/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7329 - accuracy: 0.7631 - val_loss: 0.5802 - val_accuracy: 0.8057
# Epoch 84/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7112 - accuracy: 0.7683 - val_loss: 0.4784 - val_accuracy: 0.8241
# Epoch 85/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7071 - accuracy: 0.7696 - val_loss: 0.5237 - val_accuracy: 0.8258
# Epoch 86/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6912 - accuracy: 0.7698 - val_loss: 0.4775 - val_accuracy: 0.8442
# Epoch 87/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7346 - accuracy: 0.7643 - val_loss: 0.5089 - val_accuracy: 0.8174
# Epoch 88/200
# 8/8 [==============================] - 10s 1s/step - loss: 0.6774 - accuracy: 0.7723 - val_loss: 0.5012 - val_accuracy: 0.8241
# Epoch 89/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6942 - accuracy: 0.7763 - val_loss: 0.4912 - val_accuracy: 0.8275
# Epoch 90/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.6882 - accuracy: 0.7777 - val_loss: 0.4833 - val_accuracy: 0.8375
# Epoch 91/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7068 - accuracy: 0.7656 - val_loss: 0.4686 - val_accuracy: 0.8392
# Epoch 92/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6725 - accuracy: 0.7786 - val_loss: 0.5055 - val_accuracy: 0.8090
# Epoch 93/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7030 - accuracy: 0.7727 - val_loss: 0.4701 - val_accuracy: 0.8325
# Epoch 94/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6756 - accuracy: 0.7786 - val_loss: 0.4662 - val_accuracy: 0.8375
# Epoch 95/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6787 - accuracy: 0.7813 - val_loss: 0.4664 - val_accuracy: 0.8325
# Epoch 96/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6513 - accuracy: 0.7851 - val_loss: 0.4608 - val_accuracy: 0.8325
# Epoch 97/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6690 - accuracy: 0.7853 - val_loss: 0.4798 - val_accuracy: 0.8342
# Epoch 98/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6533 - accuracy: 0.7907 - val_loss: 0.4724 - val_accuracy: 0.8425
# Epoch 99/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6526 - accuracy: 0.7905 - val_loss: 0.4458 - val_accuracy: 0.8442
# Epoch 100/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.6910 - accuracy: 0.7771 - val_loss: 0.4702 - val_accuracy: 0.8325
# Epoch 101/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6859 - accuracy: 0.7777 - val_loss: 0.4955 - val_accuracy: 0.8174
# Epoch 102/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6800 - accuracy: 0.7872 - val_loss: 0.4564 - val_accuracy: 0.8409
# Epoch 103/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6764 - accuracy: 0.7840 - val_loss: 0.4616 - val_accuracy: 0.8409
# Epoch 104/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6520 - accuracy: 0.7909 - val_loss: 0.4438 - val_accuracy: 0.8492
# Epoch 105/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.6786 - accuracy: 0.7800 - val_loss: 0.4926 - val_accuracy: 0.8308
# Epoch 106/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6537 - accuracy: 0.7880 - val_loss: 0.4940 - val_accuracy: 0.8174
# Epoch 107/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6700 - accuracy: 0.7840 - val_loss: 0.5218 - val_accuracy: 0.8174
# Epoch 108/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7096 - accuracy: 0.7668 - val_loss: 0.4784 - val_accuracy: 0.8275
# Epoch 109/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6820 - accuracy: 0.7798 - val_loss: 0.5314 - val_accuracy: 0.8107
# Epoch 110/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.6531 - accuracy: 0.7842 - val_loss: 0.4840 - val_accuracy: 0.8392
# Epoch 111/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6232 - accuracy: 0.7968 - val_loss: 0.4600 - val_accuracy: 0.8392
# Epoch 112/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.6601 - accuracy: 0.7880 - val_loss: 0.4810 - val_accuracy: 0.8325
# Epoch 113/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6328 - accuracy: 0.7943 - val_loss: 0.4644 - val_accuracy: 0.8291
# Epoch 114/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.6635 - accuracy: 0.7891 - val_loss: 0.4870 - val_accuracy: 0.8291
# Epoch 115/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6358 - accuracy: 0.7962 - val_loss: 0.4690 - val_accuracy: 0.8375
# Epoch 116/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6764 - accuracy: 0.7782 - val_loss: 0.4515 - val_accuracy: 0.8442
# Epoch 117/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6710 - accuracy: 0.7861 - val_loss: 0.4843 - val_accuracy: 0.8325
# Epoch 118/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.6526 - accuracy: 0.7906 - val_loss: 0.4607 - val_accuracy: 0.8425
# Epoch 119/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.6455 - accuracy: 0.7874 - val_loss: 0.4747 - val_accuracy: 0.8258
# Epoch 120/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.6653 - accuracy: 0.7914 - val_loss: 0.4816 - val_accuracy: 0.8224
# Epoch 121/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6430 - accuracy: 0.7964 - val_loss: 0.4545 - val_accuracy: 0.8409
# Epoch 122/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6695 - accuracy: 0.7784 - val_loss: 0.4571 - val_accuracy: 0.8492
# Epoch 123/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6726 - accuracy: 0.7863 - val_loss: 0.4764 - val_accuracy: 0.8258
# Epoch 124/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.7357 - accuracy: 0.7662 - val_loss: 0.4766 - val_accuracy: 0.8308
# Epoch 125/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6453 - accuracy: 0.7912 - val_loss: 0.5057 - val_accuracy: 0.8107
# Epoch 126/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6745 - accuracy: 0.7842 - val_loss: 0.4772 - val_accuracy: 0.8342
# Epoch 127/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6570 - accuracy: 0.7856 - val_loss: 0.4839 - val_accuracy: 0.8191
# Epoch 128/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.6353 - accuracy: 0.7981 - val_loss: 0.4560 - val_accuracy: 0.8342
# Epoch 129/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6362 - accuracy: 0.7930 - val_loss: 0.4698 - val_accuracy: 0.8409
# Epoch 130/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6130 - accuracy: 0.8023 - val_loss: 0.4399 - val_accuracy: 0.8492
# Epoch 131/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6405 - accuracy: 0.7956 - val_loss: 0.4456 - val_accuracy: 0.8492
# Epoch 132/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6044 - accuracy: 0.7985 - val_loss: 0.4409 - val_accuracy: 0.8425
# Epoch 133/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6401 - accuracy: 0.7951 - val_loss: 0.4557 - val_accuracy: 0.8459
# Epoch 134/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6465 - accuracy: 0.7958 - val_loss: 0.4330 - val_accuracy: 0.8509
# Epoch 135/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6394 - accuracy: 0.7903 - val_loss: 0.4447 - val_accuracy: 0.8392
# Epoch 136/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.6206 - accuracy: 0.8017 - val_loss: 0.4545 - val_accuracy: 0.8224
# Epoch 137/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6449 - accuracy: 0.7987 - val_loss: 0.4772 - val_accuracy: 0.8224
# Epoch 138/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6270 - accuracy: 0.7972 - val_loss: 0.4334 - val_accuracy: 0.8626
# Epoch 139/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6088 - accuracy: 0.8018 - val_loss: 0.4410 - val_accuracy: 0.8526
# Epoch 140/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6060 - accuracy: 0.8081 - val_loss: 0.4528 - val_accuracy: 0.8425
# Epoch 141/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6173 - accuracy: 0.7995 - val_loss: 0.4484 - val_accuracy: 0.8543
# Epoch 142/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6248 - accuracy: 0.8012 - val_loss: 0.4350 - val_accuracy: 0.8543
# Epoch 143/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6136 - accuracy: 0.8065 - val_loss: 0.4456 - val_accuracy: 0.8677
# Epoch 144/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6093 - accuracy: 0.8048 - val_loss: 0.4325 - val_accuracy: 0.8425
# Epoch 145/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6205 - accuracy: 0.8092 - val_loss: 0.4120 - val_accuracy: 0.8710
# Epoch 146/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5928 - accuracy: 0.8048 - val_loss: 0.4322 - val_accuracy: 0.8593
# Epoch 147/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5783 - accuracy: 0.8121 - val_loss: 0.4276 - val_accuracy: 0.8425
# Epoch 148/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.6305 - accuracy: 0.7987 - val_loss: 0.4132 - val_accuracy: 0.8660
# Epoch 149/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6014 - accuracy: 0.8073 - val_loss: 0.4004 - val_accuracy: 0.8727
# Epoch 150/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6094 - accuracy: 0.8111 - val_loss: 0.4369 - val_accuracy: 0.8492
# Epoch 151/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6269 - accuracy: 0.7956 - val_loss: 0.4178 - val_accuracy: 0.8660
# Epoch 152/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6128 - accuracy: 0.8004 - val_loss: 0.4049 - val_accuracy: 0.8660
# Epoch 153/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5935 - accuracy: 0.8113 - val_loss: 0.4241 - val_accuracy: 0.8576
# Epoch 154/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5974 - accuracy: 0.8096 - val_loss: 0.4052 - val_accuracy: 0.8710
# Epoch 155/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5976 - accuracy: 0.8048 - val_loss: 0.4136 - val_accuracy: 0.8693
# Epoch 156/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5827 - accuracy: 0.8180 - val_loss: 0.3932 - val_accuracy: 0.8760
# Epoch 157/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6064 - accuracy: 0.8077 - val_loss: 0.4008 - val_accuracy: 0.8710
# Epoch 158/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5825 - accuracy: 0.8111 - val_loss: 0.4217 - val_accuracy: 0.8559
# Epoch 159/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5971 - accuracy: 0.8102 - val_loss: 0.4169 - val_accuracy: 0.8492
# Epoch 160/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5768 - accuracy: 0.8132 - val_loss: 0.3948 - val_accuracy: 0.8626
# Epoch 161/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5837 - accuracy: 0.8121 - val_loss: 0.3866 - val_accuracy: 0.8777
# Epoch 162/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5951 - accuracy: 0.8142 - val_loss: 0.4105 - val_accuracy: 0.8626
# Epoch 163/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5753 - accuracy: 0.8181 - val_loss: 0.3806 - val_accuracy: 0.8693
# Epoch 164/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5626 - accuracy: 0.8186 - val_loss: 0.3767 - val_accuracy: 0.8710
# Epoch 165/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5943 - accuracy: 0.8050 - val_loss: 0.3902 - val_accuracy: 0.8710
# Epoch 166/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5777 - accuracy: 0.8144 - val_loss: 0.4168 - val_accuracy: 0.8509
# Epoch 167/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5764 - accuracy: 0.8205 - val_loss: 0.4196 - val_accuracy: 0.8593
# Epoch 168/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5889 - accuracy: 0.8136 - val_loss: 0.4059 - val_accuracy: 0.8626
# Epoch 169/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5559 - accuracy: 0.8213 - val_loss: 0.3817 - val_accuracy: 0.8693
# Epoch 170/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5932 - accuracy: 0.8134 - val_loss: 0.3871 - val_accuracy: 0.8727
# Epoch 171/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5916 - accuracy: 0.8075 - val_loss: 0.4319 - val_accuracy: 0.8459
# Epoch 172/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.6327 - accuracy: 0.8042 - val_loss: 0.4329 - val_accuracy: 0.8425
# Epoch 173/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.6279 - accuracy: 0.7947 - val_loss: 0.4254 - val_accuracy: 0.8492
# Epoch 174/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5710 - accuracy: 0.8180 - val_loss: 0.4251 - val_accuracy: 0.8593
# Epoch 175/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5698 - accuracy: 0.8172 - val_loss: 0.3942 - val_accuracy: 0.8727
# Epoch 176/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5878 - accuracy: 0.8146 - val_loss: 0.3787 - val_accuracy: 0.8643
# Epoch 177/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5742 - accuracy: 0.8161 - val_loss: 0.3941 - val_accuracy: 0.8794
# Epoch 178/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5572 - accuracy: 0.8180 - val_loss: 0.3783 - val_accuracy: 0.8744
# Epoch 179/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5735 - accuracy: 0.8100 - val_loss: 0.4013 - val_accuracy: 0.8626
# Epoch 180/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5702 - accuracy: 0.8201 - val_loss: 0.3849 - val_accuracy: 0.8660
# Epoch 181/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5675 - accuracy: 0.8167 - val_loss: 0.3790 - val_accuracy: 0.8576
# Epoch 182/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5631 - accuracy: 0.8209 - val_loss: 0.3873 - val_accuracy: 0.8827
# Epoch 183/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5428 - accuracy: 0.8268 - val_loss: 0.3899 - val_accuracy: 0.8626
# Epoch 184/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5605 - accuracy: 0.8211 - val_loss: 0.4029 - val_accuracy: 0.8476
# Epoch 185/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5579 - accuracy: 0.8192 - val_loss: 0.3644 - val_accuracy: 0.8744
# Epoch 186/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5387 - accuracy: 0.8278 - val_loss: 0.4086 - val_accuracy: 0.8610
# Epoch 187/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5910 - accuracy: 0.8079 - val_loss: 0.4163 - val_accuracy: 0.8593
# Epoch 188/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5889 - accuracy: 0.8117 - val_loss: 0.4063 - val_accuracy: 0.8610
# Epoch 189/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5612 - accuracy: 0.8241 - val_loss: 0.3947 - val_accuracy: 0.8543
# Epoch 190/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5386 - accuracy: 0.8271 - val_loss: 0.3725 - val_accuracy: 0.8559
# Epoch 191/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5677 - accuracy: 0.8184 - val_loss: 0.3939 - val_accuracy: 0.8710
# Epoch 192/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5610 - accuracy: 0.8209 - val_loss: 0.3861 - val_accuracy: 0.8593
# Epoch 193/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5720 - accuracy: 0.8172 - val_loss: 0.4034 - val_accuracy: 0.8509
# Epoch 194/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5444 - accuracy: 0.8281 - val_loss: 0.3850 - val_accuracy: 0.8626
# Epoch 195/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5525 - accuracy: 0.8241 - val_loss: 0.3782 - val_accuracy: 0.8610
# Epoch 196/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5525 - accuracy: 0.8266 - val_loss: 0.3902 - val_accuracy: 0.8660
# Epoch 197/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5441 - accuracy: 0.8268 - val_loss: 0.3762 - val_accuracy: 0.8794
# Epoch 198/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5393 - accuracy: 0.8278 - val_loss: 0.3811 - val_accuracy: 0.8710
# Epoch 199/200
# 8/8 [==============================] - 8s 1s/step - loss: 0.5613 - accuracy: 0.8202 - val_loss: 0.3611 - val_accuracy: 0.8744
# Epoch 200/200
# 8/8 [==============================] - 9s 1s/step - loss: 0.5535 - accuracy: 0.8239 - val_loss: 0.3830 - val_accuracy: 0.8559

# %%
tab_1=pd.read_csv("/mnt/BigFast/VegaFastExtension/Rpackages/c3po_all/c3po/Images_aquises/generateur_bigger.csv")
tab_2=pd.read_csv("/mnt/BigFast/VegaFastExtension/Rpackages/c3po_all/c3po/Images_aquises/imagettes_bigger.csv")

# %%
import pandas as pd

# %%
tab_1.shape
# Out:
# (6220, 3)

# %%
tab_2.shape
# Out:
# (6220, 11)
