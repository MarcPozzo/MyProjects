# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns

# %%
#Le BlockSize est fixé à 17 car les imagettes ont des tailles intéressantes, cepedant un peu moins d'imagettes sont générées que si on avait un bS plus grand.
#On essaie d'augmnter le blur pour voir s'il y un impact sur le nombre d'images générées

# %% [markdown]
# ## Block Size 15

# %% [markdown]
# ## Blur Fact 11

# %%
BS=11

path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BF"+str(BS)+"/"

with open(path_save+"surface_carre_gen_tous_fichiers_BF"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BF"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print("Nombre d'élements",len(flat_im_gen))
print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# Nombre d'élements 1996
# la médiane est 1.125
# la moyenne est 1.3453178868721596

# %% [markdown]
# ## BF 13

# %%
BS=13

path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BF"+str(BS)+"/"

with open(path_save+"surface_carre_gen_tous_fichiers_BF"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BF"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print("Nombre d'élements",len(flat_im_gen))
print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# Nombre d'élements 2001
# la médiane est 1.2
# la moyenne est 1.4178795871691086

# %% [markdown]
# ## BF 15

# %%
BS=15

path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BF"+str(BS)+"/"

with open(path_save+"surface_carre_gen_tous_fichiers_BF"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BF"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print("Nombre d'élements",len(flat_im_gen))
print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# Nombre d'élements 2007
# la médiane est 1.2380952380952381
# la moyenne est 1.4690894616266141

# %% [markdown]
# ## BF17

# %%
BS=17

path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BF"+str(BS)+"/"

with open(path_save+"surface_carre_gen_tous_fichiers_BF"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BF"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print("Nombre d'élements",len(flat_im_gen))
print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# Nombre d'élements 2013
# la médiane est 1.2833333333333334
# la moyenne est 1.5221405569382567

# %% [markdown]
# ## BlurFact 19

# %%
BS=19

path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BF"+str(BS)+"/"

with open(path_save+"surface_carre_gen_tous_fichiers_BF"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BF"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print("Nombre d'élements",len(flat_im_gen))
print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# Nombre d'élements 2005
# la médiane est 1.3066666666666666
# la moyenne est 1.576075343529136

# %%
## Pouvelle après

# %% [markdown]
# ## BlocK Size 41

# %%
BS=41

path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS"+str(BS)+"/"

with open(path_save+"surface_carre_gen_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print("Nombre d'élements",len(flat_im_gen))
print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# Nombre d'élements 1938
# la médiane est 1.8583234946871312
# la moyenne est 2.1123995034949155

# %% [markdown]
# ## Bloc Size 37

# %%
BS=37

path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS"+str(BS)+"/"

with open(path_save+"surface_carre_gen_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print("Nombre d'élements",len(flat_im_gen))
print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-e18ea2d164b8> in <module>
#       3 path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS"+str(BS)+"/"
#       4
# ----> 5 with open(path_save+"surface_carre_gen_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
#       6     im_gen = pickle.load(fp)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS37/surface_carre_gen_tous_fichiers_BS37.txt'

# %% [markdown]
# ## Block Size 27

# %%
BS=27

path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS"+str(BS)+"/"

with open(path_save+"surface_carre_gen_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print("Nombre d'élements",len(flat_im_gen))
print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-21fb10a5e2e0> in <module>
#       3 path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS"+str(BS)+"/"
#       4
# ----> 5 with open(path_save+"surface_carre_gen_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
#       6     im_gen = pickle.load(fp)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS27/surface_carre_gen_tous_fichiers_BS27.txt'

# %% [markdown]
# ## Bloc Size 23

# %%
BS=23

path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS"+str(BS)+"/"

with open(path_save+"surface_carre_gen_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print("Nombre d'élements",len(flat_im_gen))
print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# Nombre d'élements 2035
# la médiane est 1.4545454545454546
# la moyenne est 1.722079558175945

# %%
## Block Size 17

# %%
BS=17

path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS"+str(BS)+"/"

with open(path_save+"surface_carre_gen_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print("Nombre d'élements",len(flat_im_gen))
print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# Nombre d'élements 2007
# la médiane est 1.2380952380952381
# la moyenne est 1.4690894616266141

# %% [markdown]
# ## Block Size 11

# %%
BS=11

path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS"+str(BS)+"/"

with open(path_save+"surface_carre_gen_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BS"+str(BS)+".txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print("Nombre d'élements",len(flat_im_gen))
print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# Nombre d'élements 1829
# la médiane est 0.984375
# la moyenne est 1.1506159848294988

# %%
#Pour le reste il y a un soucis

# %%
path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS29/"
#/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS35/image_no_caught_BS35.txt
#/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS35/surface_anote_liste_tous_fichiers_BS35.txt
#/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS35/surface_carre_gen_tous_fichiers_BS35.txt

with open(path_save+"surface_carre_gen_tous_fichiers_BS29.txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BS29.txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print(len(flat_im_gen))
print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# 1813
# la médiane est 2.0534188034188032
# la moyenne est 2.277150169586598

# %% [markdown]
# ## BlocK Size 25

# %%
path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS25/"
#/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS35/image_no_caught_BS35.txt
#/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS35/surface_anote_liste_tous_fichiers_BS35.txt
#/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS35/surface_carre_gen_tous_fichiers_BS35.txt

with open(path_save+"surface_carre_gen_tous_fichiers_BS25.txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BS25.txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print(len(flat_im_gen))

print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# 1805
# la médiane est 2.0606060606060606
# la moyenne est 2.28454063780887

# %%
path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS21/"


with open(path_save+"surface_carre_gen_tous_fichiers_BS21.txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BS21.txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print(len(flat_im_gen))

print("la médiane est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# 1774
# la médiane est 2.0739576213260422
# la moyenne est 2.3014722344875578

# %% [markdown]
# ## Block Size 19

# %%
path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS19/"


with open(path_save+"surface_carre_gen_tous_fichiers_BS19.txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_anote_liste_tous_fichiers_BS19.txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-a425851fc69b> in <module>
#       2
#       3
# ----> 4 with open(path_save+"surface_carre_gen_tous_fichiers_BS19.txt", "rb") as fp:   # Unpickling
#       5     im_gen = pickle.load(fp)
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS19/surface_carre_gen_tous_fichiers_BS19.txt'

# %% [markdown]
# ## Block Size 15

# %%
path_save="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/listes/Comp_imgen_imanote/BS15/"

with open(path_save+"surface_anote_liste_tous_fichiers_BS15.txt", "rb") as fp:   # Unpickling
    im_gen = pickle.load(fp)
    
with open(path_save+"surface_carre_gen_tous_fichiers_BS15.txt", "rb") as fp:   # Unpickling
    im_anote = pickle.load(fp)    
    
flat_im_gen = [item for sublist in im_gen for item in sublist]
flat_im_anote = [item for sublist in im_anote for item in sublist]

plt.figure(figsize=(12,12))
sns.set(); 

for i in range(5):
    rapport_taille_im_gen_anote_ce_dossier = [int(b) / int(m) for b,m in zip(im_gen[i], im_anote[i])]
    plt.subplot(3,2,i+1)
    plt.title("dossier"+str(i))
    ax = sns.distplot(rapport_taille_im_gen_anote_ce_dossier)
    
rapport_taille_im_gen_anote_tous_dossiers = [int(b) / int(m) for b,m in zip(flat_im_gen, flat_im_anote)]

plt.subplot(3,2,6)
plt.title("tous les dossiers confondus")
ax = sns.distplot(rapport_taille_im_gen_anote_tous_dossiers)

print(len(flat_im_gen))
print("la moyenne est",np.median(rapport_taille_im_gen_anote_tous_dossiers))
print("la moyenne est",np.mean(rapport_taille_im_gen_anote_tous_dossiers))
# Out:
# 1685
# la moyenne est 0.47337278106508873
# la moyenne est 0.5175677748223586

# %%
#im_anote[3]
