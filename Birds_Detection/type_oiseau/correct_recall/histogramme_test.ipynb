# %%
import matplotlib.pyplot as plt
import pickle
path="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_predicts_saved/"

# %%
#Avec 100 epochs
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_200ep/"
print("Avec 200 epochs")
#Dossier 0

with open(path_neurones+"fp_tf_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)

plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_200epPi1_1.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_200epPi1_1.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(152)
plt.title("dossier1")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_200epPi1_2.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_200epPi1_2.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(153)
plt.title("dossier2")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))


with open(path_neurones+"fp_tf_200epPi1_3.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_200epPi1_3.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(154)
plt.title("dossier3")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_200epPi1_4.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_200epPi1_4.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(1,5,5)
plt.title("dossier4")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# Avec 200 epochs
# 263 272
# 1314 896
# 35 69
# 1976 489
# 2107 334

# %%
#Avec 100 epochs
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/tf_fp+match/80%/200ep/"

#Dossier 0

with open(path_neurones+"fp_tf_fp+match_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_fp+match_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)



plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# 1388 272

# %%
#Avec 100 epochs
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/test/"

#Dossier 0

with open(path_neurones+"fp_lessfp_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_lessfp_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)



plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# 1214 272

# %%
#Maintenant j'aimerais ajouter avec les oiseaux matchs


#Avec 100 epochs
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/tf_fp+match/80%/200ep/"

#Dossier 0

with open(path_neurones+"fp_tf_fp+match_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_fp+match_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)



plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_1.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_1.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(152)
plt.title("dossier1")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_2.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_2.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(153)
plt.title("dossier2")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))


with open(path_neurones+"fp_tf_100epPi1_3.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_3.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(154)
plt.title("dossier3")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_4.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_4.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(1,5,5)
plt.title("dossier4")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# 1388 272
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f004fe4bfb81> in <module>
#      26
#      27
# ---> 28 with open(path_neurones+"fp_tf_100epPi1_1.txt", "rb") as fp:   # Unpickling
#      29    FP = pickle.load(fp)
#      30
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/tf_fp+match/80%/200ep/fp_tf_100epPi1_1.txt'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-411edc3b7840> in <module>
# ----> 1 imagettes
#
# NameError: name 'imagettes' is not defined

# %%
#Avec 100 epochs
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/tf_fp+match/80%/200ep/"

#Dossier 0

with open(path_neurones+"fp_tf_fp+match_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_fp+match_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)



plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_1.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_1.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(152)
plt.title("dossier1")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_2.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_2.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(153)
plt.title("dossier2")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))


with open(path_neurones+"fp_tf_100epPi1_3.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_3.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(154)
plt.title("dossier3")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_4.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_4.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(1,5,5)
plt.title("dossier4")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# 1388 272
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-191-777bfc03fcef> in <module>
#      23
#      24
# ---> 25 with open(path_neurones+"fp_tf_100epPi1_1.txt", "rb") as fp:   # Unpickling
#      26    FP = pickle.load(fp)
#      27
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/tf_fp+match/80%/200ep/fp_tf_100epPi1_1.txt'

# %%
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/tf_fp+match/50%/200ep/"

#Dossier 0

with open(path_neurones+"fp_lessfp_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_lessfp_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)



plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# 1214 272

# %%
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/tf_fp+match/80%/200ep/"

#Dossier 0

with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/test/fp_doublePi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/test/mb_doublePi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)



plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# 1673 272

# %%
#Avec 100 epochs
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/tf_fp+match/80%/200ep/"

#Dossier 0

with open(path_neurones+"fp_tf_fp+match_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_fp+match_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)



plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# 1388 272
