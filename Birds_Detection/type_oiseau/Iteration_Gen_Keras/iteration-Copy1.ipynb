# %%
"Refaire avec le grand écran"
import numpy as np # Pour la manipulation de tableaux
from keras.applications import  resnet50
from sklearn import metrics 
import os

import pandas as pd # Pour manipuler des DataFrames pandas

import matplotlib.pyplot as plt # Pour l'affichage d'images
from matplotlib import cm # Pour importer de nouvelles cartes de couleur
# %matplotlib inline

from keras.models import Sequential # Pour construire un réseau de neurones



from keras.layers import Dense, Conv2D # Pour instancier une couche dense
from keras.utils import np_utils

from keras.models import Sequential



from keras.layers import Dense, Activation,GlobalAveragePooling2D, MaxPooling2D
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.models import Model



import cv2
import keras
from numpy.random import seed
import tensorflow

from keras.preprocessing.image import ImageDataGenerator
import itertools # Pour créer des iterateurs

from sklearn import linear_model, preprocessing 



# %matplotlib inline
import numpy as np

import matplotlib.pyplot as plt
import time, cv2
import seaborn as sns

import pandas as pd
from sklearn.model_selection import train_test_split

from keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.models import Model, Sequential
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras import backend as K
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.applications.vgg16 import preprocess_input

# %%
#Paramètres

#generateur_path='/mnt/VegaSlowDataDisk/c3po/Chaine_de_traitement/Train_imagettes_annotées/type_oiseau/Materiel/generateur.csv'
test_size=0.2
epochs=200
batch_size = 600
zoom_range = 1.25
horizontal_flip = True
Minimum_Number_Class=100
dropout_rate=0.3
#steps_per_epoch=len(data_train)//batch_size
steps_per_epoch=1
#validation_steps=len(data_test)//batch_size
validation_steps=1

# %%
#df=pd.read_csv("/home/marcpozzo/Desktop/c3po/Images_aquises/generateur.csv")


base_img_paths="/home/marcpozzo/Desktop/c3po/Images_aquises/"
generateur_path='/mnt/VegaSlowDataDisk/c3po/Images_aquises/generateur_bigger.csv'

df=pd.read_csv(generateur_path)
df.drop('labels',inplace=True,axis=1)

df["class"].unique()
for c in df:
    print(''+c+':',len(df[c].unique()))
df["class"].unique()


All_Unique=df["class"].unique()
Utilisable=[]
for i in df["class"].unique():
    if df["class"][df["class"]==i].count()>Minimum_Number_Class:
        Utilisable.append(i)
Utilisable
Non_Utilisable=set(All_Unique)-set(Utilisable)
Non_Utilisable
for i in Non_Utilisable:
    df=df[df["class"]!=i]
df=df[df["class"]!="oiseau"]  
df["class"].unique()


for i in range(len(df["class"])):
    image_name=df["img_paths"].iloc[i]
    df["img_paths"].iloc[i]=os.path.join(base_img_paths,image_name)
# Out:
# class: 13
# img_paths: 6220

# %%
    
lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = dropout_rate)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 6,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation



seed(1)
tensorflow.random.set_seed(2)

data_train,data_test= train_test_split(df,stratify=df["class"], test_size=test_size,random_state=42)
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        #zoom_range = zoom_range,
        #horizontal_flip = horizontal_flip
        )



train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_train) )



gen_train=train_generator[0]

x_train=gen_train[0]
y_train=gen_train[1]



test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)







test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_test))





gen_test=test_generator[0]

x_test=gen_test[0]
y_test=gen_test[1]









val_accuracy_list=[]
accuracy_list=[]

#Paramètres
base_img_paths="/home/marcpozzo/Desktop/c3po/Images_aquises/"
generateur_path='/mnt/VegaSlowDataDisk/c3po/Images_aquises/generateur.csv'
#generateur_path='/mnt/VegaSlowDataDisk/c3po/Chaine_de_traitement/Train_imagettes_annotées/type_oiseau/Materiel/generateur.csv'
test_size=0.2
epochs=2000
batch_size = len(x_train)
zoom_range = 1
horizontal_flip = False
dropout_rate=0.3



val_accuracy=[]
accuracy=[]

"""datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)"""


datagen = ImageDataGenerator(rotation_range=5)



longueur=round(len(x_train)) 

history=lenet.fit(x_train, y_train,validation_data=(x_test,y_test),verbose=0,
                 steps_per_epoch=1,
                           epochs=epochs,
                           workers=-1,
                           validation_steps=1)



# here's a more "manual" example
for e in range(epochs):
    batches = 0

    for x_batch, y_batch in datagen.flow(x_train, y_train, batch_size=len(x_train)):
        history=lenet.fit(x_batch, y_batch,validation_data=(x_test,y_test),verbose=0)
        val_accuracy.append(history.history["val_accuracy"][len(history.history["val_accuracy"])  -1 ])
        #val_accuracy.append(history.history["val_accuracy"])
        accuracy.append(history.history["accuracy"][len(history.history["accuracy"])  -1 ])
        batches += 1
        
        #accuracy=history.history["accuracy"]
        #val_accuracy=history.history["val_accuracy"]
        accuracy_list.append(accuracy)
        val_accuracy_list.append(val_accuracy)
        if batches >= len(x_train) / longueur:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break 
            
            
print("test_size",test_size)
print("epochs",epochs)
print("batch_size",batch_size)
print("zoom_range",zoom_range)
print("horizontal_flip ",horizontal_flip )
print("dropout_rate",dropout_rate)


plt.figure(figsize=(16,12))

plt.plot(accuracy,label="train");
plt.plot(val_accuracy,label="test");
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title("Accuracy en fonction du nombre d'epoch");

lenet.save('1')
# Out:
# Found 4772 validated image filenames belonging to 6 classes.
# Found 1194 validated image filenames belonging to 6 classes.
# test_size 0.2
# epochs 2000
# batch_size 4772
# zoom_range 1
# horizontal_flip  False
# dropout_rate 0.3

# %%
    
lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = dropout_rate)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 6,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation



seed(1)
tensorflow.random.set_seed(2)

data_train,data_test= train_test_split(df,stratify=df["class"], test_size=test_size,random_state=42)
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        #zoom_range = zoom_range,
        #horizontal_flip = horizontal_flip
        )



train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_train) )



gen_train=train_generator[0]

x_train=gen_train[0]
y_train=gen_train[1]



test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)







test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_test))





gen_test=test_generator[0]

x_test=gen_test[0]
y_test=gen_test[1]









val_accuracy_list=[]
accuracy_list=[]

#Paramètres
base_img_paths="/home/marcpozzo/Desktop/c3po/Images_aquises/"
generateur_path='/mnt/VegaSlowDataDisk/c3po/Images_aquises/generateur.csv'
#generateur_path='/mnt/VegaSlowDataDisk/c3po/Chaine_de_traitement/Train_imagettes_annotées/type_oiseau/Materiel/generateur.csv'
test_size=0.2
epochs=2000
batch_size = len(x_train)
zoom_range = 1
horizontal_flip = False
dropout_rate=0.3



val_accuracy=[]
accuracy=[]

"""datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)"""


datagen = ImageDataGenerator(width_shift_range=0.1,height_shift_range=0.1)



longueur=round(len(x_train)) 

history=lenet.fit(x_train, y_train,validation_data=(x_test,y_test),verbose=0,
                 steps_per_epoch=1,
                           epochs=epochs,
                           workers=-1,
                           validation_steps=1)



# here's a more "manual" example
for e in range(epochs):
    batches = 0

    for x_batch, y_batch in datagen.flow(x_train, y_train, batch_size=len(x_train)):
        history=lenet.fit(x_batch, y_batch,validation_data=(x_test,y_test),verbose=0)
        val_accuracy.append(history.history["val_accuracy"][len(history.history["val_accuracy"])  -1 ])
        #val_accuracy.append(history.history["val_accuracy"])
        accuracy.append(history.history["accuracy"][len(history.history["accuracy"])  -1 ])
        batches += 1
        
        #accuracy=history.history["accuracy"]
        #val_accuracy=history.history["val_accuracy"]
        accuracy_list.append(accuracy)
        val_accuracy_list.append(val_accuracy)
        if batches >= len(x_train) / longueur:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break 
            
            
print("test_size",test_size)
print("epochs",epochs)
print("batch_size",batch_size)
print("zoom_range",zoom_range)
print("horizontal_flip ",horizontal_flip )
print("dropout_rate",dropout_rate)


plt.figure(figsize=(16,12))

plt.plot(accuracy,label="train");
plt.plot(val_accuracy,label="test");
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title("Accuracy en fonction du nombre d'epoch");

lenet.save('2')
# Out:
# Found 4772 validated image filenames belonging to 6 classes.
# Found 1194 validated image filenames belonging to 6 classes.
# test_size 0.2
# epochs 2000
# batch_size 4772
# zoom_range 1
# horizontal_flip  False
# dropout_rate 0.3

# %%
    
lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = dropout_rate)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 6,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation



seed(1)
tensorflow.random.set_seed(2)

data_train,data_test= train_test_split(df,stratify=df["class"], test_size=test_size,random_state=42)
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        #zoom_range = zoom_range,
        #horizontal_flip = horizontal_flip
        )



train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_train) )



gen_train=train_generator[0]

x_train=gen_train[0]
y_train=gen_train[1]



test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)







test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_test))





gen_test=test_generator[0]

x_test=gen_test[0]
y_test=gen_test[1]









val_accuracy_list=[]
accuracy_list=[]

#Paramètres
base_img_paths="/home/marcpozzo/Desktop/c3po/Images_aquises/"
generateur_path='/mnt/VegaSlowDataDisk/c3po/Images_aquises/generateur.csv'
#generateur_path='/mnt/VegaSlowDataDisk/c3po/Chaine_de_traitement/Train_imagettes_annotées/type_oiseau/Materiel/generateur.csv'
test_size=0.2
epochs=2000
batch_size = len(x_train)
zoom_range = 1
horizontal_flip = False
dropout_rate=0.3



val_accuracy=[]
accuracy=[]

"""datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)"""


datagen = ImageDataGenerator(width_shift_range=0.1,height_shift_range=0.1)



longueur=round(len(x_train)) 

history=lenet.fit(x_train, y_train,validation_data=(x_test,y_test),verbose=0,
                 steps_per_epoch=1,
                           epochs=epochs,
                           workers=-1,
                           validation_steps=1)



# here's a more "manual" example
for e in range(epochs):
    batches = 0

    for x_batch, y_batch in datagen.flow(x_train, y_train, batch_size=len(x_train)):
        history=lenet.fit(x_batch, y_batch,validation_data=(x_test,y_test),verbose=0)
        val_accuracy.append(history.history["val_accuracy"][len(history.history["val_accuracy"])  -1 ])
        #val_accuracy.append(history.history["val_accuracy"])
        accuracy.append(history.history["accuracy"][len(history.history["accuracy"])  -1 ])
        batches += 1
        
        #accuracy=history.history["accuracy"]
        #val_accuracy=history.history["val_accuracy"]
        accuracy_list.append(accuracy)
        val_accuracy_list.append(val_accuracy)
        if batches >= len(x_train) / longueur:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break 
            
            
print("test_size",test_size)
print("epochs",epochs)
print("batch_size",batch_size)
print("zoom_range",zoom_range)
print("horizontal_flip ",horizontal_flip )
print("dropout_rate",dropout_rate)


plt.figure(figsize=(16,12))

plt.plot(accuracy,label="train");
plt.plot(val_accuracy,label="test");
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title("Accuracy en fonction du nombre d'epoch");

lenet.save('3')
# Out:
# Found 4772 validated image filenames belonging to 6 classes.
# Found 1194 validated image filenames belonging to 6 classes.
# test_size 0.2
# epochs 2000
# batch_size 4772
# zoom_range 1
# horizontal_flip  False
# dropout_rate 0.3

# %%
    
lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = dropout_rate)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 6,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation



seed(1)
tensorflow.random.set_seed(2)

data_train,data_test= train_test_split(df,stratify=df["class"], test_size=test_size,random_state=42)
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        #zoom_range = zoom_range,
        #horizontal_flip = horizontal_flip
        )



train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_train) )



gen_train=train_generator[0]

x_train=gen_train[0]
y_train=gen_train[1]



test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)







test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_test))





gen_test=test_generator[0]

x_test=gen_test[0]
y_test=gen_test[1]









val_accuracy_list=[]
accuracy_list=[]

#Paramètres
base_img_paths="/home/marcpozzo/Desktop/c3po/Images_aquises/"
generateur_path='/mnt/VegaSlowDataDisk/c3po/Images_aquises/generateur.csv'
#generateur_path='/mnt/VegaSlowDataDisk/c3po/Chaine_de_traitement/Train_imagettes_annotées/type_oiseau/Materiel/generateur.csv'
test_size=0.2
epochs=2000
batch_size = len(x_train)
zoom_range = 1
horizontal_flip = False
dropout_rate=0.3



val_accuracy=[]
accuracy=[]

"""datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)"""


datagen = ImageDataGenerator(horizontal_flip=True)



longueur=round(len(x_train)) 

history=lenet.fit(x_train, y_train,validation_data=(x_test,y_test),verbose=0,
                 steps_per_epoch=1,
                           epochs=epochs,
                           workers=-1,
                           validation_steps=1)



# here's a more "manual" example
for e in range(epochs):
    batches = 0

    for x_batch, y_batch in datagen.flow(x_train, y_train, batch_size=len(x_train)):
        history=lenet.fit(x_batch, y_batch,validation_data=(x_test,y_test),verbose=0)
        val_accuracy.append(history.history["val_accuracy"][len(history.history["val_accuracy"])  -1 ])
        #val_accuracy.append(history.history["val_accuracy"])
        accuracy.append(history.history["accuracy"][len(history.history["accuracy"])  -1 ])
        batches += 1
        
        #accuracy=history.history["accuracy"]
        #val_accuracy=history.history["val_accuracy"]
        accuracy_list.append(accuracy)
        val_accuracy_list.append(val_accuracy)
        if batches >= len(x_train) / longueur:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break 
            
            
print("test_size",test_size)
print("epochs",epochs)
print("batch_size",batch_size)
print("zoom_range",zoom_range)
print("horizontal_flip ",horizontal_flip )
print("dropout_rate",dropout_rate)


plt.figure(figsize=(16,12))

plt.plot(accuracy,label="train");
plt.plot(val_accuracy,label="test");
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title("Accuracy en fonction du nombre d'epoch");

lenet.save('4')
# Out:
# Found 4772 validated image filenames belonging to 6 classes.
# Found 1194 validated image filenames belonging to 6 classes.
# test_size 0.2
# epochs 2000
# batch_size 4772
# zoom_range 1
# horizontal_flip  False
# dropout_rate 0.3

# %%
    
lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = dropout_rate)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 6,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation



seed(1)
tensorflow.random.set_seed(2)

data_train,data_test= train_test_split(df,stratify=df["class"], test_size=test_size,random_state=42)
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        #zoom_range = zoom_range,
        #horizontal_flip = horizontal_flip
        )



train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_train) )



gen_train=train_generator[0]

x_train=gen_train[0]
y_train=gen_train[1]



test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)







test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_test))





gen_test=test_generator[0]

x_test=gen_test[0]
y_test=gen_test[1]









val_accuracy_list=[]
accuracy_list=[]

#Paramètres
base_img_paths="/home/marcpozzo/Desktop/c3po/Images_aquises/"
generateur_path='/mnt/VegaSlowDataDisk/c3po/Images_aquises/generateur.csv'
#generateur_path='/mnt/VegaSlowDataDisk/c3po/Chaine_de_traitement/Train_imagettes_annotées/type_oiseau/Materiel/generateur.csv'
test_size=0.2
epochs=2000
batch_size = len(x_train)
zoom_range = 1
horizontal_flip = False
dropout_rate=0.3



val_accuracy=[]
accuracy=[]

datagen = ImageDataGenerator(
    #featurewise_center=True,
    #featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)


#datagen = ImageDataGenerator(horizontal_flip=True)



longueur=round(len(x_train)) 

history=lenet.fit(x_train, y_train,validation_data=(x_test,y_test),verbose=0,
                 steps_per_epoch=1,
                           epochs=epochs,
                           workers=-1,
                           validation_steps=1)



# here's a more "manual" example
for e in range(epochs):
    batches = 0

    for x_batch, y_batch in datagen.flow(x_train, y_train, batch_size=len(x_train)):
        history=lenet.fit(x_batch, y_batch,validation_data=(x_test,y_test),verbose=0)
        val_accuracy.append(history.history["val_accuracy"][len(history.history["val_accuracy"])  -1 ])
        #val_accuracy.append(history.history["val_accuracy"])
        accuracy.append(history.history["accuracy"][len(history.history["accuracy"])  -1 ])
        batches += 1
        
        #accuracy=history.history["accuracy"]
        #val_accuracy=history.history["val_accuracy"]
        accuracy_list.append(accuracy)
        val_accuracy_list.append(val_accuracy)
        if batches >= len(x_train) / longueur:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break 
            
            
print("test_size",test_size)
print("epochs",epochs)
print("batch_size",batch_size)
print("zoom_range",zoom_range)
print("horizontal_flip ",horizontal_flip )
print("dropout_rate",dropout_rate)


plt.figure(figsize=(16,12))

plt.plot(accuracy,label="train");
plt.plot(val_accuracy,label="test");
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title("Accuracy en fonction du nombre d'epoch");

lenet.save('5')
# Out:
# Found 4772 validated image filenames belonging to 6 classes.
# Found 1194 validated image filenames belonging to 6 classes.
# test_size 0.2
# epochs 2000
# batch_size 4772
# zoom_range 1
# horizontal_flip  False
# dropout_rate 0.3

# %%
    
lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = dropout_rate)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 6,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation



seed(1)
tensorflow.random.set_seed(2)

data_train,data_test= train_test_split(df,stratify=df["class"], test_size=test_size,random_state=42)
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        #zoom_range = zoom_range,
        #horizontal_flip = horizontal_flip
        )



train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_train) )



gen_train=train_generator[0]

x_train=gen_train[0]
y_train=gen_train[1]



test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)







test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_test))





gen_test=test_generator[0]

x_test=gen_test[0]
y_test=gen_test[1]









val_accuracy_list=[]
accuracy_list=[]

#Paramètres
base_img_paths="/home/marcpozzo/Desktop/c3po/Images_aquises/"
generateur_path='/mnt/VegaSlowDataDisk/c3po/Images_aquises/generateur.csv'
#generateur_path='/mnt/VegaSlowDataDisk/c3po/Chaine_de_traitement/Train_imagettes_annotées/type_oiseau/Materiel/generateur.csv'
test_size=0.2
epochs=2000
batch_size = len(x_train)
zoom_range = 1
horizontal_flip = False
dropout_rate=0.3



val_accuracy=[]
accuracy=[]

datagen = ImageDataGenerator(
    zoom_range=[0.9,1.3])
    #featurewise_center=True,
    #featurewise_std_normalization=True,
    #rotation_range=,
    #width_shift_range=0.2,
    #height_shift_range=0.2,
    #horizontal_flip=True)


#datagen = ImageDataGenerator(horizontal_flip=True)



longueur=round(len(x_train)) 

history=lenet.fit(x_train, y_train,validation_data=(x_test,y_test),verbose=0,
                 steps_per_epoch=1,
                           epochs=epochs,
                           workers=-1,
                           validation_steps=1)



# here's a more "manual" example
for e in range(epochs):
    batches = 0

    for x_batch, y_batch in datagen.flow(x_train, y_train, batch_size=len(x_train)):
        history=lenet.fit(x_batch, y_batch,validation_data=(x_test,y_test),verbose=0)
        val_accuracy.append(history.history["val_accuracy"][len(history.history["val_accuracy"])  -1 ])
        #val_accuracy.append(history.history["val_accuracy"])
        accuracy.append(history.history["accuracy"][len(history.history["accuracy"])  -1 ])
        batches += 1
        
        #accuracy=history.history["accuracy"]
        #val_accuracy=history.history["val_accuracy"]
        accuracy_list.append(accuracy)
        val_accuracy_list.append(val_accuracy)
        if batches >= len(x_train) / longueur:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break 
            
            
print("test_size",test_size)
print("epochs",epochs)
print("batch_size",batch_size)
print("zoom_range",zoom_range)
print("horizontal_flip ",horizontal_flip )
print("dropout_rate",dropout_rate)


plt.figure(figsize=(16,12))

plt.plot(accuracy,label="train");
plt.plot(val_accuracy,label="test");
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title("Accuracy en fonction du nombre d'epoch");

lenet.save('6')
# Out:
# Found 4772 validated image filenames belonging to 6 classes.
# Found 1194 validated image filenames belonging to 6 classes.
# test_size 0.2
# epochs 2000
# batch_size 4772
# zoom_range 1
# horizontal_flip  False
# dropout_rate 0.3

# %%
    
lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = dropout_rate)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 6,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation



seed(1)
tensorflow.random.set_seed(2)

data_train,data_test= train_test_split(df,stratify=df["class"], test_size=test_size,random_state=42)
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        #zoom_range = zoom_range,
        #horizontal_flip = horizontal_flip
        )



train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_train) )



gen_train=train_generator[0]

x_train=gen_train[0]
y_train=gen_train[1]



test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)







test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_test))





gen_test=test_generator[0]

x_test=gen_test[0]
y_test=gen_test[1]









val_accuracy_list=[]
accuracy_list=[]

#Paramètres
base_img_paths="/home/marcpozzo/Desktop/c3po/Images_aquises/"
generateur_path='/mnt/VegaSlowDataDisk/c3po/Images_aquises/generateur.csv'
#generateur_path='/mnt/VegaSlowDataDisk/c3po/Chaine_de_traitement/Train_imagettes_annotées/type_oiseau/Materiel/generateur.csv'
test_size=0.2
epochs=2000
batch_size = len(x_train)
zoom_range = 1
horizontal_flip = False
dropout_rate=0.3



val_accuracy=[]
accuracy=[]

datagen = ImageDataGenerator(
    zoom_range=[0.9,1.3],
    #featurewise_center=True,
    #featurewise_std_normalization=True,
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True)


#datagen = ImageDataGenerator(horizontal_flip=True)



longueur=round(len(x_train)) 

history=lenet.fit(x_train, y_train,validation_data=(x_test,y_test),verbose=0,
                 steps_per_epoch=1,
                           epochs=epochs,
                           workers=-1,
                           validation_steps=1)



# here's a more "manual" example
for e in range(epochs):
    batches = 0

    for x_batch, y_batch in datagen.flow(x_train, y_train, batch_size=len(x_train)):
        history=lenet.fit(x_batch, y_batch,validation_data=(x_test,y_test),verbose=0)
        val_accuracy.append(history.history["val_accuracy"][len(history.history["val_accuracy"])  -1 ])
        #val_accuracy.append(history.history["val_accuracy"])
        accuracy.append(history.history["accuracy"][len(history.history["accuracy"])  -1 ])
        batches += 1
        
        #accuracy=history.history["accuracy"]
        #val_accuracy=history.history["val_accuracy"]
        accuracy_list.append(accuracy)
        val_accuracy_list.append(val_accuracy)
        if batches >= len(x_train) / longueur:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break 
            
            
print("test_size",test_size)
print("epochs",epochs)
print("batch_size",batch_size)
print("zoom_range",zoom_range)
print("horizontal_flip ",horizontal_flip )
print("dropout_rate",dropout_rate)


plt.figure(figsize=(16,12))

plt.plot(accuracy,label="train");
plt.plot(val_accuracy,label="test");
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title("Accuracy en fonction du nombre d'epoch");

lenet.save('7')
# Out:
# Found 4772 validated image filenames belonging to 6 classes.
# Found 1194 validated image filenames belonging to 6 classes.
# test_size 0.2
# epochs 2000
# batch_size 4772
# zoom_range 1
# horizontal_flip  False
# dropout_rate 0.3

# %%
    
lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = dropout_rate)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 6,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation



seed(1)
tensorflow.random.set_seed(2)

data_train,data_test= train_test_split(df,stratify=df["class"], test_size=test_size,random_state=42)
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        #zoom_range = zoom_range,
        #horizontal_flip = horizontal_flip
        )



train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_train) )



gen_train=train_generator[0]

x_train=gen_train[0]
y_train=gen_train[1]



test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)







test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_test))





gen_test=test_generator[0]

x_test=gen_test[0]
y_test=gen_test[1]









val_accuracy_list=[]
accuracy_list=[]

#Paramètres
base_img_paths="/home/marcpozzo/Desktop/c3po/Images_aquises/"
generateur_path='/mnt/VegaSlowDataDisk/c3po/Images_aquises/generateur.csv'
#generateur_path='/mnt/VegaSlowDataDisk/c3po/Chaine_de_traitement/Train_imagettes_annotées/type_oiseau/Materiel/generateur.csv'
test_size=0.2
epochs=2000
batch_size = len(x_train)
zoom_range = 1
horizontal_flip = False
dropout_rate=0.3



val_accuracy=[]
accuracy=[]

datagen = ImageDataGenerator()


#datagen = ImageDataGenerator(horizontal_flip=True)



longueur=round(len(x_train)) 

history=lenet.fit(x_train, y_train,validation_data=(x_test,y_test),verbose=0,
                 steps_per_epoch=1,
                           epochs=epochs,
                           workers=-1,
                           validation_steps=1)



# here's a more "manual" example
for e in range(epochs):
    batches = 0

    for x_batch, y_batch in datagen.flow(x_train, y_train, batch_size=len(x_train)):
        history=lenet.fit(x_batch, y_batch,validation_data=(x_test,y_test),verbose=0)
        val_accuracy.append(history.history["val_accuracy"][len(history.history["val_accuracy"])  -1 ])
        #val_accuracy.append(history.history["val_accuracy"])
        accuracy.append(history.history["accuracy"][len(history.history["accuracy"])  -1 ])
        batches += 1
        
        #accuracy=history.history["accuracy"]
        #val_accuracy=history.history["val_accuracy"]
        accuracy_list.append(accuracy)
        val_accuracy_list.append(val_accuracy)
        if batches >= len(x_train) / longueur:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break 
            
            
print("test_size",test_size)
print("epochs",epochs)
print("batch_size",batch_size)
print("zoom_range",zoom_range)
print("horizontal_flip ",horizontal_flip )
print("dropout_rate",dropout_rate)


plt.figure(figsize=(16,12))

plt.plot(accuracy,label="train");
plt.plot(val_accuracy,label="test");
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title("Accuracy en fonction du nombre d'epoch");

lenet.save('8')
# Out:
# Found 4772 validated image filenames belonging to 6 classes.
# Found 1194 validated image filenames belonging to 6 classes.
# test_size 0.2
# epochs 2000
# batch_size 4772
# zoom_range 1
# horizontal_flip  False
# dropout_rate 0.3

# %%
    
lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = dropout_rate)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 6,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation



seed(2)
tensorflow.random.set_seed(3)

data_train,data_test= train_test_split(df,stratify=df["class"], test_size=test_size,random_state=42)
train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        #zoom_range = zoom_range,
        #horizontal_flip = horizontal_flip
        )



train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_train) )



gen_train=train_generator[0]

x_train=gen_train[0]
y_train=gen_train[1]



test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)







test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = len(data_test))





gen_test=test_generator[0]

x_test=gen_test[0]
y_test=gen_test[1]









val_accuracy_list=[]
accuracy_list=[]

#Paramètres
base_img_paths="/home/marcpozzo/Desktop/c3po/Images_aquises/"
generateur_path='/mnt/VegaSlowDataDisk/c3po/Images_aquises/generateur.csv'
#generateur_path='/mnt/VegaSlowDataDisk/c3po/Chaine_de_traitement/Train_imagettes_annotées/type_oiseau/Materiel/generateur.csv'
test_size=0.2
epochs=500
batch_size = len(x_train)
zoom_range = 1
horizontal_flip = False
dropout_rate=0.3



val_accuracy=[]
accuracy=[]

datagen = ImageDataGenerator(
    zoom_range=[0.9,1.3],
    #featurewise_center=True,
    #featurewise_std_normalization=True,
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True)


#datagen = ImageDataGenerator(horizontal_flip=True)



longueur=round(len(x_train)) 

history=lenet.fit(x_train, y_train,validation_data=(x_test,y_test),verbose=1,
                 steps_per_epoch=1,
                           epochs=epochs,
                           workers=-1,
                           validation_steps=1)



# here's a more "manual" example
for e in range(epochs):
    batches = 0

    for x_batch, y_batch in datagen.flow(x_train, y_train, batch_size=len(x_train)):
        history=lenet.fit(x_batch, y_batch,validation_data=(x_test,y_test),verbose=0)
        val_accuracy.append(history.history["val_accuracy"][len(history.history["val_accuracy"])  -1 ])
        #val_accuracy.append(history.history["val_accuracy"])
        accuracy.append(history.history["accuracy"][len(history.history["accuracy"])  -1 ])
        batches += 1
        
        #accuracy=history.history["accuracy"]
        #val_accuracy=history.history["val_accuracy"]
        accuracy_list.append(accuracy)
        val_accuracy_list.append(val_accuracy)
        if batches >= len(x_train) / longueur:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break 
            
            
print("test_size",test_size)
print("epochs",epochs)
print("batch_size",batch_size)
print("zoom_range",zoom_range)
print("horizontal_flip ",horizontal_flip )
print("dropout_rate",dropout_rate)


plt.figure(figsize=(16,12))

plt.plot(accuracy,label="train");
plt.plot(val_accuracy,label="test");
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title("Accuracy en fonction du nombre d'epoch");

lenet.save('7')
# Out:
# Found 4772 validated image filenames belonging to 6 classes.
# Found 1194 validated image filenames belonging to 6 classes.
# Train on 4772 samples, validate on 1194 samples
# Epoch 1/500
# 1/1 [==============================] - 1s 774ms/step - loss: 42.9843 - accuracy: 0.0465 - val_loss: 10.3880 - val_accuracy: 0.2328
# Epoch 2/500
# 1/1 [==============================] - 1s 586ms/step - loss: 19.1642 - accuracy: 0.1655 - val_loss: 4.2247 - val_accuracy: 0.4045
# Epoch 3/500
# 1/1 [==============================] - 1s 611ms/step - loss: 9.0381 - accuracy: 0.2714 - val_loss: 6.3846 - val_accuracy: 0.5461
# Epoch 4/500
# 1/1 [==============================] - 1s 578ms/step - loss: 6.3812 - accuracy: 0.4679 - val_loss: 6.4358 - val_accuracy: 0.5184
# Epoch 5/500
# 1/1 [==============================] - 1s 576ms/step - loss: 6.2520 - accuracy: 0.4874 - val_loss: 5.5077 - val_accuracy: 0.4916
# Epoch 6/500
# 1/1 [==============================] - 1s 578ms/step - loss: 5.6808 - accuracy: 0.4009 - val_loss: 4.4225 - val_accuracy: 0.4422
# Epoch 7/500
# 1/1 [==============================] - 1s 589ms/step - loss: 4.8039 - accuracy: 0.3994 - val_loss: 3.7123 - val_accuracy: 0.4506
# Epoch 8/500
# 1/1 [==============================] - 1s 577ms/step - loss: 4.2208 - accuracy: 0.4151 - val_loss: 3.2111 - val_accuracy: 0.4464
# Epoch 9/500
# 1/1 [==============================] - 1s 585ms/step - loss: 3.8714 - accuracy: 0.4283 - val_loss: 2.7220 - val_accuracy: 0.4782
# Epoch 10/500
# 1/1 [==============================] - 1s 576ms/step - loss: 3.2613 - accuracy: 0.4549 - val_loss: 2.3623 - val_accuracy: 0.5201
# Epoch 11/500
# 1/1 [==============================] - 1s 596ms/step - loss: 2.8421 - accuracy: 0.4826 - val_loss: 2.1203 - val_accuracy: 0.5620
# Epoch 12/500
# 1/1 [==============================] - 1s 572ms/step - loss: 2.5202 - accuracy: 0.5197 - val_loss: 1.9621 - val_accuracy: 0.5896
# Epoch 13/500
# 1/1 [==============================] - 1s 572ms/step - loss: 2.4008 - accuracy: 0.5283 - val_loss: 1.8660 - val_accuracy: 0.6147
# Epoch 14/500
# 1/1 [==============================] - 1s 582ms/step - loss: 2.1891 - accuracy: 0.5549 - val_loss: 1.8039 - val_accuracy: 0.6256
# Epoch 15/500
# 1/1 [==============================] - 1s 576ms/step - loss: 2.0904 - accuracy: 0.5562 - val_loss: 1.7534 - val_accuracy: 0.6240
# Epoch 16/500
# 1/1 [==============================] - 1s 614ms/step - loss: 1.9458 - accuracy: 0.5698 - val_loss: 1.7054 - val_accuracy: 0.6290
# Epoch 17/500
# 1/1 [==============================] - 1s 588ms/step - loss: 1.9252 - accuracy: 0.5622 - val_loss: 1.6719 - val_accuracy: 0.6265
# Epoch 18/500
# 1/1 [==============================] - 1s 606ms/step - loss: 1.8004 - accuracy: 0.5731 - val_loss: 1.6531 - val_accuracy: 0.6240
# Epoch 19/500
# 1/1 [==============================] - 1s 595ms/step - loss: 1.7680 - accuracy: 0.5729 - val_loss: 1.6455 - val_accuracy: 0.6214
# Epoch 20/500
# 1/1 [==============================] - 1s 594ms/step - loss: 1.7286 - accuracy: 0.5689 - val_loss: 1.6399 - val_accuracy: 0.6139
# Epoch 21/500
# 1/1 [==============================] - 1s 601ms/step - loss: 1.7018 - accuracy: 0.5666 - val_loss: 1.6332 - val_accuracy: 0.6064
# Epoch 22/500
# 1/1 [==============================] - 1s 578ms/step - loss: 1.6786 - accuracy: 0.5606 - val_loss: 1.6277 - val_accuracy: 0.6072
# Epoch 23/500
# 1/1 [==============================] - 1s 587ms/step - loss: 1.6655 - accuracy: 0.5543 - val_loss: 1.6239 - val_accuracy: 0.6030
# Epoch 24/500
# 1/1 [==============================] - 1s 599ms/step - loss: 1.6607 - accuracy: 0.5566 - val_loss: 1.6182 - val_accuracy: 0.5997
# Epoch 25/500
# 1/1 [==============================] - 1s 599ms/step - loss: 1.6479 - accuracy: 0.5580 - val_loss: 1.6103 - val_accuracy: 0.6013
# Epoch 26/500
# 1/1 [==============================] - 1s 572ms/step - loss: 1.6427 - accuracy: 0.5505 - val_loss: 1.6023 - val_accuracy: 0.6064
# Epoch 27/500
# 1/1 [==============================] - 1s 585ms/step - loss: 1.6347 - accuracy: 0.5604 - val_loss: 1.5929 - val_accuracy: 0.6039
# Epoch 28/500
# 1/1 [==============================] - 1s 583ms/step - loss: 1.6197 - accuracy: 0.5662 - val_loss: 1.5817 - val_accuracy: 0.6030
# Epoch 29/500
# 1/1 [==============================] - 1s 576ms/step - loss: 1.6116 - accuracy: 0.5679 - val_loss: 1.5699 - val_accuracy: 0.6064
# Epoch 30/500
# 1/1 [==============================] - 1s 587ms/step - loss: 1.5957 - accuracy: 0.5727 - val_loss: 1.5569 - val_accuracy: 0.6055
# Epoch 31/500
# 1/1 [==============================] - 1s 589ms/step - loss: 1.5831 - accuracy: 0.5727 - val_loss: 1.5438 - val_accuracy: 0.6106
# Epoch 32/500
# 1/1 [==============================] - 1s 616ms/step - loss: 1.5715 - accuracy: 0.5756 - val_loss: 1.5300 - val_accuracy: 0.6164
# Epoch 33/500
# 1/1 [==============================] - 1s 605ms/step - loss: 1.5459 - accuracy: 0.5895 - val_loss: 1.5147 - val_accuracy: 0.6332
# Epoch 34/500
# 1/1 [==============================] - 1s 614ms/step - loss: 1.5297 - accuracy: 0.5970 - val_loss: 1.4982 - val_accuracy: 0.6415
# Epoch 35/500
# 1/1 [==============================] - 1s 579ms/step - loss: 1.5154 - accuracy: 0.6134 - val_loss: 1.4802 - val_accuracy: 0.6524
# Epoch 36/500
# 1/1 [==============================] - 1s 602ms/step - loss: 1.4936 - accuracy: 0.6194 - val_loss: 1.4614 - val_accuracy: 0.6549
# Epoch 37/500
# 1/1 [==============================] - 1s 591ms/step - loss: 1.4848 - accuracy: 0.6209 - val_loss: 1.4453 - val_accuracy: 0.6633
# Epoch 38/500
# 1/1 [==============================] - 1s 618ms/step - loss: 1.4573 - accuracy: 0.6310 - val_loss: 1.4339 - val_accuracy: 0.6650
# Epoch 39/500
# 1/1 [==============================] - 1s 606ms/step - loss: 1.4578 - accuracy: 0.6339 - val_loss: 1.4263 - val_accuracy: 0.6692
# Epoch 40/500
# 1/1 [==============================] - 1s 582ms/step - loss: 1.4460 - accuracy: 0.6440 - val_loss: 1.4196 - val_accuracy: 0.6709
# Epoch 41/500
# 1/1 [==============================] - 1s 571ms/step - loss: 1.4354 - accuracy: 0.6446 - val_loss: 1.4116 - val_accuracy: 0.6709
# Epoch 42/500
# 1/1 [==============================] - 1s 579ms/step - loss: 1.4248 - accuracy: 0.6517 - val_loss: 1.4014 - val_accuracy: 0.6776
# Epoch 43/500
# 1/1 [==============================] - 1s 584ms/step - loss: 1.4201 - accuracy: 0.6561 - val_loss: 1.3900 - val_accuracy: 0.6851
# Epoch 44/500
# 1/1 [==============================] - 1s 595ms/step - loss: 1.3942 - accuracy: 0.6593 - val_loss: 1.3781 - val_accuracy: 0.6884
# Epoch 45/500
# 1/1 [==============================] - 1s 587ms/step - loss: 1.3898 - accuracy: 0.6685 - val_loss: 1.3668 - val_accuracy: 0.6943
# Epoch 46/500
# 1/1 [==============================] - 1s 586ms/step - loss: 1.3621 - accuracy: 0.6695 - val_loss: 1.3576 - val_accuracy: 0.7010
# Epoch 47/500
# 1/1 [==============================] - 1s 585ms/step - loss: 1.3654 - accuracy: 0.6710 - val_loss: 1.3507 - val_accuracy: 0.7018
# Epoch 48/500
# 1/1 [==============================] - 1s 590ms/step - loss: 1.3525 - accuracy: 0.6760 - val_loss: 1.3444 - val_accuracy: 0.7069
# Epoch 49/500
# 1/1 [==============================] - 1s 569ms/step - loss: 1.3398 - accuracy: 0.6819 - val_loss: 1.3377 - val_accuracy: 0.7069
# Epoch 50/500
# 1/1 [==============================] - 1s 594ms/step - loss: 1.3268 - accuracy: 0.6855 - val_loss: 1.3297 - val_accuracy: 0.7094
# Epoch 51/500
# 1/1 [==============================] - 1s 597ms/step - loss: 1.3202 - accuracy: 0.6844 - val_loss: 1.3202 - val_accuracy: 0.7085
# Epoch 52/500
# 1/1 [==============================] - 1s 587ms/step - loss: 1.3110 - accuracy: 0.6896 - val_loss: 1.3104 - val_accuracy: 0.7085
# Epoch 53/500
# 1/1 [==============================] - 1s 571ms/step - loss: 1.2980 - accuracy: 0.6892 - val_loss: 1.3022 - val_accuracy: 0.7085
# Epoch 54/500
# 1/1 [==============================] - 1s 566ms/step - loss: 1.2890 - accuracy: 0.6917 - val_loss: 1.2951 - val_accuracy: 0.7111
# Epoch 55/500
# 1/1 [==============================] - 1s 569ms/step - loss: 1.2846 - accuracy: 0.6928 - val_loss: 1.2887 - val_accuracy: 0.7127
# Epoch 56/500
# 1/1 [==============================] - 1s 577ms/step - loss: 1.2739 - accuracy: 0.6947 - val_loss: 1.2820 - val_accuracy: 0.7136
# Epoch 57/500
# 1/1 [==============================] - 1s 582ms/step - loss: 1.2693 - accuracy: 0.6980 - val_loss: 1.2745 - val_accuracy: 0.7178
# Epoch 58/500
# 1/1 [==============================] - 1s 575ms/step - loss: 1.2656 - accuracy: 0.6949 - val_loss: 1.2660 - val_accuracy: 0.7203
# Epoch 59/500
# 1/1 [==============================] - 1s 594ms/step - loss: 1.2463 - accuracy: 0.7077 - val_loss: 1.2585 - val_accuracy: 0.7194
# Epoch 60/500
# 1/1 [==============================] - 1s 570ms/step - loss: 1.2323 - accuracy: 0.7047 - val_loss: 1.2511 - val_accuracy: 0.7211
# Epoch 61/500
# 1/1 [==============================] - 1s 576ms/step - loss: 1.2311 - accuracy: 0.7022 - val_loss: 1.2441 - val_accuracy: 0.7228
# Epoch 62/500
# 1/1 [==============================] - 1s 596ms/step - loss: 1.2304 - accuracy: 0.7077 - val_loss: 1.2377 - val_accuracy: 0.7194
# Epoch 63/500
# 1/1 [==============================] - 1s 589ms/step - loss: 1.2251 - accuracy: 0.7081 - val_loss: 1.2319 - val_accuracy: 0.7194
# Epoch 64/500
# 1/1 [==============================] - 1s 593ms/step - loss: 1.2140 - accuracy: 0.7083 - val_loss: 1.2254 - val_accuracy: 0.7169
# Epoch 65/500
# 1/1 [==============================] - 1s 607ms/step - loss: 1.2226 - accuracy: 0.7024 - val_loss: 1.2185 - val_accuracy: 0.7152
# Epoch 66/500
# 1/1 [==============================] - 1s 585ms/step - loss: 1.1990 - accuracy: 0.7098 - val_loss: 1.2118 - val_accuracy: 0.7161
# Epoch 67/500
# 1/1 [==============================] - 1s 565ms/step - loss: 1.1834 - accuracy: 0.7137 - val_loss: 1.2051 - val_accuracy: 0.7178
# Epoch 68/500
# 1/1 [==============================] - 1s 538ms/step - loss: 1.1796 - accuracy: 0.7181 - val_loss: 1.1974 - val_accuracy: 0.7203
# Epoch 69/500
# 1/1 [==============================] - 1s 566ms/step - loss: 1.1754 - accuracy: 0.7150 - val_loss: 1.1912 - val_accuracy: 0.7211
# Epoch 70/500
# 1/1 [==============================] - 1s 540ms/step - loss: 1.1580 - accuracy: 0.7198 - val_loss: 1.1854 - val_accuracy: 0.7194
# Epoch 71/500
# 1/1 [==============================] - 1s 551ms/step - loss: 1.1547 - accuracy: 0.7177 - val_loss: 1.1818 - val_accuracy: 0.7136
# Epoch 72/500
# 1/1 [==============================] - 1s 557ms/step - loss: 1.1424 - accuracy: 0.7131 - val_loss: 1.1743 - val_accuracy: 0.7178
# Epoch 73/500
# 1/1 [==============================] - 1s 566ms/step - loss: 1.1396 - accuracy: 0.7156 - val_loss: 1.1660 - val_accuracy: 0.7219
# Epoch 74/500
# 1/1 [==============================] - 1s 542ms/step - loss: 1.1322 - accuracy: 0.7181 - val_loss: 1.1587 - val_accuracy: 0.7219
# Epoch 75/500
# 1/1 [==============================] - 1s 605ms/step - loss: 1.1252 - accuracy: 0.7255 - val_loss: 1.1512 - val_accuracy: 0.7236
# Epoch 76/500
# 1/1 [==============================] - 1s 587ms/step - loss: 1.1100 - accuracy: 0.7230 - val_loss: 1.1227 - val_accuracy: 0.7270
# Epoch 77/500
# 1/1 [==============================] - 1s 612ms/step - loss: 1.0977 - accuracy: 0.7020 - val_loss: 0.9766 - val_accuracy: 0.7194
# Epoch 78/500
# 1/1 [==============================] - 1s 640ms/step - loss: 1.0521 - accuracy: 0.6641 - val_loss: 0.9603 - val_accuracy: 0.7203
# Epoch 79/500
# 1/1 [==============================] - 1s 645ms/step - loss: 1.0275 - accuracy: 0.6781 - val_loss: 1.0025 - val_accuracy: 0.7362
# Epoch 80/500
# 1/1 [==============================] - 1s 592ms/step - loss: 1.0002 - accuracy: 0.7117 - val_loss: 0.9723 - val_accuracy: 0.7412
# Epoch 81/500
# 1/1 [==============================] - 1s 623ms/step - loss: 0.9656 - accuracy: 0.7207 - val_loss: 0.9317 - val_accuracy: 0.7253
# Epoch 82/500
# 1/1 [==============================] - 1s 603ms/step - loss: 0.9515 - accuracy: 0.6984 - val_loss: 0.9203 - val_accuracy: 0.7236
# Epoch 83/500
# 1/1 [==============================] - 1s 623ms/step - loss: 0.9594 - accuracy: 0.7064 - val_loss: 0.9158 - val_accuracy: 0.7529
# Epoch 84/500
# 1/1 [==============================] - 1s 549ms/step - loss: 0.9248 - accuracy: 0.7297 - val_loss: 0.8948 - val_accuracy: 0.7479
# Epoch 85/500
# 1/1 [==============================] - 1s 552ms/step - loss: 0.9033 - accuracy: 0.7295 - val_loss: 0.9018 - val_accuracy: 0.7295
# Epoch 86/500
# 1/1 [==============================] - 1s 541ms/step - loss: 0.9188 - accuracy: 0.7246 - val_loss: 0.8661 - val_accuracy: 0.7412
# Epoch 87/500
# 1/1 [==============================] - 1s 535ms/step - loss: 0.8759 - accuracy: 0.7343 - val_loss: 0.9339 - val_accuracy: 0.7663
# Epoch 88/500
# 1/1 [==============================] - 1s 544ms/step - loss: 0.9252 - accuracy: 0.7481 - val_loss: 0.8518 - val_accuracy: 0.7446
# Epoch 89/500
# 1/1 [==============================] - 1s 537ms/step - loss: 0.8588 - accuracy: 0.7408 - val_loss: 0.8706 - val_accuracy: 0.7395
# Epoch 90/500
# 1/1 [==============================] - 1s 536ms/step - loss: 0.8714 - accuracy: 0.7324 - val_loss: 0.8274 - val_accuracy: 0.7605
# Epoch 91/500
# 1/1 [==============================] - 1s 561ms/step - loss: 0.8313 - accuracy: 0.7475 - val_loss: 0.8749 - val_accuracy: 0.7730
# Epoch 92/500
# 1/1 [==============================] - 1s 565ms/step - loss: 0.8761 - accuracy: 0.7487 - val_loss: 0.8192 - val_accuracy: 0.7554
# Epoch 93/500
# 1/1 [==============================] - 1s 552ms/step - loss: 0.8349 - accuracy: 0.7475 - val_loss: 0.8407 - val_accuracy: 0.7471
# Epoch 94/500
# 1/1 [==============================] - 1s 540ms/step - loss: 0.8555 - accuracy: 0.7435 - val_loss: 0.7945 - val_accuracy: 0.7739
# Epoch 95/500
# 1/1 [==============================] - 1s 558ms/step - loss: 0.8134 - accuracy: 0.7567 - val_loss: 0.8376 - val_accuracy: 0.7747
# Epoch 96/500
# 1/1 [==============================] - 1s 565ms/step - loss: 0.8525 - accuracy: 0.7578 - val_loss: 0.7939 - val_accuracy: 0.7680
# Epoch 97/500
# 1/1 [==============================] - 1s 540ms/step - loss: 0.8040 - accuracy: 0.7502 - val_loss: 0.8081 - val_accuracy: 0.7638
# Epoch 98/500
# 1/1 [==============================] - 1s 560ms/step - loss: 0.8120 - accuracy: 0.7483 - val_loss: 0.7660 - val_accuracy: 0.7839
# Epoch 99/500
# 1/1 [==============================] - 1s 545ms/step - loss: 0.7819 - accuracy: 0.7697 - val_loss: 0.7820 - val_accuracy: 0.7856
# Epoch 100/500
# 1/1 [==============================] - 1s 585ms/step - loss: 0.7943 - accuracy: 0.7634 - val_loss: 0.7615 - val_accuracy: 0.7764
# Epoch 101/500
# 1/1 [==============================] - 1s 619ms/step - loss: 0.7685 - accuracy: 0.7649 - val_loss: 0.7799 - val_accuracy: 0.7672
# Epoch 102/500
# 1/1 [==============================] - 1s 562ms/step - loss: 0.7843 - accuracy: 0.7613 - val_loss: 0.7496 - val_accuracy: 0.7831
# Epoch 103/500
# 1/1 [==============================] - 1s 575ms/step - loss: 0.7443 - accuracy: 0.7785 - val_loss: 0.7541 - val_accuracy: 0.7931
# Epoch 104/500
# 1/1 [==============================] - 1s 606ms/step - loss: 0.7619 - accuracy: 0.7770 - val_loss: 0.7303 - val_accuracy: 0.7915
# Epoch 105/500
# 1/1 [==============================] - 1s 605ms/step - loss: 0.7367 - accuracy: 0.7743 - val_loss: 0.7386 - val_accuracy: 0.7764
# Epoch 106/500
# 1/1 [==============================] - 1s 572ms/step - loss: 0.7620 - accuracy: 0.7630 - val_loss: 0.7102 - val_accuracy: 0.7881
# Epoch 107/500
# 1/1 [==============================] - 1s 588ms/step - loss: 0.7277 - accuracy: 0.7758 - val_loss: 0.7009 - val_accuracy: 0.7998
# Epoch 108/500
# 1/1 [==============================] - 1s 600ms/step - loss: 0.7216 - accuracy: 0.7768 - val_loss: 0.7140 - val_accuracy: 0.7940
# Epoch 109/500
# 1/1 [==============================] - 1s 590ms/step - loss: 0.7268 - accuracy: 0.7804 - val_loss: 0.6984 - val_accuracy: 0.7956
# Epoch 110/500
# 1/1 [==============================] - 1s 577ms/step - loss: 0.7070 - accuracy: 0.7848 - val_loss: 0.7004 - val_accuracy: 0.8015
# Epoch 111/500
# 1/1 [==============================] - 1s 562ms/step - loss: 0.7081 - accuracy: 0.7850 - val_loss: 0.6839 - val_accuracy: 0.7965
# Epoch 112/500
# 1/1 [==============================] - 1s 613ms/step - loss: 0.6978 - accuracy: 0.7848 - val_loss: 0.6820 - val_accuracy: 0.7956
# Epoch 113/500
# 1/1 [==============================] - 1s 545ms/step - loss: 0.6910 - accuracy: 0.7821 - val_loss: 0.6637 - val_accuracy: 0.8049
# Epoch 114/500
# 1/1 [==============================] - 1s 620ms/step - loss: 0.6902 - accuracy: 0.7795 - val_loss: 0.6596 - val_accuracy: 0.8174
# Epoch 115/500
# 1/1 [==============================] - 1s 582ms/step - loss: 0.6921 - accuracy: 0.7879 - val_loss: 0.6732 - val_accuracy: 0.8049
# Epoch 116/500
# 1/1 [==============================] - 1s 586ms/step - loss: 0.6916 - accuracy: 0.7921 - val_loss: 0.6631 - val_accuracy: 0.8124
# Epoch 117/500
# 1/1 [==============================] - 1s 570ms/step - loss: 0.6659 - accuracy: 0.7972 - val_loss: 0.6615 - val_accuracy: 0.8208
# Epoch 118/500
# 1/1 [==============================] - 1s 566ms/step - loss: 0.6762 - accuracy: 0.7969 - val_loss: 0.6361 - val_accuracy: 0.8124
# Epoch 119/500
# 1/1 [==============================] - 1s 555ms/step - loss: 0.6478 - accuracy: 0.8003 - val_loss: 0.6276 - val_accuracy: 0.8141
# Epoch 120/500
# 1/1 [==============================] - 1s 560ms/step - loss: 0.6587 - accuracy: 0.8011 - val_loss: 0.6145 - val_accuracy: 0.8250
# Epoch 121/500
# 1/1 [==============================] - 1s 571ms/step - loss: 0.6487 - accuracy: 0.8028 - val_loss: 0.6087 - val_accuracy: 0.8233
# Epoch 122/500
# 1/1 [==============================] - 1s 543ms/step - loss: 0.6325 - accuracy: 0.7959 - val_loss: 0.6132 - val_accuracy: 0.8258
# Epoch 123/500
# 1/1 [==============================] - 1s 534ms/step - loss: 0.6302 - accuracy: 0.8024 - val_loss: 0.6196 - val_accuracy: 0.8258
# Epoch 124/500
# 1/1 [==============================] - 1s 558ms/step - loss: 0.6372 - accuracy: 0.8116 - val_loss: 0.6097 - val_accuracy: 0.8250
# Epoch 125/500
# 1/1 [==============================] - 1s 542ms/step - loss: 0.6281 - accuracy: 0.8047 - val_loss: 0.5929 - val_accuracy: 0.8300
# Epoch 126/500
# 1/1 [==============================] - 1s 566ms/step - loss: 0.6139 - accuracy: 0.8078 - val_loss: 0.5843 - val_accuracy: 0.8367
# Epoch 127/500
# 1/1 [==============================] - 1s 536ms/step - loss: 0.6200 - accuracy: 0.8072 - val_loss: 0.5893 - val_accuracy: 0.8216
# Epoch 128/500
# 1/1 [==============================] - 1s 558ms/step - loss: 0.6013 - accuracy: 0.8139 - val_loss: 0.5816 - val_accuracy: 0.8342
# Epoch 129/500
# 1/1 [==============================] - 1s 543ms/step - loss: 0.6047 - accuracy: 0.8204 - val_loss: 0.5805 - val_accuracy: 0.8333
# Epoch 130/500
# 1/1 [==============================] - 1s 553ms/step - loss: 0.6053 - accuracy: 0.8122 - val_loss: 0.5784 - val_accuracy: 0.8258
# Epoch 131/500
# 1/1 [==============================] - 1s 551ms/step - loss: 0.6017 - accuracy: 0.8104 - val_loss: 0.5721 - val_accuracy: 0.8333
# Epoch 132/500
# 1/1 [==============================] - 1s 542ms/step - loss: 0.5840 - accuracy: 0.8181 - val_loss: 0.5636 - val_accuracy: 0.8417
# Epoch 133/500
# 1/1 [==============================] - 1s 556ms/step - loss: 0.5850 - accuracy: 0.8196 - val_loss: 0.5680 - val_accuracy: 0.8317
# Epoch 134/500
# 1/1 [==============================] - 1s 576ms/step - loss: 0.5911 - accuracy: 0.8206 - val_loss: 0.5551 - val_accuracy: 0.8400
# Epoch 135/500
# 1/1 [==============================] - 1s 534ms/step - loss: 0.5898 - accuracy: 0.8206 - val_loss: 0.5617 - val_accuracy: 0.8325
# Epoch 136/500
# 1/1 [==============================] - 1s 532ms/step - loss: 0.5713 - accuracy: 0.8202 - val_loss: 0.5644 - val_accuracy: 0.8375
# Epoch 137/500
# 1/1 [==============================] - 1s 540ms/step - loss: 0.5787 - accuracy: 0.8148 - val_loss: 0.5595 - val_accuracy: 0.8409
# Epoch 138/500
# 1/1 [==============================] - 1s 527ms/step - loss: 0.5718 - accuracy: 0.8261 - val_loss: 0.5439 - val_accuracy: 0.8375
# Epoch 139/500
# 1/1 [==============================] - 1s 529ms/step - loss: 0.5669 - accuracy: 0.8194 - val_loss: 0.5358 - val_accuracy: 0.8400
# Epoch 140/500
# 1/1 [==============================] - 1s 531ms/step - loss: 0.5570 - accuracy: 0.8284 - val_loss: 0.5405 - val_accuracy: 0.8459
# Epoch 141/500
# 1/1 [==============================] - 1s 545ms/step - loss: 0.5630 - accuracy: 0.8223 - val_loss: 0.5507 - val_accuracy: 0.8459
# Epoch 142/500
# 1/1 [==============================] - 1s 533ms/step - loss: 0.5569 - accuracy: 0.8326 - val_loss: 0.5408 - val_accuracy: 0.8392
# Epoch 143/500
# 1/1 [==============================] - 1s 567ms/step - loss: 0.5471 - accuracy: 0.8311 - val_loss: 0.5284 - val_accuracy: 0.8459
# Epoch 144/500
# 1/1 [==============================] - 1s 534ms/step - loss: 0.5519 - accuracy: 0.8280 - val_loss: 0.5277 - val_accuracy: 0.8476
# Epoch 145/500
# 1/1 [==============================] - 1s 542ms/step - loss: 0.5530 - accuracy: 0.8334 - val_loss: 0.5412 - val_accuracy: 0.8392
# Epoch 146/500
# 1/1 [==============================] - 1s 534ms/step - loss: 0.5597 - accuracy: 0.8200 - val_loss: 0.5411 - val_accuracy: 0.8467
# Epoch 147/500
# 1/1 [==============================] - 1s 538ms/step - loss: 0.5519 - accuracy: 0.8399 - val_loss: 0.5278 - val_accuracy: 0.8526
# Epoch 148/500
# 1/1 [==============================] - 1s 544ms/step - loss: 0.5402 - accuracy: 0.8326 - val_loss: 0.5177 - val_accuracy: 0.8484
# Epoch 149/500
# 1/1 [==============================] - 1s 531ms/step - loss: 0.5226 - accuracy: 0.8349 - val_loss: 0.5136 - val_accuracy: 0.8492
# Epoch 150/500
# 1/1 [==============================] - 1s 534ms/step - loss: 0.5360 - accuracy: 0.8309 - val_loss: 0.5160 - val_accuracy: 0.8459
# Epoch 151/500
# 1/1 [==============================] - 1s 562ms/step - loss: 0.5170 - accuracy: 0.8330 - val_loss: 0.5254 - val_accuracy: 0.8492
# Epoch 152/500
# 1/1 [==============================] - 1s 547ms/step - loss: 0.5424 - accuracy: 0.8361 - val_loss: 0.5235 - val_accuracy: 0.8442
# Epoch 153/500
# 1/1 [==============================] - 1s 570ms/step - loss: 0.5214 - accuracy: 0.8384 - val_loss: 0.5191 - val_accuracy: 0.8442
# Epoch 154/500
# 1/1 [==============================] - 1s 540ms/step - loss: 0.5218 - accuracy: 0.8301 - val_loss: 0.5112 - val_accuracy: 0.8509
# Epoch 155/500
# 1/1 [==============================] - 1s 552ms/step - loss: 0.5215 - accuracy: 0.8393 - val_loss: 0.5225 - val_accuracy: 0.8467
# Epoch 156/500
# 1/1 [==============================] - 1s 542ms/step - loss: 0.5248 - accuracy: 0.8311 - val_loss: 0.5234 - val_accuracy: 0.8518
# Epoch 157/500
# 1/1 [==============================] - 1s 549ms/step - loss: 0.5358 - accuracy: 0.8340 - val_loss: 0.5301 - val_accuracy: 0.8417
# Epoch 158/500
# 1/1 [==============================] - 1s 562ms/step - loss: 0.5200 - accuracy: 0.8263 - val_loss: 0.5292 - val_accuracy: 0.8400
# Epoch 159/500
# 1/1 [==============================] - 1s 554ms/step - loss: 0.5175 - accuracy: 0.8315 - val_loss: 0.5485 - val_accuracy: 0.8526
# Epoch 160/500
# 1/1 [==============================] - 1s 542ms/step - loss: 0.5396 - accuracy: 0.8386 - val_loss: 0.5184 - val_accuracy: 0.8476
# Epoch 161/500
# 1/1 [==============================] - 1s 566ms/step - loss: 0.5290 - accuracy: 0.8355 - val_loss: 0.5244 - val_accuracy: 0.8476
# Epoch 162/500
# 1/1 [==============================] - 1s 557ms/step - loss: 0.5718 - accuracy: 0.8231 - val_loss: 0.5050 - val_accuracy: 0.8526
# Epoch 163/500
# 1/1 [==============================] - 1s 558ms/step - loss: 0.5283 - accuracy: 0.8401 - val_loss: 0.5151 - val_accuracy: 0.8559
# Epoch 164/500
# 1/1 [==============================] - 1s 562ms/step - loss: 0.5027 - accuracy: 0.8428 - val_loss: 0.6024 - val_accuracy: 0.8467
# Epoch 165/500
# 1/1 [==============================] - 1s 570ms/step - loss: 0.5764 - accuracy: 0.8418 - val_loss: 0.5834 - val_accuracy: 0.8283
# Epoch 166/500
# 1/1 [==============================] - 1s 528ms/step - loss: 0.5703 - accuracy: 0.8248 - val_loss: 0.5111 - val_accuracy: 0.8568
# Epoch 167/500
# 1/1 [==============================] - 1s 554ms/step - loss: 0.5246 - accuracy: 0.8345 - val_loss: 0.5483 - val_accuracy: 0.8484
# Epoch 168/500
# 1/1 [==============================] - 1s 532ms/step - loss: 0.6120 - accuracy: 0.8018 - val_loss: 0.5173 - val_accuracy: 0.8501
# Epoch 169/500
# 1/1 [==============================] - 1s 528ms/step - loss: 0.5125 - accuracy: 0.8389 - val_loss: 0.5405 - val_accuracy: 0.8392
# Epoch 170/500
# 1/1 [==============================] - 1s 566ms/step - loss: 0.5386 - accuracy: 0.8303 - val_loss: 0.6070 - val_accuracy: 0.8451
# Epoch 171/500
# 1/1 [==============================] - 1s 542ms/step - loss: 0.5857 - accuracy: 0.8342 - val_loss: 0.5529 - val_accuracy: 0.8317
# Epoch 172/500
# 1/1 [==============================] - 1s 535ms/step - loss: 0.5384 - accuracy: 0.8233 - val_loss: 0.5623 - val_accuracy: 0.8241
# Epoch 173/500
# 1/1 [==============================] - 1s 538ms/step - loss: 0.5550 - accuracy: 0.8261 - val_loss: 0.5351 - val_accuracy: 0.8484
# Epoch 174/500
# 1/1 [==============================] - 1s 554ms/step - loss: 0.5183 - accuracy: 0.8378 - val_loss: 0.5543 - val_accuracy: 0.8559
# Epoch 175/500
# 1/1 [==============================] - 1s 547ms/step - loss: 0.5468 - accuracy: 0.8435 - val_loss: 0.5083 - val_accuracy: 0.8543
# Epoch 176/500
# 1/1 [==============================] - 1s 548ms/step - loss: 0.5127 - accuracy: 0.8342 - val_loss: 0.5176 - val_accuracy: 0.8543
# Epoch 177/500
# 1/1 [==============================] - 1s 574ms/step - loss: 0.5266 - accuracy: 0.8372 - val_loss: 0.4885 - val_accuracy: 0.8626
# Epoch 178/500
# 1/1 [==============================] - 1s 530ms/step - loss: 0.4930 - accuracy: 0.8445 - val_loss: 0.4970 - val_accuracy: 0.8626
# Epoch 179/500
# 1/1 [==============================] - 1s 521ms/step - loss: 0.5025 - accuracy: 0.8345 - val_loss: 0.4864 - val_accuracy: 0.8668
# Epoch 180/500
# 1/1 [==============================] - 1s 550ms/step - loss: 0.4797 - accuracy: 0.8567 - val_loss: 0.4909 - val_accuracy: 0.8660
# Epoch 181/500
# 1/1 [==============================] - 1s 537ms/step - loss: 0.4851 - accuracy: 0.8453 - val_loss: 0.4951 - val_accuracy: 0.8576
# Epoch 182/500
# 1/1 [==============================] - 1s 532ms/step - loss: 0.4880 - accuracy: 0.8468 - val_loss: 0.4980 - val_accuracy: 0.8543
# Epoch 183/500
# 1/1 [==============================] - 1s 529ms/step - loss: 0.4926 - accuracy: 0.8462 - val_loss: 0.5063 - val_accuracy: 0.8593
# Epoch 184/500
# 1/1 [==============================] - 1s 559ms/step - loss: 0.4797 - accuracy: 0.8527 - val_loss: 0.4980 - val_accuracy: 0.8585
# Epoch 185/500
# 1/1 [==============================] - 1s 573ms/step - loss: 0.4749 - accuracy: 0.8548 - val_loss: 0.4841 - val_accuracy: 0.8618
# Epoch 186/500
# 1/1 [==============================] - 1s 577ms/step - loss: 0.4682 - accuracy: 0.8485 - val_loss: 0.4703 - val_accuracy: 0.8668
# Epoch 187/500
# 1/1 [==============================] - 1s 546ms/step - loss: 0.4655 - accuracy: 0.8548 - val_loss: 0.4674 - val_accuracy: 0.8693
# Epoch 188/500
# 1/1 [==============================] - 1s 552ms/step - loss: 0.4612 - accuracy: 0.8590 - val_loss: 0.4681 - val_accuracy: 0.8677
# Epoch 189/500
# 1/1 [==============================] - 1s 585ms/step - loss: 0.4499 - accuracy: 0.8558 - val_loss: 0.4712 - val_accuracy: 0.8702
# Epoch 190/500
# 1/1 [==============================] - 1s 576ms/step - loss: 0.4583 - accuracy: 0.8556 - val_loss: 0.4666 - val_accuracy: 0.8685
# Epoch 191/500
# 1/1 [==============================] - 1s 579ms/step - loss: 0.4485 - accuracy: 0.8565 - val_loss: 0.4583 - val_accuracy: 0.8643
# Epoch 192/500
# 1/1 [==============================] - 1s 595ms/step - loss: 0.4521 - accuracy: 0.8573 - val_loss: 0.4540 - val_accuracy: 0.8660
# Epoch 193/500
# 1/1 [==============================] - 1s 574ms/step - loss: 0.4509 - accuracy: 0.8575 - val_loss: 0.4559 - val_accuracy: 0.8652
# Epoch 194/500
# 1/1 [==============================] - 1s 579ms/step - loss: 0.4489 - accuracy: 0.8579 - val_loss: 0.4509 - val_accuracy: 0.8702
# Epoch 195/500
# 1/1 [==============================] - 1s 559ms/step - loss: 0.4509 - accuracy: 0.8556 - val_loss: 0.4511 - val_accuracy: 0.8685
# Epoch 196/500
# 1/1 [==============================] - 1s 588ms/step - loss: 0.4275 - accuracy: 0.8640 - val_loss: 0.4514 - val_accuracy: 0.8727
# Epoch 197/500
# 1/1 [==============================] - 1s 565ms/step - loss: 0.4424 - accuracy: 0.8606 - val_loss: 0.4516 - val_accuracy: 0.8719
# Epoch 198/500
# 1/1 [==============================] - 1s 563ms/step - loss: 0.4474 - accuracy: 0.8613 - val_loss: 0.4489 - val_accuracy: 0.8693
# Epoch 199/500
# 1/1 [==============================] - 1s 580ms/step - loss: 0.4317 - accuracy: 0.8632 - val_loss: 0.4445 - val_accuracy: 0.8693
# Epoch 200/500
# 1/1 [==============================] - 1s 551ms/step - loss: 0.4443 - accuracy: 0.8596 - val_loss: 0.4408 - val_accuracy: 0.8735
# Epoch 201/500
# 1/1 [==============================] - 1s 574ms/step - loss: 0.4319 - accuracy: 0.8634 - val_loss: 0.4488 - val_accuracy: 0.8702
# Epoch 202/500
# 1/1 [==============================] - 1s 569ms/step - loss: 0.4372 - accuracy: 0.8594 - val_loss: 0.4429 - val_accuracy: 0.8710
# Epoch 203/500
# 1/1 [==============================] - 1s 598ms/step - loss: 0.4224 - accuracy: 0.8604 - val_loss: 0.4415 - val_accuracy: 0.8744
# Epoch 204/500
# 1/1 [==============================] - 1s 586ms/step - loss: 0.4216 - accuracy: 0.8630 - val_loss: 0.4320 - val_accuracy: 0.8760
# Epoch 205/500
# 1/1 [==============================] - 1s 599ms/step - loss: 0.4266 - accuracy: 0.8692 - val_loss: 0.4418 - val_accuracy: 0.8710
# Epoch 206/500
# 1/1 [==============================] - 1s 606ms/step - loss: 0.4290 - accuracy: 0.8634 - val_loss: 0.4352 - val_accuracy: 0.8760
# Epoch 207/500
# 1/1 [==============================] - 1s 560ms/step - loss: 0.4203 - accuracy: 0.8674 - val_loss: 0.4318 - val_accuracy: 0.8760
# Epoch 208/500
# 1/1 [==============================] - 1s 575ms/step - loss: 0.4387 - accuracy: 0.8596 - val_loss: 0.4282 - val_accuracy: 0.8769
# Epoch 209/500
# 1/1 [==============================] - 1s 563ms/step - loss: 0.4190 - accuracy: 0.8661 - val_loss: 0.4334 - val_accuracy: 0.8760
# Epoch 210/500
# 1/1 [==============================] - 1s 568ms/step - loss: 0.4248 - accuracy: 0.8596 - val_loss: 0.4320 - val_accuracy: 0.8752
# Epoch 211/500
# 1/1 [==============================] - 1s 574ms/step - loss: 0.4188 - accuracy: 0.8682 - val_loss: 0.4285 - val_accuracy: 0.8744
# Epoch 212/500
# 1/1 [==============================] - 1s 582ms/step - loss: 0.4122 - accuracy: 0.8701 - val_loss: 0.4238 - val_accuracy: 0.8802
# Epoch 213/500
# 1/1 [==============================] - 1s 570ms/step - loss: 0.4091 - accuracy: 0.8711 - val_loss: 0.4239 - val_accuracy: 0.8794
# Epoch 214/500
# 1/1 [==============================] - 1s 593ms/step - loss: 0.4018 - accuracy: 0.8694 - val_loss: 0.4236 - val_accuracy: 0.8760
# Epoch 215/500
# 1/1 [==============================] - 1s 573ms/step - loss: 0.3961 - accuracy: 0.8774 - val_loss: 0.4198 - val_accuracy: 0.8769
# Epoch 216/500
# 1/1 [==============================] - 1s 596ms/step - loss: 0.4102 - accuracy: 0.8747 - val_loss: 0.4216 - val_accuracy: 0.8760
# Epoch 217/500
# 1/1 [==============================] - 1s 562ms/step - loss: 0.4146 - accuracy: 0.8711 - val_loss: 0.4215 - val_accuracy: 0.8752
# Epoch 218/500
# 1/1 [==============================] - 1s 556ms/step - loss: 0.4021 - accuracy: 0.8720 - val_loss: 0.4204 - val_accuracy: 0.8777
# Epoch 219/500
# 1/1 [==============================] - 1s 582ms/step - loss: 0.4008 - accuracy: 0.8718 - val_loss: 0.4160 - val_accuracy: 0.8794
# Epoch 220/500
# 1/1 [==============================] - 1s 579ms/step - loss: 0.3944 - accuracy: 0.8694 - val_loss: 0.4194 - val_accuracy: 0.8777
# Epoch 221/500
# 1/1 [==============================] - 1s 572ms/step - loss: 0.3956 - accuracy: 0.8751 - val_loss: 0.4170 - val_accuracy: 0.8811
# Epoch 222/500
# 1/1 [==============================] - 1s 576ms/step - loss: 0.4170 - accuracy: 0.8699 - val_loss: 0.4140 - val_accuracy: 0.8819
# Epoch 223/500
# 1/1 [==============================] - 1s 596ms/step - loss: 0.3869 - accuracy: 0.8768 - val_loss: 0.4125 - val_accuracy: 0.8786
# Epoch 224/500
# 1/1 [==============================] - 1s 603ms/step - loss: 0.3942 - accuracy: 0.8778 - val_loss: 0.4096 - val_accuracy: 0.8811
# Epoch 225/500
# 1/1 [==============================] - 1s 597ms/step - loss: 0.3854 - accuracy: 0.8749 - val_loss: 0.4126 - val_accuracy: 0.8802
# Epoch 226/500
# 1/1 [==============================] - 1s 591ms/step - loss: 0.3969 - accuracy: 0.8728 - val_loss: 0.4092 - val_accuracy: 0.8802
# Epoch 227/500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.3867 - accuracy: 0.8793 - val_loss: 0.4070 - val_accuracy: 0.8811
# Epoch 228/500
# 1/1 [==============================] - 1s 568ms/step - loss: 0.3944 - accuracy: 0.8782 - val_loss: 0.4082 - val_accuracy: 0.8819
# Epoch 229/500
# 1/1 [==============================] - 1s 577ms/step - loss: 0.3863 - accuracy: 0.8843 - val_loss: 0.4082 - val_accuracy: 0.8827
# Epoch 230/500
# 1/1 [==============================] - 1s 602ms/step - loss: 0.3794 - accuracy: 0.8843 - val_loss: 0.4078 - val_accuracy: 0.8794
# Epoch 231/500
# 1/1 [==============================] - 1s 604ms/step - loss: 0.3841 - accuracy: 0.8810 - val_loss: 0.3985 - val_accuracy: 0.8836
# Epoch 232/500
# 1/1 [==============================] - 1s 615ms/step - loss: 0.3757 - accuracy: 0.8826 - val_loss: 0.4002 - val_accuracy: 0.8836
# Epoch 233/500
# 1/1 [==============================] - 1s 611ms/step - loss: 0.3931 - accuracy: 0.8785 - val_loss: 0.4010 - val_accuracy: 0.8836
# Epoch 234/500
# 1/1 [==============================] - 1s 624ms/step - loss: 0.3813 - accuracy: 0.8791 - val_loss: 0.4000 - val_accuracy: 0.8836
# Epoch 235/500
# 1/1 [==============================] - 1s 586ms/step - loss: 0.3928 - accuracy: 0.8743 - val_loss: 0.3968 - val_accuracy: 0.8844
# Epoch 236/500
# 1/1 [==============================] - 1s 610ms/step - loss: 0.3834 - accuracy: 0.8799 - val_loss: 0.3985 - val_accuracy: 0.8827
# Epoch 237/500
# 1/1 [==============================] - 1s 575ms/step - loss: 0.3854 - accuracy: 0.8818 - val_loss: 0.4017 - val_accuracy: 0.8802
# Epoch 238/500
# 1/1 [==============================] - 1s 606ms/step - loss: 0.3593 - accuracy: 0.8799 - val_loss: 0.3945 - val_accuracy: 0.8861
# Epoch 239/500
# 1/1 [==============================] - 1s 618ms/step - loss: 0.3783 - accuracy: 0.8770 - val_loss: 0.3972 - val_accuracy: 0.8844
# Epoch 240/500
# 1/1 [==============================] - 1s 613ms/step - loss: 0.3868 - accuracy: 0.8803 - val_loss: 0.3956 - val_accuracy: 0.8844
# Epoch 241/500
# 1/1 [==============================] - 1s 602ms/step - loss: 0.3721 - accuracy: 0.8814 - val_loss: 0.3997 - val_accuracy: 0.8827
# Epoch 242/500
# 1/1 [==============================] - 1s 568ms/step - loss: 0.3786 - accuracy: 0.8778 - val_loss: 0.3914 - val_accuracy: 0.8869
# Epoch 243/500
# 1/1 [==============================] - 1s 575ms/step - loss: 0.3660 - accuracy: 0.8812 - val_loss: 0.3922 - val_accuracy: 0.8861
# Epoch 244/500
# 1/1 [==============================] - 1s 591ms/step - loss: 0.3627 - accuracy: 0.8837 - val_loss: 0.4001 - val_accuracy: 0.8802
# Epoch 245/500
# 1/1 [==============================] - 1s 589ms/step - loss: 0.3568 - accuracy: 0.8826 - val_loss: 0.3994 - val_accuracy: 0.8819
# Epoch 246/500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.3705 - accuracy: 0.8826 - val_loss: 0.3948 - val_accuracy: 0.8886
# Epoch 247/500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.3742 - accuracy: 0.8887 - val_loss: 0.3882 - val_accuracy: 0.8903
# Epoch 248/500
# 1/1 [==============================] - 1s 583ms/step - loss: 0.3598 - accuracy: 0.8829 - val_loss: 0.4009 - val_accuracy: 0.8844
# Epoch 249/500
# 1/1 [==============================] - 1s 588ms/step - loss: 0.3544 - accuracy: 0.8858 - val_loss: 0.3918 - val_accuracy: 0.8853
# Epoch 250/500
# 1/1 [==============================] - 1s 580ms/step - loss: 0.3613 - accuracy: 0.8860 - val_loss: 0.3857 - val_accuracy: 0.8911
# Epoch 251/500
# 1/1 [==============================] - 1s 585ms/step - loss: 0.3595 - accuracy: 0.8929 - val_loss: 0.3881 - val_accuracy: 0.8869
# Epoch 252/500
# 1/1 [==============================] - 1s 601ms/step - loss: 0.3622 - accuracy: 0.8873 - val_loss: 0.3947 - val_accuracy: 0.8827
# Epoch 253/500
# 1/1 [==============================] - 1s 594ms/step - loss: 0.3553 - accuracy: 0.8854 - val_loss: 0.3882 - val_accuracy: 0.8853
# Epoch 254/500
# 1/1 [==============================] - 1s 598ms/step - loss: 0.3501 - accuracy: 0.8881 - val_loss: 0.3853 - val_accuracy: 0.8861
# Epoch 255/500
# 1/1 [==============================] - 1s 592ms/step - loss: 0.3407 - accuracy: 0.8915 - val_loss: 0.3897 - val_accuracy: 0.8878
# Epoch 256/500
# 1/1 [==============================] - 1s 562ms/step - loss: 0.3532 - accuracy: 0.8810 - val_loss: 0.3904 - val_accuracy: 0.8886
# Epoch 257/500
# 1/1 [==============================] - 1s 586ms/step - loss: 0.3490 - accuracy: 0.8894 - val_loss: 0.3860 - val_accuracy: 0.8903
# Epoch 258/500
# 1/1 [==============================] - 1s 574ms/step - loss: 0.3490 - accuracy: 0.8856 - val_loss: 0.3845 - val_accuracy: 0.8886
# Epoch 259/500
# 1/1 [==============================] - 1s 585ms/step - loss: 0.3525 - accuracy: 0.8912 - val_loss: 0.3859 - val_accuracy: 0.8903
# Epoch 260/500
# 1/1 [==============================] - 1s 607ms/step - loss: 0.3450 - accuracy: 0.8925 - val_loss: 0.3829 - val_accuracy: 0.8894
# Epoch 261/500
# 1/1 [==============================] - 1s 582ms/step - loss: 0.3479 - accuracy: 0.8906 - val_loss: 0.3850 - val_accuracy: 0.8878
# Epoch 262/500
# 1/1 [==============================] - 1s 570ms/step - loss: 0.3473 - accuracy: 0.8910 - val_loss: 0.3841 - val_accuracy: 0.8894
# Epoch 263/500
# 1/1 [==============================] - 1s 581ms/step - loss: 0.3472 - accuracy: 0.8894 - val_loss: 0.3824 - val_accuracy: 0.8861
# Epoch 264/500
# 1/1 [==============================] - 1s 603ms/step - loss: 0.3321 - accuracy: 0.8952 - val_loss: 0.3823 - val_accuracy: 0.8894
# Epoch 265/500
# 1/1 [==============================] - 1s 621ms/step - loss: 0.3490 - accuracy: 0.8885 - val_loss: 0.3805 - val_accuracy: 0.8911
# Epoch 266/500
# 1/1 [==============================] - 1s 582ms/step - loss: 0.3414 - accuracy: 0.8900 - val_loss: 0.3812 - val_accuracy: 0.8894
# Epoch 267/500
# 1/1 [==============================] - 1s 583ms/step - loss: 0.3468 - accuracy: 0.8883 - val_loss: 0.3817 - val_accuracy: 0.8878
# Epoch 268/500
# 1/1 [==============================] - 1s 602ms/step - loss: 0.3398 - accuracy: 0.8950 - val_loss: 0.3791 - val_accuracy: 0.8894
# Epoch 269/500
# 1/1 [==============================] - 1s 591ms/step - loss: 0.3326 - accuracy: 0.8917 - val_loss: 0.3848 - val_accuracy: 0.8853
# Epoch 270/500
# 1/1 [==============================] - 1s 588ms/step - loss: 0.3311 - accuracy: 0.8898 - val_loss: 0.3759 - val_accuracy: 0.8911
# Epoch 271/500
# 1/1 [==============================] - 1s 580ms/step - loss: 0.3279 - accuracy: 0.8973 - val_loss: 0.3784 - val_accuracy: 0.8894
# Epoch 272/500
# 1/1 [==============================] - 1s 609ms/step - loss: 0.3276 - accuracy: 0.8948 - val_loss: 0.3793 - val_accuracy: 0.8894
# Epoch 273/500
# 1/1 [==============================] - 1s 601ms/step - loss: 0.3473 - accuracy: 0.8902 - val_loss: 0.3783 - val_accuracy: 0.8920
# Epoch 274/500
# 1/1 [==============================] - 1s 594ms/step - loss: 0.3300 - accuracy: 0.8956 - val_loss: 0.3749 - val_accuracy: 0.8903
# Epoch 275/500
# 1/1 [==============================] - 1s 582ms/step - loss: 0.3374 - accuracy: 0.8898 - val_loss: 0.3744 - val_accuracy: 0.8886
# Epoch 276/500
# 1/1 [==============================] - 1s 632ms/step - loss: 0.3238 - accuracy: 0.8979 - val_loss: 0.3791 - val_accuracy: 0.8894
# Epoch 277/500
# 1/1 [==============================] - 1s 577ms/step - loss: 0.3306 - accuracy: 0.8963 - val_loss: 0.3754 - val_accuracy: 0.8894
# Epoch 278/500
# 1/1 [==============================] - 1s 579ms/step - loss: 0.3314 - accuracy: 0.8996 - val_loss: 0.3722 - val_accuracy: 0.8903
# Epoch 279/500
# 1/1 [==============================] - 1s 596ms/step - loss: 0.3320 - accuracy: 0.8963 - val_loss: 0.3702 - val_accuracy: 0.8928
# Epoch 280/500
# 1/1 [==============================] - 1s 599ms/step - loss: 0.3243 - accuracy: 0.8967 - val_loss: 0.3752 - val_accuracy: 0.8886
# Epoch 281/500
# 1/1 [==============================] - 1s 570ms/step - loss: 0.3251 - accuracy: 0.8998 - val_loss: 0.3801 - val_accuracy: 0.8886
# Epoch 282/500
# 1/1 [==============================] - 1s 575ms/step - loss: 0.3359 - accuracy: 0.8940 - val_loss: 0.3710 - val_accuracy: 0.8886
# Epoch 283/500
# 1/1 [==============================] - 1s 597ms/step - loss: 0.3198 - accuracy: 0.9011 - val_loss: 0.3729 - val_accuracy: 0.8869
# Epoch 284/500
# 1/1 [==============================] - 1s 616ms/step - loss: 0.3180 - accuracy: 0.8969 - val_loss: 0.3751 - val_accuracy: 0.8894
# Epoch 285/500
# 1/1 [==============================] - 1s 619ms/step - loss: 0.3171 - accuracy: 0.8992 - val_loss: 0.3756 - val_accuracy: 0.8911
# Epoch 286/500
# 1/1 [==============================] - 1s 602ms/step - loss: 0.3200 - accuracy: 0.8992 - val_loss: 0.3742 - val_accuracy: 0.8886
# Epoch 287/500
# 1/1 [==============================] - 1s 608ms/step - loss: 0.3172 - accuracy: 0.8965 - val_loss: 0.3733 - val_accuracy: 0.8903
# Epoch 288/500
# 1/1 [==============================] - 1s 632ms/step - loss: 0.3062 - accuracy: 0.9049 - val_loss: 0.3766 - val_accuracy: 0.8894
# Epoch 289/500
# 1/1 [==============================] - 1s 635ms/step - loss: 0.3079 - accuracy: 0.8990 - val_loss: 0.3730 - val_accuracy: 0.8928
# Epoch 290/500
# 1/1 [==============================] - 1s 597ms/step - loss: 0.3158 - accuracy: 0.9015 - val_loss: 0.3726 - val_accuracy: 0.8920
# Epoch 291/500
# 1/1 [==============================] - 1s 607ms/step - loss: 0.3091 - accuracy: 0.8996 - val_loss: 0.3717 - val_accuracy: 0.8928
# Epoch 292/500
# 1/1 [==============================] - 1s 598ms/step - loss: 0.3211 - accuracy: 0.8977 - val_loss: 0.3769 - val_accuracy: 0.8911
# Epoch 293/500
# 1/1 [==============================] - 1s 614ms/step - loss: 0.3130 - accuracy: 0.8990 - val_loss: 0.3723 - val_accuracy: 0.8911
# Epoch 294/500
# 1/1 [==============================] - 1s 610ms/step - loss: 0.3170 - accuracy: 0.8979 - val_loss: 0.3657 - val_accuracy: 0.8928
# Epoch 295/500
# 1/1 [==============================] - 1s 595ms/step - loss: 0.3166 - accuracy: 0.8975 - val_loss: 0.3697 - val_accuracy: 0.8886
# Epoch 296/500
# 1/1 [==============================] - 1s 613ms/step - loss: 0.2997 - accuracy: 0.9019 - val_loss: 0.3758 - val_accuracy: 0.8878
# Epoch 297/500
# 1/1 [==============================] - 1s 622ms/step - loss: 0.3102 - accuracy: 0.9023 - val_loss: 0.3637 - val_accuracy: 0.8911
# Epoch 298/500
# 1/1 [==============================] - 1s 586ms/step - loss: 0.3090 - accuracy: 0.9005 - val_loss: 0.3617 - val_accuracy: 0.8936
# Epoch 299/500
# 1/1 [==============================] - 1s 602ms/step - loss: 0.3091 - accuracy: 0.9013 - val_loss: 0.3670 - val_accuracy: 0.8886
# Epoch 300/500
# 1/1 [==============================] - 1s 603ms/step - loss: 0.3105 - accuracy: 0.9011 - val_loss: 0.3687 - val_accuracy: 0.8903
# Epoch 301/500
# 1/1 [==============================] - 1s 588ms/step - loss: 0.3060 - accuracy: 0.9015 - val_loss: 0.3634 - val_accuracy: 0.8903
# Epoch 302/500
# 1/1 [==============================] - 1s 607ms/step - loss: 0.2901 - accuracy: 0.9055 - val_loss: 0.3631 - val_accuracy: 0.8928
# Epoch 303/500
# 1/1 [==============================] - 1s 587ms/step - loss: 0.3008 - accuracy: 0.9049 - val_loss: 0.3663 - val_accuracy: 0.8903
# Epoch 304/500
# 1/1 [==============================] - 1s 600ms/step - loss: 0.3050 - accuracy: 0.9017 - val_loss: 0.3635 - val_accuracy: 0.8920
# Epoch 305/500
# 1/1 [==============================] - 1s 634ms/step - loss: 0.3011 - accuracy: 0.9013 - val_loss: 0.3586 - val_accuracy: 0.8945
# Epoch 306/500
# 1/1 [==============================] - 1s 609ms/step - loss: 0.3074 - accuracy: 0.9032 - val_loss: 0.3594 - val_accuracy: 0.8945
# Epoch 307/500
# 1/1 [==============================] - 1s 608ms/step - loss: 0.3004 - accuracy: 0.9009 - val_loss: 0.3629 - val_accuracy: 0.8903
# Epoch 308/500
# 1/1 [==============================] - 1s 618ms/step - loss: 0.3100 - accuracy: 0.9021 - val_loss: 0.3611 - val_accuracy: 0.8911
# Epoch 309/500
# 1/1 [==============================] - 1s 607ms/step - loss: 0.3053 - accuracy: 0.9049 - val_loss: 0.3576 - val_accuracy: 0.8936
# Epoch 310/500
# 1/1 [==============================] - 1s 607ms/step - loss: 0.3096 - accuracy: 0.9009 - val_loss: 0.3568 - val_accuracy: 0.8936
# Epoch 311/500
# 1/1 [==============================] - 1s 599ms/step - loss: 0.2924 - accuracy: 0.9084 - val_loss: 0.3646 - val_accuracy: 0.8903
# Epoch 312/500
# 1/1 [==============================] - 1s 593ms/step - loss: 0.3002 - accuracy: 0.9019 - val_loss: 0.3649 - val_accuracy: 0.8920
# Epoch 313/500
# 1/1 [==============================] - 1s 595ms/step - loss: 0.3073 - accuracy: 0.9021 - val_loss: 0.3556 - val_accuracy: 0.8970
# Epoch 314/500
# 1/1 [==============================] - 1s 583ms/step - loss: 0.2991 - accuracy: 0.9057 - val_loss: 0.3579 - val_accuracy: 0.8970
# Epoch 315/500
# 1/1 [==============================] - 1s 588ms/step - loss: 0.2949 - accuracy: 0.9059 - val_loss: 0.3658 - val_accuracy: 0.8945
# Epoch 316/500
# 1/1 [==============================] - 1s 587ms/step - loss: 0.2910 - accuracy: 0.9078 - val_loss: 0.3583 - val_accuracy: 0.8945
# Epoch 317/500
# 1/1 [==============================] - 1s 595ms/step - loss: 0.2903 - accuracy: 0.9078 - val_loss: 0.3585 - val_accuracy: 0.8936
# Epoch 318/500
# 1/1 [==============================] - 1s 591ms/step - loss: 0.2785 - accuracy: 0.9122 - val_loss: 0.3644 - val_accuracy: 0.8936
# Epoch 319/500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.2910 - accuracy: 0.9080 - val_loss: 0.3602 - val_accuracy: 0.8953
# Epoch 320/500
# 1/1 [==============================] - 1s 590ms/step - loss: 0.2967 - accuracy: 0.9078 - val_loss: 0.3579 - val_accuracy: 0.8987
# Epoch 321/500
# 1/1 [==============================] - 1s 600ms/step - loss: 0.2874 - accuracy: 0.9114 - val_loss: 0.3625 - val_accuracy: 0.8953
# Epoch 322/500
# 1/1 [==============================] - 1s 594ms/step - loss: 0.2946 - accuracy: 0.9072 - val_loss: 0.3633 - val_accuracy: 0.8945
# Epoch 323/500
# 1/1 [==============================] - 1s 607ms/step - loss: 0.2814 - accuracy: 0.9084 - val_loss: 0.3599 - val_accuracy: 0.8961
# Epoch 324/500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.2840 - accuracy: 0.9101 - val_loss: 0.3568 - val_accuracy: 0.8961
# Epoch 325/500
# 1/1 [==============================] - 1s 623ms/step - loss: 0.2807 - accuracy: 0.9101 - val_loss: 0.3578 - val_accuracy: 0.8936
# Epoch 326/500
# 1/1 [==============================] - 1s 622ms/step - loss: 0.2876 - accuracy: 0.9072 - val_loss: 0.3618 - val_accuracy: 0.8945
# Epoch 327/500
# 1/1 [==============================] - 1s 614ms/step - loss: 0.2890 - accuracy: 0.9057 - val_loss: 0.3576 - val_accuracy: 0.8953
# Epoch 328/500
# 1/1 [==============================] - 1s 607ms/step - loss: 0.2869 - accuracy: 0.9047 - val_loss: 0.3599 - val_accuracy: 0.8953
# Epoch 329/500
# 1/1 [==============================] - 1s 617ms/step - loss: 0.2870 - accuracy: 0.9099 - val_loss: 0.3617 - val_accuracy: 0.8936
# Epoch 330/500
# 1/1 [==============================] - 1s 632ms/step - loss: 0.2755 - accuracy: 0.9116 - val_loss: 0.3617 - val_accuracy: 0.8953
# Epoch 331/500
# 1/1 [==============================] - 1s 598ms/step - loss: 0.2906 - accuracy: 0.9101 - val_loss: 0.3570 - val_accuracy: 0.8953
# Epoch 332/500
# 1/1 [==============================] - 1s 607ms/step - loss: 0.2864 - accuracy: 0.9099 - val_loss: 0.3604 - val_accuracy: 0.8953
# Epoch 333/500
# 1/1 [==============================] - 1s 613ms/step - loss: 0.2822 - accuracy: 0.9026 - val_loss: 0.3620 - val_accuracy: 0.8953
# Epoch 334/500
# 1/1 [==============================] - 1s 602ms/step - loss: 0.2831 - accuracy: 0.9101 - val_loss: 0.3537 - val_accuracy: 0.8961
# Epoch 335/500
# 1/1 [==============================] - 1s 625ms/step - loss: 0.2784 - accuracy: 0.9080 - val_loss: 0.3539 - val_accuracy: 0.8995
# Epoch 336/500
# ...
# Epoch 390/500
# 1/1 [==============================] - 1s 619ms/step - loss: 0.2427 - accuracy: 0.9195 - val_loss: 0.3559 - val_accuracy: 0.9062
# Epoch 391/500
# 1/1 [==============================] - 1s 592ms/step - loss: 0.2442 - accuracy: 0.9204 - val_loss: 0.3543 - val_accuracy: 0.9070
# Epoch 392/500
# 1/1 [==============================] - 1s 582ms/step - loss: 0.2441 - accuracy: 0.9233 - val_loss: 0.3649 - val_accuracy: 0.9028
# Epoch 393/500
# 1/1 [==============================] - 1s 589ms/step - loss: 0.2456 - accuracy: 0.9210 - val_loss: 0.3694 - val_accuracy: 0.9045
# Epoch 394/500
# 1/1 [==============================] - 1s 627ms/step - loss: 0.2527 - accuracy: 0.9139 - val_loss: 0.3563 - val_accuracy: 0.9070
# Epoch 395/500
# 1/1 [==============================] - 1s 602ms/step - loss: 0.2459 - accuracy: 0.9214 - val_loss: 0.3570 - val_accuracy: 0.9045
# Epoch 396/500
# 1/1 [==============================] - 1s 612ms/step - loss: 0.2411 - accuracy: 0.9206 - val_loss: 0.3691 - val_accuracy: 0.9045
# Epoch 397/500
# 1/1 [==============================] - 1s 610ms/step - loss: 0.2534 - accuracy: 0.9197 - val_loss: 0.3628 - val_accuracy: 0.9079
# Epoch 398/500
# 1/1 [==============================] - 1s 596ms/step - loss: 0.2449 - accuracy: 0.9212 - val_loss: 0.3644 - val_accuracy: 0.9070
# Epoch 399/500
# 1/1 [==============================] - 1s 598ms/step - loss: 0.2515 - accuracy: 0.9220 - val_loss: 0.3602 - val_accuracy: 0.9104
# Epoch 400/500
# 1/1 [==============================] - 1s 618ms/step - loss: 0.2398 - accuracy: 0.9250 - val_loss: 0.3771 - val_accuracy: 0.9020
# Epoch 401/500
# 1/1 [==============================] - 1s 603ms/step - loss: 0.2365 - accuracy: 0.9229 - val_loss: 0.3698 - val_accuracy: 0.9070
# Epoch 402/500
# 1/1 [==============================] - 1s 587ms/step - loss: 0.2470 - accuracy: 0.9216 - val_loss: 0.3585 - val_accuracy: 0.9104
# Epoch 403/500
# 1/1 [==============================] - 1s 625ms/step - loss: 0.2411 - accuracy: 0.9220 - val_loss: 0.3559 - val_accuracy: 0.9054
# Epoch 404/500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.2385 - accuracy: 0.9225 - val_loss: 0.3754 - val_accuracy: 0.9062
# Epoch 405/500
# 1/1 [==============================] - 1s 607ms/step - loss: 0.2439 - accuracy: 0.9166 - val_loss: 0.3606 - val_accuracy: 0.9087
# Epoch 406/500
# 1/1 [==============================] - 1s 579ms/step - loss: 0.2296 - accuracy: 0.9264 - val_loss: 0.3546 - val_accuracy: 0.9112
# Epoch 407/500
# 1/1 [==============================] - 1s 600ms/step - loss: 0.2435 - accuracy: 0.9237 - val_loss: 0.3589 - val_accuracy: 0.9079
# Epoch 408/500
# 1/1 [==============================] - 1s 626ms/step - loss: 0.2401 - accuracy: 0.9241 - val_loss: 0.3710 - val_accuracy: 0.9054
# Epoch 409/500
# 1/1 [==============================] - 1s 622ms/step - loss: 0.2436 - accuracy: 0.9197 - val_loss: 0.3570 - val_accuracy: 0.9095
# Epoch 410/500
# 1/1 [==============================] - 1s 602ms/step - loss: 0.2387 - accuracy: 0.9227 - val_loss: 0.3539 - val_accuracy: 0.9079
# Epoch 411/500
# 1/1 [==============================] - 1s 584ms/step - loss: 0.2305 - accuracy: 0.9237 - val_loss: 0.3558 - val_accuracy: 0.9087
# Epoch 412/500
# 1/1 [==============================] - 1s 611ms/step - loss: 0.2320 - accuracy: 0.9267 - val_loss: 0.3639 - val_accuracy: 0.9054
# Epoch 413/500
# 1/1 [==============================] - 1s 638ms/step - loss: 0.2317 - accuracy: 0.9254 - val_loss: 0.3558 - val_accuracy: 0.9079
# Epoch 414/500
# 1/1 [==============================] - 1s 607ms/step - loss: 0.2285 - accuracy: 0.9302 - val_loss: 0.3531 - val_accuracy: 0.9079
# Epoch 415/500
# 1/1 [==============================] - 1s 601ms/step - loss: 0.2274 - accuracy: 0.9292 - val_loss: 0.3590 - val_accuracy: 0.9079
# Epoch 416/500
# 1/1 [==============================] - 1s 594ms/step - loss: 0.2266 - accuracy: 0.9250 - val_loss: 0.3696 - val_accuracy: 0.9062
# Epoch 417/500
# 1/1 [==============================] - 1s 587ms/step - loss: 0.2252 - accuracy: 0.9237 - val_loss: 0.3624 - val_accuracy: 0.9054
# Epoch 418/500
# 1/1 [==============================] - 1s 594ms/step - loss: 0.2280 - accuracy: 0.9267 - val_loss: 0.3542 - val_accuracy: 0.9070
# Epoch 419/500
# 1/1 [==============================] - 1s 602ms/step - loss: 0.2365 - accuracy: 0.9239 - val_loss: 0.3576 - val_accuracy: 0.9079
# Epoch 420/500
# 1/1 [==============================] - 1s 587ms/step - loss: 0.2396 - accuracy: 0.9271 - val_loss: 0.3646 - val_accuracy: 0.9087
# Epoch 421/500
# 1/1 [==============================] - 1s 580ms/step - loss: 0.2332 - accuracy: 0.9237 - val_loss: 0.3556 - val_accuracy: 0.9087
# Epoch 422/500
# 1/1 [==============================] - 1s 589ms/step - loss: 0.2266 - accuracy: 0.9267 - val_loss: 0.3513 - val_accuracy: 0.9087
# Epoch 423/500
# 1/1 [==============================] - 1s 614ms/step - loss: 0.2442 - accuracy: 0.9239 - val_loss: 0.3600 - val_accuracy: 0.9070
# Epoch 424/500
# 1/1 [==============================] - 1s 590ms/step - loss: 0.2258 - accuracy: 0.9250 - val_loss: 0.3592 - val_accuracy: 0.9087
# Epoch 425/500
# 1/1 [==============================] - 1s 610ms/step - loss: 0.2273 - accuracy: 0.9306 - val_loss: 0.3485 - val_accuracy: 0.9095
# Epoch 426/500
# 1/1 [==============================] - 1s 602ms/step - loss: 0.2292 - accuracy: 0.9262 - val_loss: 0.3492 - val_accuracy: 0.9112
# Epoch 427/500
# 1/1 [==============================] - 1s 631ms/step - loss: 0.2349 - accuracy: 0.9254 - val_loss: 0.3608 - val_accuracy: 0.9079
# Epoch 428/500
# 1/1 [==============================] - 1s 634ms/step - loss: 0.2266 - accuracy: 0.9267 - val_loss: 0.3669 - val_accuracy: 0.9070
# Epoch 429/500
# 1/1 [==============================] - 1s 585ms/step - loss: 0.2254 - accuracy: 0.9256 - val_loss: 0.3576 - val_accuracy: 0.9121
# Epoch 430/500
# 1/1 [==============================] - 1s 604ms/step - loss: 0.2251 - accuracy: 0.9308 - val_loss: 0.3554 - val_accuracy: 0.9121
# Epoch 431/500
# 1/1 [==============================] - 1s 623ms/step - loss: 0.2255 - accuracy: 0.9279 - val_loss: 0.3655 - val_accuracy: 0.9087
# Epoch 432/500
# 1/1 [==============================] - 1s 608ms/step - loss: 0.2258 - accuracy: 0.9264 - val_loss: 0.3584 - val_accuracy: 0.9079
# Epoch 433/500
# 1/1 [==============================] - 1s 608ms/step - loss: 0.2243 - accuracy: 0.9304 - val_loss: 0.3527 - val_accuracy: 0.9104
# Epoch 434/500
# 1/1 [==============================] - 1s 615ms/step - loss: 0.2165 - accuracy: 0.9311 - val_loss: 0.3526 - val_accuracy: 0.9104
# Epoch 435/500
# 1/1 [==============================] - 1s 638ms/step - loss: 0.2090 - accuracy: 0.9327 - val_loss: 0.3614 - val_accuracy: 0.9087
# Epoch 436/500
# 1/1 [==============================] - 1s 601ms/step - loss: 0.2136 - accuracy: 0.9334 - val_loss: 0.3652 - val_accuracy: 0.9087
# Epoch 437/500
# 1/1 [==============================] - 1s 612ms/step - loss: 0.2303 - accuracy: 0.9246 - val_loss: 0.3582 - val_accuracy: 0.9112
# Epoch 438/500
# 1/1 [==============================] - 1s 595ms/step - loss: 0.2227 - accuracy: 0.9296 - val_loss: 0.3591 - val_accuracy: 0.9129
# Epoch 439/500
# 1/1 [==============================] - 1s 614ms/step - loss: 0.2172 - accuracy: 0.9327 - val_loss: 0.3626 - val_accuracy: 0.9095
# Epoch 440/500
# 1/1 [==============================] - 1s 612ms/step - loss: 0.2189 - accuracy: 0.9294 - val_loss: 0.3631 - val_accuracy: 0.9112
# Epoch 441/500
# 1/1 [==============================] - 1s 601ms/step - loss: 0.2134 - accuracy: 0.9315 - val_loss: 0.3549 - val_accuracy: 0.9129
# Epoch 442/500
# 1/1 [==============================] - 1s 581ms/step - loss: 0.2134 - accuracy: 0.9300 - val_loss: 0.3565 - val_accuracy: 0.9095
# Epoch 443/500
# 1/1 [==============================] - 1s 592ms/step - loss: 0.2173 - accuracy: 0.9290 - val_loss: 0.3631 - val_accuracy: 0.9121
# Epoch 444/500
# 1/1 [==============================] - 1s 599ms/step - loss: 0.2101 - accuracy: 0.9350 - val_loss: 0.3623 - val_accuracy: 0.9095
# Epoch 445/500
# 1/1 [==============================] - 1s 606ms/step - loss: 0.2084 - accuracy: 0.9294 - val_loss: 0.3623 - val_accuracy: 0.9095
# Epoch 446/500
# 1/1 [==============================] - 1s 624ms/step - loss: 0.2142 - accuracy: 0.9302 - val_loss: 0.3581 - val_accuracy: 0.9095
# Epoch 447/500
# 1/1 [==============================] - 1s 655ms/step - loss: 0.2165 - accuracy: 0.9311 - val_loss: 0.3598 - val_accuracy: 0.9087
# Epoch 448/500
# 1/1 [==============================] - 1s 591ms/step - loss: 0.2178 - accuracy: 0.9304 - val_loss: 0.3596 - val_accuracy: 0.9104
# Epoch 449/500
# 1/1 [==============================] - 1s 642ms/step - loss: 0.2131 - accuracy: 0.9321 - val_loss: 0.3572 - val_accuracy: 0.9087
# Epoch 450/500
# 1/1 [==============================] - 1s 629ms/step - loss: 0.2201 - accuracy: 0.9308 - val_loss: 0.3586 - val_accuracy: 0.9095
# Epoch 451/500
# 1/1 [==============================] - 1s 612ms/step - loss: 0.2094 - accuracy: 0.9319 - val_loss: 0.3576 - val_accuracy: 0.9095
# Epoch 452/500
# 1/1 [==============================] - 1s 605ms/step - loss: 0.2158 - accuracy: 0.9277 - val_loss: 0.3538 - val_accuracy: 0.9104
# Epoch 453/500
# 1/1 [==============================] - 1s 596ms/step - loss: 0.2218 - accuracy: 0.9283 - val_loss: 0.3566 - val_accuracy: 0.9104
# Epoch 454/500
# 1/1 [==============================] - 1s 597ms/step - loss: 0.2098 - accuracy: 0.9290 - val_loss: 0.3674 - val_accuracy: 0.9095
# Epoch 455/500
# 1/1 [==============================] - 1s 596ms/step - loss: 0.2114 - accuracy: 0.9342 - val_loss: 0.3615 - val_accuracy: 0.9112
# Epoch 456/500
# 1/1 [==============================] - 1s 606ms/step - loss: 0.2100 - accuracy: 0.9327 - val_loss: 0.3570 - val_accuracy: 0.9121
# Epoch 457/500
# 1/1 [==============================] - 1s 601ms/step - loss: 0.2072 - accuracy: 0.9336 - val_loss: 0.3609 - val_accuracy: 0.9070
# Epoch 458/500
# 1/1 [==============================] - 1s 591ms/step - loss: 0.2169 - accuracy: 0.9319 - val_loss: 0.3628 - val_accuracy: 0.9087
# Epoch 459/500
# 1/1 [==============================] - 1s 593ms/step - loss: 0.2105 - accuracy: 0.9344 - val_loss: 0.3569 - val_accuracy: 0.9070
# Epoch 460/500
# 1/1 [==============================] - 1s 620ms/step - loss: 0.2092 - accuracy: 0.9306 - val_loss: 0.3535 - val_accuracy: 0.9070
# Epoch 461/500
# 1/1 [==============================] - 1s 601ms/step - loss: 0.2024 - accuracy: 0.9367 - val_loss: 0.3636 - val_accuracy: 0.9037
# Epoch 462/500
# 1/1 [==============================] - 1s 616ms/step - loss: 0.2054 - accuracy: 0.9342 - val_loss: 0.3584 - val_accuracy: 0.9062
# Epoch 463/500
# 1/1 [==============================] - 1s 598ms/step - loss: 0.2051 - accuracy: 0.9390 - val_loss: 0.3522 - val_accuracy: 0.9079
# Epoch 464/500
# 1/1 [==============================] - 1s 603ms/step - loss: 0.2188 - accuracy: 0.9311 - val_loss: 0.3574 - val_accuracy: 0.9062
# Epoch 465/500
# 1/1 [==============================] - 1s 609ms/step - loss: 0.2092 - accuracy: 0.9313 - val_loss: 0.3694 - val_accuracy: 0.9079
# Epoch 466/500
# 1/1 [==============================] - 1s 603ms/step - loss: 0.2098 - accuracy: 0.9332 - val_loss: 0.3588 - val_accuracy: 0.9104
# Epoch 467/500
# 1/1 [==============================] - 1s 599ms/step - loss: 0.1979 - accuracy: 0.9350 - val_loss: 0.3574 - val_accuracy: 0.9087
# Epoch 468/500
# 1/1 [==============================] - 1s 609ms/step - loss: 0.2133 - accuracy: 0.9313 - val_loss: 0.3621 - val_accuracy: 0.9095
# Epoch 469/500
# 1/1 [==============================] - 1s 621ms/step - loss: 0.2078 - accuracy: 0.9321 - val_loss: 0.3672 - val_accuracy: 0.9062
# Epoch 470/500
# 1/1 [==============================] - 1s 597ms/step - loss: 0.2036 - accuracy: 0.9344 - val_loss: 0.3600 - val_accuracy: 0.9079
# Epoch 471/500
# 1/1 [==============================] - 1s 602ms/step - loss: 0.2092 - accuracy: 0.9317 - val_loss: 0.3603 - val_accuracy: 0.9087
# Epoch 472/500
# 1/1 [==============================] - 1s 644ms/step - loss: 0.2006 - accuracy: 0.9344 - val_loss: 0.3629 - val_accuracy: 0.9095
# Epoch 473/500
# 1/1 [==============================] - 1s 620ms/step - loss: 0.2018 - accuracy: 0.9392 - val_loss: 0.3625 - val_accuracy: 0.9079
# Epoch 474/500
# 1/1 [==============================] - 1s 596ms/step - loss: 0.2025 - accuracy: 0.9336 - val_loss: 0.3641 - val_accuracy: 0.9087
# Epoch 475/500
# 1/1 [==============================] - 1s 593ms/step - loss: 0.2002 - accuracy: 0.9365 - val_loss: 0.3587 - val_accuracy: 0.9070
# Epoch 476/500
# 1/1 [==============================] - 1s 640ms/step - loss: 0.2016 - accuracy: 0.9359 - val_loss: 0.3623 - val_accuracy: 0.9095
# Epoch 477/500
# 1/1 [==============================] - 1s 610ms/step - loss: 0.2025 - accuracy: 0.9355 - val_loss: 0.3673 - val_accuracy: 0.9070
# Epoch 478/500
# 1/1 [==============================] - 1s 610ms/step - loss: 0.1926 - accuracy: 0.9378 - val_loss: 0.3661 - val_accuracy: 0.9087
# Epoch 479/500
# 1/1 [==============================] - 1s 607ms/step - loss: 0.1906 - accuracy: 0.9386 - val_loss: 0.3582 - val_accuracy: 0.9079
# Epoch 480/500
# 1/1 [==============================] - 1s 589ms/step - loss: 0.1947 - accuracy: 0.9376 - val_loss: 0.3569 - val_accuracy: 0.9112
# Epoch 481/500
# 1/1 [==============================] - 1s 622ms/step - loss: 0.1918 - accuracy: 0.9367 - val_loss: 0.3717 - val_accuracy: 0.9087
# Epoch 482/500
# 1/1 [==============================] - 1s 582ms/step - loss: 0.2034 - accuracy: 0.9352 - val_loss: 0.3565 - val_accuracy: 0.9095
# Epoch 483/500
# 1/1 [==============================] - 1s 598ms/step - loss: 0.1964 - accuracy: 0.9342 - val_loss: 0.3499 - val_accuracy: 0.9112
# Epoch 484/500
# 1/1 [==============================] - 1s 613ms/step - loss: 0.2017 - accuracy: 0.9401 - val_loss: 0.3559 - val_accuracy: 0.9079
# Epoch 485/500
# 1/1 [==============================] - 1s 618ms/step - loss: 0.2040 - accuracy: 0.9338 - val_loss: 0.3530 - val_accuracy: 0.9104
# Epoch 486/500
# 1/1 [==============================] - 1s 601ms/step - loss: 0.1944 - accuracy: 0.9394 - val_loss: 0.3562 - val_accuracy: 0.9095
# Epoch 487/500
# 1/1 [==============================] - 1s 605ms/step - loss: 0.1917 - accuracy: 0.9361 - val_loss: 0.3591 - val_accuracy: 0.9104
# Epoch 488/500
# 1/1 [==============================] - 1s 616ms/step - loss: 0.1984 - accuracy: 0.9382 - val_loss: 0.3523 - val_accuracy: 0.9079
# Epoch 489/500
# 1/1 [==============================] - 1s 612ms/step - loss: 0.2006 - accuracy: 0.9367 - val_loss: 0.3494 - val_accuracy: 0.9087
# Epoch 490/500
# 1/1 [==============================] - 1s 609ms/step - loss: 0.2002 - accuracy: 0.9348 - val_loss: 0.3657 - val_accuracy: 0.9104
# Epoch 491/500
# 1/1 [==============================] - 1s 605ms/step - loss: 0.2049 - accuracy: 0.9348 - val_loss: 0.3583 - val_accuracy: 0.9112
# Epoch 492/500
# 1/1 [==============================] - 1s 624ms/step - loss: 0.1910 - accuracy: 0.9394 - val_loss: 0.3604 - val_accuracy: 0.9087
# Epoch 493/500
# 1/1 [==============================] - 1s 603ms/step - loss: 0.1955 - accuracy: 0.9409 - val_loss: 0.3619 - val_accuracy: 0.9104
# Epoch 494/500
# 1/1 [==============================] - 1s 593ms/step - loss: 0.1990 - accuracy: 0.9365 - val_loss: 0.3638 - val_accuracy: 0.9095
# Epoch 495/500
# 1/1 [==============================] - 1s 601ms/step - loss: 0.1987 - accuracy: 0.9369 - val_loss: 0.3614 - val_accuracy: 0.9121
# Epoch 496/500
# 1/1 [==============================] - 1s 600ms/step - loss: 0.1903 - accuracy: 0.9394 - val_loss: 0.3555 - val_accuracy: 0.9112
# Epoch 497/500
# 1/1 [==============================] - 1s 618ms/step - loss: 0.1941 - accuracy: 0.9340 - val_loss: 0.3569 - val_accuracy: 0.9070
# Epoch 498/500
# 1/1 [==============================] - 1s 609ms/step - loss: 0.1971 - accuracy: 0.9332 - val_loss: 0.3563 - val_accuracy: 0.9079
# Epoch 499/500
# 1/1 [==============================] - 1s 623ms/step - loss: 0.1924 - accuracy: 0.9428 - val_loss: 0.3591 - val_accuracy: 0.9095
# Epoch 500/500
# 1/1 [==============================] - 1s 625ms/step - loss: 0.1912 - accuracy: 0.9413 - val_loss: 0.3644 - val_accuracy: 0.9095
# test_size 0.2
# epochs 500
# batch_size 4772
# zoom_range 1
# horizontal_flip  False
# dropout_rate 0.3
