# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
import colorsys
#https://docs.python.org/2/library/colorsys.html

# %%
image_rgb=cv2.imread("/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_0/image_2019-04-30_18-26-25.jpg")
im_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
plt.imshow(im_rgb)

# %%
#Version GRB

# %%
path_imagettes="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/pictures/imagettes_colors/"
liste_images=os.listdir(path_imagettes)



plt.figure(figsize=(20,20))

for image_num in range(len(liste_images)):
    color_range_liste=[]
    
    image_rgb=cv2.imread(path_imagettes+liste_images[image_num])
    image_rgb_reshape=(image_rgb.reshape(-1,3))

    for i in range(len(image_rgb_reshape)):
        pixel=image_rgb_reshape[i]
        red=pixel[0]
        green=pixel[1]
        blue=pixel[2]
        hsv=colorsys.rgb_to_hsv(red,green,blue)
        color_range=hsv[0]*360
        color_range_liste.append(color_range)
        
    print(liste_images[image_num])
    print(np.median(color_range_liste),np.mean(color_range_liste))
    #print("median",)

    plt.subplot(4,4,image_num+1)
    plt.title(liste_images[image_num])
    plt.hist(color_range_liste)
# Out:
# arbre.jpg
# 196.721311211586 197.06104540133052
# arbre2.jpg
# 191.61290287971497 192.84581916824897
# arbre3.jpg
# 188.82352977991104 189.50650172878284
# incertain1.jpg
# 213.33333492279053 212.96693330668674
# incertain2.jpg
# 208.6956524848938 212.86531752507602
# incertain3.jpg
# 204.70588266849518 204.46364126719382
# oiseau.jpg
# 207.27272808551788 208.46485528486724
# oiseau2.jpg
# 208.92857193946838 208.85046828462154
# oiseau3.jpg
# 209.1176462173462 209.25107251548644
# oiseau4.jpg
# 208.42105329036713 209.93280977466884
# pierre1.jpg
# 206.75675690174103 205.18751783866662
# terre1.jpg
# 208.73239517211914 209.02935708359797
# terre2.jpg
# 209.5652174949646 208.86924338736097
# terre3.jpg
# 210.7317066192627 211.1477495380202
# terre4.jpg
# 210.352942943573 210.37340222268688
# terre5.jpg
# 210.0 210.39055170605377

# %%
image_rgb=cv2.imread("/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_0/image_2019-04-30_18-26-25.jpg")
image_rgb_reshape=(image_rgb.reshape(-1,3))




color_range_liste=[]

for i in range(len(image_rgb_reshape)):
    pixel=image_rgb_reshape[i]
    red=pixel[0]
    green=pixel[1]
    blue=pixel[2]
    hsv=colorsys.rgb_to_hsv(red,green,blue)
    color_range=hsv[0]*360
    color_range_liste.append(color_range)
    
print(np.median(color_range_liste))
plt.figure(figsize=(12,12))
plt.hist(color_range_liste,bins=40);
# Out:
# 205.21739065647125

# %%
#On remarque que la médiane pour l'herbe vers 190 est largement en dessous de la médiane générale à 205, les oiseaux sont verts 208

# %%
#Version RGB maintenant

# %%
path_imagettes="/mnt/VegaSlowDataDisk/c3po_interface_mark/Materiels/pictures/imagettes_colors/"
liste_images=os.listdir(path_imagettes)



plt.figure(figsize=(20,20))

for image_num in range(len(liste_images)):
    color_range_liste=[]
    
    image_rgb=cv2.imread(path_imagettes+liste_images[image_num])
    image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
    image_rgb_reshape=(image_rgb.reshape(-1,3))

    for i in range(len(image_rgb_reshape)):
        pixel=image_rgb_reshape[i]
        red=pixel[0]
        green=pixel[1]
        blue=pixel[2]
        hsv=colorsys.rgb_to_hsv(red,green,blue)
        color_range=hsv[0]*360
        color_range_liste.append(color_range)
        
    print(liste_images[image_num])
    print(np.median(color_range_liste),np.mean(color_range_liste))
    #print("median",)

    plt.subplot(4,4,image_num+1)
    plt.title(liste_images[image_num])
    plt.hist(color_range_liste)
# Out:
# arbre.jpg
# 43.27868700027466 42.9389546887607
# arbre2.jpg
# 48.387097120285034 47.154181100884266
# arbre3.jpg
# 51.17646932601929 50.49349852210405
# incertain1.jpg
# 26.666665077209473 27.03306670243643
# incertain2.jpg
# 34.285712242126465 57.44080491706121
# incertain3.jpg
# 35.29411554336548 35.53635912282126
# oiseau.jpg
# 32.72727012634277 31.535144265817138
# oiseau2.jpg
# 31.071428060531616 31.149531797486908
# oiseau3.jpg
# 30.88235378265381 30.748927331700617
# oiseau4.jpg
# 31.578948497772217 30.06719017971535
# pierre1.jpg
# 33.24324131011963 34.812481561485605
# terre1.jpg
# 31.26760482788086 30.970642925525198
# terre2.jpg
# 30.4347825050354 31.13075644386058
# terre3.jpg
# 29.268293380737305 28.85225037987135
# terre4.jpg
# 29.647057056427002 29.626597421509878
# terre5.jpg
# 30.0 29.60944805218249

# %%
image_rgb=cv2.imread("/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_0/image_2019-04-30_18-26-25.jpg")
image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
image_rgb_reshape=(image_rgb.reshape(-1,3))




color_range_liste=[]

for i in range(len(image_rgb_reshape)):
    pixel=image_rgb_reshape[i]
    red=pixel[0]
    green=pixel[1]
    blue=pixel[2]
    hsv=colorsys.rgb_to_hsv(red,green,blue)
    color_range=hsv[0]*360
    color_range_liste.append(color_range)
    
print(np.median(color_range_liste))
plt.figure(figsize=(12,12))
plt.hist(color_range_liste,bins=40);
# Out:
# 39.54545259475708

# %%
color_range_liste_w_sky=[ i for i in color_range_liste if i<100]
print(np.median(color_range_liste_w_sky),np.mean(color_range_liste_w_sky))

plt.figure(figsize=(12,12))
plt.hist(color_range_liste_w_sky,bins=40);
plt.xticks(np.arange(min(color_range_liste_w_sky), max(color_range_liste_w_sky)+1, 5.0));
# Out:
# 32.95774698257446 36.06316988021128

# %%
#Prendre d'autres images, jours, nuit, autre champs
#Il y a peut être un soucis sur les fonctions
#faire des pushs
#Regarder bien sûr le masque

# %%
#Maintenant on se place en fin d'après midi toujours dans le dossier 0

# %%
plt.figure(figsize=(12,12))

image_rgb=cv2.imread("/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_0/image_2019-04-30_18-55-03.jpg")
im_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
plt.subplot(3,1,1)
plt.imshow(im_rgb)


image_rgb_reshape=(im_rgb.reshape(-1,3))




color_range_liste=[]

for i in range(len(image_rgb_reshape)):
    pixel=image_rgb_reshape[i]
    red=pixel[0]
    green=pixel[1]
    blue=pixel[2]
    hsv=colorsys.rgb_to_hsv(red,green,blue)
    color_range=hsv[0]*360
    color_range_liste.append(color_range)
    
print(np.median(color_range_liste))
plt.subplot(3,1,2)
plt.hist(color_range_liste,bins=40);


color_range_liste_w_sky=[ i for i in color_range_liste if i<100]
print(np.median(color_range_liste_w_sky),np.mean(color_range_liste_w_sky))

plt.subplot(3,1,3)
plt.hist(color_range_liste_w_sky,bins=40);
plt.xticks(np.arange(min(color_range_liste_w_sky), max(color_range_liste_w_sky)+1, 5.0));
# Out:
# 41.59999966621399
# 33.947367668151855 36.997106576391076

# %%
path_imagettes="/home/marcpozzo/Desktop/c3po_interface_mark/Materiels/pictures/imagettes_colors/dossier0_fin_am/"
liste_images=os.listdir(path_imagettes)
print(len(liste_images))


plt.figure(figsize=(20,20))

for image_num in range(len(liste_images)):
    color_range_liste=[]
    
    image_rgb=cv2.imread(path_imagettes+liste_images[image_num])
    image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
    image_rgb_reshape=(image_rgb.reshape(-1,3))

    for i in range(len(image_rgb_reshape)):
        pixel=image_rgb_reshape[i]
        red=pixel[0]
        green=pixel[1]
        blue=pixel[2]
        hsv=colorsys.rgb_to_hsv(red,green,blue)
        color_range=hsv[0]*360
        color_range_liste.append(color_range)
        
    print(liste_images[image_num])
    print(np.median(color_range_liste),np.mean(color_range_liste))
    #print("median",)

    plt.subplot(4,5,image_num+1)
    plt.title(liste_images[image_num])
    plt.hist(color_range_liste)
# Out:
# 20
# arbre.3jpg
# 49.84615445137024 50.00842166038192
# arbre.4.jpg
# 51.81818246841431 48.89816557266274
# arbre.6.jpg
# 42.85714387893677 42.86597825434743
# arbre.7.jpg
# 33.00000071525574 32.168364435130236
# arbre.8.jpg
# 47.14285612106323 46.12667879279779
# arbre1.jpg
# 40.90909123420715 40.596805497699854
# arbre2.jpg
# 46.22951030731201 46.10240731920515
# arbre5.jpg
# 54.705880880355835 53.47786352043135
# oiseau0.jpg
# 33.24324131011963 32.503165555547696
# oiseau1.jpg
# 32.592594623565674 31.54818648434415
# oiseau2.jpg
# 33.24324131011963 33.02760511180576
# oiseau3.jpg
# 33.24324131011963 33.28840967343778
# pierre1.jpg
# 28.500001430511475 30.317735684161285
# pierre2.jpg
# 30.749999284744263 30.327487685242478
# pierre3.jpg
# 30.0 30.267205502913924
# pierre4.jpg
# 31.46341323852539 31.393094731836904
# pierre5.jpg
# 26.493505239486694 26.520990446514013
# pierre6.jpg
# 31.999998092651367 37.00562074932517
# terre.jpg
# 23.999998569488525 24.161906052304772
# ...

# %%
#Oiseau strictement compris entre 32 et 33 et un peu en dessous de la médiane sans le ciel qui est à  33 et des poussières
#L'image d'avant oiseaux entre 30 et 33. Mediane à 32.9. Visiblement pas beaucoup de changmeent en terme de médiane.

# %%
#Dossier1 toujours en fin d'après midi
#/home/marcpozzo/Desktop/c3po_interface_mark/Materiels/pictures/imagettes_colors/dossier1/
#'image_2019-04-18_18-49-20.jpg'

# %%
plt.figure(figsize=(12,12))

image_rgb=cv2.imread("/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_1/image_2019-04-18_18-49-20.jpg")
im_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
plt.subplot(3,1,1)
plt.imshow(im_rgb)


image_rgb_reshape=(im_rgb.reshape(-1,3))




color_range_liste=[]

for i in range(len(image_rgb_reshape)):
    pixel=image_rgb_reshape[i]
    red=pixel[0]
    green=pixel[1]
    blue=pixel[2]
    hsv=colorsys.rgb_to_hsv(red,green,blue)
    color_range=hsv[0]*360
    color_range_liste.append(color_range)
    
print("median sur ensemble des pixels",np.median(color_range_liste))
plt.subplot(3,1,2)
plt.hist(color_range_liste,bins=40);


color_range_liste_w_sky=[ i for i in color_range_liste if i<100]
print("medianne sans le ciel",np.median(color_range_liste_w_sky))
print("moyenne sans le ciel",np.mean(color_range_liste_w_sky))

plt.subplot(3,1,3)
plt.hist(color_range_liste_w_sky,bins=40);
plt.xticks(np.arange(min(color_range_liste_w_sky), max(color_range_liste_w_sky)+1, 5.0));
# Out:
# median sur ensemble des pixels 31.875
# medianne sans le ciel 28.656717538833618
# moyenne sans le ciel 32.611178780393466

# %%
path_imagettes="/home/marcpozzo/Desktop/c3po_interface_mark/Materiels/pictures/imagettes_colors/dossier1/"
liste_images=os.listdir(path_imagettes)
print(len(liste_images))


plt.figure(figsize=(20,20))

for image_num in range(len(liste_images)):
    color_range_liste=[]
    
    image_rgb=cv2.imread(path_imagettes+liste_images[image_num])
    image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
    image_rgb_reshape=(image_rgb.reshape(-1,3))

    for i in range(len(image_rgb_reshape)):
        pixel=image_rgb_reshape[i]
        red=pixel[0]
        green=pixel[1]
        blue=pixel[2]
        hsv=colorsys.rgb_to_hsv(red,green,blue)
        color_range=hsv[0]*360
        color_range_liste.append(color_range)
        
    print(liste_images[image_num])
    print(np.median(color_range_liste),np.mean(color_range_liste))
    #print("median",)

    plt.subplot(4,5,image_num+1)
    plt.title(liste_images[image_num])
    plt.hist(color_range_liste)
# Out:
# 15
# 0.jpg
# 28.235292434692383 27.37585847475091
# 10.jpg
# 26.363636255264282 26.17838277044345
# 11.jpg
# 29.142855405807495 30.32448323253466
# 12.jpg
# 26.571428775787354 26.864507459864324
# 2.jpg
# 26.363636255264282 26.47536306052792
# 3.jpg
# 29.000000953674316 29.636869328666705
# 4.jpg
# 26.571428775787354 26.642252960983587
# 6.jpg
# 29.142855405807495 28.22047660545427
# 8.jpg
# 28.235292434692383 27.46895791316519
# arbre1.jpg
# 44.65116262435913 47.85437923608994
# arbre2.jpg
# 56.78571581840515 49.37811823186408
# arbre3.jpg
# 44.51612949371338 42.971469420863656
# arbre4.jpg
# 33.00000071525574 35.29751289863976
# oiseau0.jpg
# 30.0 29.54651512661759
# oiseau1.jpg
# 26.571428775787354 27.645643528322783

# %%
#Mediane plus basse mais aussi valeur oiseaux plus bas à plus ou moins 10%
#Ois 1 26.5 et 30 pour med 28.7

# %%
#dossier2
/home/marcpozzo/Desktop/c3po_interface_mark/Materiels/pictures/imagettes_colors/dossier2/
'image_2019-04-06_19-54-15.jpg'

# %%
plt.figure(figsize=(12,12))

image_rgb=cv2.imread("/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_2/image_2019-04-06_19-54-15.jpg")
image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
plt.subplot(3,1,1)
plt.imshow(im_rgb)


image_rgb_reshape=(image_rgb.reshape(-1,3))




color_range_liste=[]

for i in range(len(image_rgb_reshape)):
    pixel=image_rgb_reshape[i]
    red=pixel[0]
    green=pixel[1]
    blue=pixel[2]
    hsv=colorsys.rgb_to_hsv(red,green,blue)
    color_range=hsv[0]*360
    color_range_liste.append(color_range)
    
print("median sur ensemble des pixels",np.median(color_range_liste))
plt.subplot(3,1,2)
plt.hist(color_range_liste,bins=40);


color_range_liste_w_sky=[ i for i in color_range_liste if i<100]
print("medianne sans le ciel",np.median(color_range_liste_w_sky))
print("moyenne sans le ciel",np.mean(color_range_liste_w_sky))

plt.subplot(3,1,3)
plt.hist(color_range_liste_w_sky,bins=40);
plt.xticks(np.arange(min(color_range_liste_w_sky), max(color_range_liste_w_sky)+1, 5.0));
# Out:
# median sur ensemble des pixels 320.0000023841858
# medianne sans le ciel 39.99999761581421
# moyenne sans le ciel 40.69339407924515

# %%
path_imagettes="/home/marcpozzo/Desktop/c3po_interface_mark/Materiels/pictures/imagettes_colors/dossier2/serie1"
liste_images=os.listdir(path_imagettes)
print(len(liste_images))


plt.figure(figsize=(20,20))

for image_num in range(len(liste_images)):
    color_range_liste=[]
    
    image_rgb=cv2.imread(path_imagettes+liste_images[image_num])
    image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
    image_rgb_reshape=(image_rgb.reshape(-1,3))

    for i in range(len(image_rgb_reshape)):
        pixel=image_rgb_reshape[i]
        red=pixel[0]
        green=pixel[1]
        blue=pixel[2]
        hsv=colorsys.rgb_to_hsv(red,green,blue)
        color_range=hsv[0]*360
        color_range_liste.append(color_range)
        
    print(liste_images[image_num])
    print(np.median(color_range_liste),np.mean(color_range_liste))
    #print("median",)

    plt.subplot(4,5,image_num+1)
    plt.title(liste_images[image_num])
    plt.hist(color_range_liste)
# Out:
# 2
# 0.jpg
# 217.5 203.1272755314273
# 1.jpg
# 247.5 241.72154403234623

# %%
#Refaisaons un test pour le dossier 2
/home/marcpozzo/Desktop/c3po_interface_mark/Materiels/pictures/imagettes_colors/dossier2/serie2/
'image_2019-04-05_17-12-11.jpg'

# %%
plt.figure(figsize=(12,12))

image_rgb=cv2.imread("/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_2/image_2019-04-05_17-12-11.jpg")
image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
plt.subplot(3,1,1)
plt.imshow(image_rgb)


image_rgb_reshape=(image_rgb.reshape(-1,3))




color_range_liste=[]

for i in range(len(image_rgb_reshape)):
    pixel=image_rgb_reshape[i]
    red=pixel[0]
    green=pixel[1]
    blue=pixel[2]
    hsv=colorsys.rgb_to_hsv(red,green,blue)
    color_range=hsv[0]*360
    color_range_liste.append(color_range)
    
print("median sur ensemble des pixels",np.median(color_range_liste))
plt.subplot(3,1,2)
plt.hist(color_range_liste,bins=40);


color_range_liste_w_sky=[ i for i in color_range_liste if i<100]
print("medianne sans le ciel",np.median(color_range_liste_w_sky))
print("moyenne sans le ciel",np.mean(color_range_liste_w_sky))

plt.subplot(3,1,3)
plt.hist(color_range_liste_w_sky,bins=40);
plt.xticks(np.arange(min(color_range_liste_w_sky), max(color_range_liste_w_sky)+1, 5.0));
# Out:
# median sur ensemble des pixels 340.0000011920929
# medianne sans le ciel 11.999999284744263
# moyenne sans le ciel 28.83902504712584

# %%
path_imagettes="/home/marcpozzo/Desktop/c3po_interface_mark/Materiels/pictures/imagettes_colors/dossier2/serie2/"
liste_images=os.listdir(path_imagettes)
print(len(liste_images))


plt.figure(figsize=(20,20))

for image_num in range(len(liste_images)):
    color_range_liste=[]
    
    image_rgb=cv2.imread(path_imagettes+liste_images[image_num])
    image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
    image_rgb_reshape=(image_rgb.reshape(-1,3))

    for i in range(len(image_rgb_reshape)):
        pixel=image_rgb_reshape[i]
        red=pixel[0]
        green=pixel[1]
        blue=pixel[2]
        hsv=colorsys.rgb_to_hsv(red,green,blue)
        color_range=hsv[0]*360
        color_range_liste.append(color_range)
        
    print(liste_images[image_num])
    print(np.median(color_range_liste),np.mean(color_range_liste))
    #print("median",)

    plt.subplot(4,5,image_num+1)
    plt.title(liste_images[image_num])
    plt.hist(color_range_liste)
# Out:
# 5
# bord.jpg
# 25.71428418159485 28.23250667781246
# oiseau0.jpg
# 340.0000011920929 281.44794772094
# oiseau1.jpg
# 279.99999940395355 220.31568203957713
# oiseau2.jpg
# 340.0000011920929 301.29518467400754
# terre_grise.jpg
# 338.1818175315857 337.6048420628115

# %%
#Ca marche très biens sauf pour le corbeau qui est dans l'herbe.

# %%
#Dossier 3
#Tous les fp se font sur fond vert

/home/marcpozzo/Desktop/c3po_interface_mark/Materiels/pictures/imagettes_colors/dossier3/
'image_2019-05-24_17-04-38.jpg'

# %%
plt.figure(figsize=(12,12))

image_rgb=cv2.imread("/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_3/image_2019-05-24_17-04-38.jpg")
image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
plt.subplot(3,1,1)
plt.imshow(image_rgb)


image_rgb_reshape=(image_rgb.reshape(-1,3))




color_range_liste=[]

for i in range(len(image_rgb_reshape)):
    pixel=image_rgb_reshape[i]
    red=pixel[0]
    green=pixel[1]
    blue=pixel[2]
    hsv=colorsys.rgb_to_hsv(red,green,blue)
    color_range=hsv[0]*360
    color_range_liste.append(color_range)
    
print("median sur ensemble des pixels",np.median(color_range_liste))
plt.subplot(3,1,2)
plt.hist(color_range_liste,bins=40);


color_range_liste_w_sky=[ i for i in color_range_liste if i<100]
print("medianne sans le ciel",np.median(color_range_liste_w_sky))
print("moyenne sans le ciel",np.mean(color_range_liste_w_sky))

plt.subplot(3,1,3)
plt.hist(color_range_liste_w_sky,bins=40);
plt.xticks(np.arange(min(color_range_liste_w_sky), max(color_range_liste_w_sky)+1, 5.0));
# Out:
# median sur ensemble des pixels 25.454546213150024
# medianne sans le ciel 23.333333730697632
# moyenne sans le ciel 27.919094379336006

# %%
path_imagettes="/home/marcpozzo/Desktop/c3po_interface_mark/Materiels/pictures/imagettes_colors/dossier3/"
liste_images=os.listdir(path_imagettes)
print(len(liste_images))


plt.figure(figsize=(20,20))

for image_num in range(len(liste_images)):
    color_range_liste=[]
    
    image_rgb=cv2.imread(path_imagettes+liste_images[image_num])
    image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
    image_rgb_reshape=(image_rgb.reshape(-1,3))

    for i in range(len(image_rgb_reshape)):
        pixel=image_rgb_reshape[i]
        red=pixel[0]
        green=pixel[1]
        blue=pixel[2]
        hsv=colorsys.rgb_to_hsv(red,green,blue)
        color_range=hsv[0]*360
        color_range_liste.append(color_range)
        
    print(liste_images[image_num])
    print(np.median(color_range_liste),np.mean(color_range_liste))
    #print("median",)

    plt.subplot(4,5,image_num+1)
    plt.title(liste_images[image_num])
    plt.hist(color_range_liste)
# Out:
# 11
# 0.jpg
# 37.14285850524902 40.21666621371191
# 1.jpg
# 34.285712242126465 41.16256661466038
# 2.jpg
# 68.57142895460129 61.427768978043176
# 3.jpg
# 73.04347783327103 70.07114616184667
# 4.jpg
# 48.00000071525574 54.38124958235694
# 5.jpg
# 43.20000171661377 44.65902727572438
# 6.jpg
# 57.14285731315613 56.0473614689723
# 7.jpg
# 41.99999928474426 40.60163188307565
# 8.jpg
# 73.04347783327103 71.24240966380707
# oiseau0.jpg
# 26.25 25.643241975684557
# oiseau1.jpg
# 57.14285731315613 59.11879027357363

# %%
#Toujours un problème pour l'oiseau dans l'herbe mais marche très bien pour l'autre oiseau

# %%
#Passons au dernier fichier, le 4 
/home/marcpozzo/Desktop/c3po_interface_mark/Materiels/pictures/imagettes_colors/dossier4/
'image_2019-06-14_15-46-54.jpg'


    Red falls between 0 and 60 degrees.
    Yellow falls between 61 and 120 degrees.
    Green falls between 121 and 180 degrees.
    Cyan falls between 181 and 240 degrees.
    Blue falls between 241 and 300 degrees.
    Magenta falls between 301 and 360 degrees.

# %%
plt.figure(figsize=(12,12))

image_rgb=cv2.imread("/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_4/image_2019-06-14_15-46-54.jpg")
image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
plt.subplot(3,1,1)
plt.imshow(image_rgb)


image_rgb_reshape=(image_rgb.reshape(-1,3))




color_range_liste=[]

for i in range(len(image_rgb_reshape)):
    pixel=image_rgb_reshape[i]
    red=pixel[0]
    green=pixel[1]
    blue=pixel[2]
    hsv=colorsys.rgb_to_hsv(red,green,blue)
    color_range=hsv[0]*360
    color_range_liste.append(color_range)
    
print("median sur ensemble des pixels",np.median(color_range_liste))
plt.subplot(3,1,2)
plt.hist(color_range_liste,bins=40);


color_range_liste_w_sky=[ i for i in color_range_liste if i<100]
print("medianne sans le ciel",np.median(color_range_liste_w_sky))
print("moyenne sans le ciel",np.mean(color_range_liste_w_sky))

plt.subplot(3,1,3)
plt.hist(color_range_liste_w_sky,bins=40);
plt.xticks(np.arange(min(color_range_liste_w_sky), max(color_range_liste_w_sky)+1, 5.0));
# Out:
# median sur ensemble des pixels 34.285712242126465
# medianne sans le ciel 32.43243455886841
# moyenne sans le ciel 42.48495282839077

# %%
path_imagettes="/home/marcpozzo/Desktop/c3po_interface_mark/Materiels/pictures/imagettes_colors/dossier4/"
liste_images=os.listdir(path_imagettes)
print(len(liste_images))


plt.figure(figsize=(20,20))

for image_num in range(len(liste_images)):
    color_range_liste=[]
    
    image_rgb=cv2.imread(path_imagettes+liste_images[image_num])
    image_rgb = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2RGB)
    image_rgb_reshape=(image_rgb.reshape(-1,3))

    for i in range(len(image_rgb_reshape)):
        pixel=image_rgb_reshape[i]
        red=pixel[0]
        green=pixel[1]
        blue=pixel[2]
        hsv=colorsys.rgb_to_hsv(red,green,blue)
        color_range=hsv[0]*360
        color_range_liste.append(color_range)
        
    print(liste_images[image_num])
    print(np.median(color_range_liste),np.mean(color_range_liste))
    #print("median",)

    plt.subplot(4,5,image_num+1)
    plt.title(liste_images[image_num])
    plt.hist(color_range_liste)
# Out:
# 14
# 1.jpg
# 67.31707334518433 65.33378210412909
# 10.jpg
# 54.782609939575195 56.4282870501736
# 11.jpg
# 81.33333384990692 81.25989415055635
# 2.jpg
# 66.48648664355278 63.93165014627181
# 3.jpg
# 76.00000083446503 78.01037175067681
# 4.jpg
# 70.00000029802322 70.00978407991708
# 5.jpg
# 61.875 60.39609020295534
# 6.jpg
# 83.33333373069763 96.01287791087312
# 7.jpg
# 68.57142895460129 67.18599439731666
# 8.jpg
# 35.625 35.88470742410543
# 9.jpg
# 69.47368383407593 66.82030174624632
# oiseau0.jpg
# 23.333333730697632 22.925963201084915
# oiseau1.jpg
# 60.0 55.64154373211026
# terre.jpg
# 24.61538314819336 86.6011381995085
