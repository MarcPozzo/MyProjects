# %%
import matplotlib.pyplot as plt
import pickle
path="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_predicts_saved/"

# %%
#Avec 100 epochs
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_100ep/"

#Dossier 0

with open(path_neurones+"fp_tf_100epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)



plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_1.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_1.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(152)
plt.title("dossier1")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_2.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_2.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(153)
plt.title("dossier2")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))


with open(path_neurones+"fp_tf_100epPi1_3.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_3.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(154)
plt.title("dossier3")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_4.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_4.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(1,5,5)
plt.title("dossier4")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# 465 272
# 2328 896
# 104 69
# 2802 489
# 2911 334

# %%
#Avec 100 epochs
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_200ep/"
print("Avec 200 epochs")
#Dossier 0

with open(path_neurones+"fp_tf_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)

plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_200epPi1_1.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_200epPi1_1.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(152)
plt.title("dossier1")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_200epPi1_2.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_200epPi1_2.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(153)
plt.title("dossier2")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))


with open(path_neurones+"fp_tf_200epPi1_3.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_200epPi1_3.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(154)
plt.title("dossier3")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_200epPi1_4.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_200epPi1_4.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(1,5,5)
plt.title("dossier4")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# Avec 200 epochs
# 263 272
# 1314 896
# 35 69
# 1976 489
# 2107 334

# %%
print("regression quantile avec 200 epochs")

#Dossier 0


with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_quantile_200ep/fp_tf_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_quantile_200ep/mb_tf_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)


plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



#Dossier 1


with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_quantile_200ep/fp_tf_200epPi1_1.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_quantile_200ep/mb_tf_200epPi1_1.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)

plt.subplot(152)
plt.title("dossier1")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();


print(len(FP),len(mb))

#Dossier 2


with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_quantile_200ep/fp_tf_200epPi1_2.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_quantile_200ep/mb_tf_200epPi1_2.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)
plt.subplot(153)
plt.title("dossier2")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))




#Dossier 3


with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_quantile_200ep/fp_tf_200epPi1_3.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_quantile_200ep/mb_tf_200epPi1_3.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)

plt.subplot(154)
plt.title("dossier3")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))





#Dossier 4


with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_quantile_200ep/fp_tf_200epPi1_4.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_quantile_200ep/mb_tf_200epPi1_4.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)

plt.subplot(155)
plt.title("dossier5")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# regression quantile avec 200 epochs
# 160 112
# 787 412
# 19 45
# 931 195
# 1262 168

# %%
#Maintenant j'aimerais ajouter avec les oiseaux matchs

# %%
#/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/match_animals/match_animals_100epochs/

with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/match_animals/match_animals_800epochs/fp_tf_match_800epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/match_animals/match_animals_800epochs/mb_tf_match_800epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)


plt.title("dossier5")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))

fp_tf_fp+match_200epPi1_0
# Out:
# 2178 112

# %%
#/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/match_animals/match_animals_100epochs/

with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_200ep/fp_tf_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_200ep/mb_tf_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)


plt.title("dossier5")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# 263 272

# %%
#/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/match_animals/match_animals_100epochs/

with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/match_animals/match_animals_300epochs/fp_tf_match_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open("/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/match_animals/match_animals_300epochs/mb_tf_match_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)


plt.title("dossier5")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# 1298 112

# %%
#Avec 100 epochs
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/tf_fp+match/80%/200ep/"

#Dossier 0

with open(path_neurones+"fp_tf_fp+match_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_fp+match_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)



plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_1.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_1.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(152)
plt.title("dossier1")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_2.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_2.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(153)
plt.title("dossier2")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))


with open(path_neurones+"fp_tf_100epPi1_3.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_3.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(154)
plt.title("dossier3")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_4.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_4.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(1,5,5)
plt.title("dossier4")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# 1388 272
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-191-777bfc03fcef> in <module>
#      23
#      24
# ---> 25 with open(path_neurones+"fp_tf_100epPi1_1.txt", "rb") as fp:   # Unpickling
#      26    FP = pickle.load(fp)
#      27
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/tf_fp+match/80%/200ep/fp_tf_100epPi1_1.txt'

# %%
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/tf_fp+match/50%/200ep/"

#Dossier 0

with open(path_neurones+"fp_lessfp_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_lessfp_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)



plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# 1214 272

# %%
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/tf_fp+match/80%/200ep/"

#Dossier 0

with open(path_neurones+"fp_lessfp_200epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_lessfp_200epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)



plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-195-4b3eb775cb7c> in <module>
#       3 #Dossier 0
#       4
# ----> 5 with open(path_neurones+"fp_lessfp_200epPi1_0.txt", "rb") as fp:   # Unpickling
#       6    FP = pickle.load(fp)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/tf_fp+match/80%/200ep/fp_lessfp_200epPi1_0.txt'

# %%
#Avec 100 epochs
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_100ep/"

#Dossier 0

with open(path_neurones+"fp_tf_100epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)



plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend()

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_1.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_1.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(152)
plt.title("dossier1")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_2.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_2.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(153)
plt.title("dossier2")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))


with open(path_neurones+"fp_tf_100epPi1_3.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_3.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(154)
plt.title("dossier3")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))



with open(path_neurones+"fp_tf_100epPi1_4.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_4.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)




plt.subplot(1,5,5)
plt.title("dossier4")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
plt.legend();

print(len(FP),len(mb))
# Out:
# 465 272
# 2328 896
# 104 69
# 2802 489
# 2911 334

# %%
import pickle
import matplotlib.pyplot as plt

# %%
#Avec 100 epochs
path_neurones="/mnt/VegaSlowDataDisk/c3po_interface/bin/liste_pred_FP/liste_predicts_saved_100ep/"

#Dossier 0

with open(path_neurones+"fp_tf_100epPi1_0.txt", "rb") as fp:   # Unpickling
   FP = pickle.load(fp)

with open(path_neurones+"mb_tf_100epPi1_0.txt", "rb") as fp:   # Unpickling
   mb = pickle.load(fp)



plt.figure(figsize=(70,10))
plt.subplot(151)
plt.title("dossier0")
category=["FP","birds"]
plt.hist([FP,mb], label=category)
# Out:
# ([array([  3.,  43.,  44.,  44.,  36.,  34.,  49.,  40.,  59., 113.]),
#   array([  2.,   2.,   9.,   1.,   9.,  14.,   9.,   9.,  19., 198.])],
#  array([0.43043056, 0.4873875 , 0.5443444 , 0.6013014 , 0.6582583 ,
#         0.71521527, 0.7721722 , 0.82912916, 0.8860861 , 0.94304305,
#         1.        ], dtype=float32),
#  <a list of 2 Lists of Patches objects>)
