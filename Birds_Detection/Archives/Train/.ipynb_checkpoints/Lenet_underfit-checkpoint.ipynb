# %%
import numpy as np # Pour la manipulation de tableaux
from keras.applications import  resnet50
from sklearn import metrics 
import os

import pandas as pd # Pour manipuler des DataFrames pandas

import matplotlib.pyplot as plt # Pour l'affichage d'images
from matplotlib import cm # Pour importer de nouvelles cartes de couleur
# %matplotlib inline

from keras.models import Sequential # Pour construire un réseau de neurones
from keras.layers import Dense, Conv2D # Pour instancier une couche dense
from keras.utils import np_utils

from keras.models import Sequential
from keras.layers import Dense, Activation,GlobalAveragePooling2D, MaxPooling2D
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.models import Model
import cv2
import keras
from numpy.random import seed
import tensorflow

from keras.preprocessing.image import ImageDataGenerator
import itertools # Pour créer des iterateurs

from sklearn import linear_model, preprocessing 



# %matplotlib inline
import numpy as np

import matplotlib.pyplot as plt
import time, cv2
import seaborn as sns

import pandas as pd
from sklearn.model_selection import train_test_split

from keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.models import Model, Sequential
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras import backend as K
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.applications.vgg16 import preprocess_input

# %%
#df=pd.read_csv("/home/marcpozzo/Desktop/c3po/Images_aquises/generateur.csv")
df=pd.read_csv("generateur.csv")
df.drop('labels',inplace=True,axis=1)
df.head()
# Out:
#        class                            img_paths
# 0     oiseau  Rec_images/DSCF0029_incertain_0.JPG
# 1      autre     Rec_images/DSCF0029_ground_1.JPG
# 2  corneille  Rec_images/DSCF0180_corneille_2.JPG
# 3  corneille  Rec_images/DSCF0180_corneille_3.JPG
# 4     pigeon     Rec_images/DSCF0258_pigeon_4.JPG

# %%
#df=df[(df["class"]=='corneille') | (df["class"]=='pigeon') | (df["class"]=='faisan')   ]
df["class"].unique()
for c in df:
    print(''+c+':',len(df[c].unique()))
df["class"].unique()
# Out:
# class: 12
# img_paths: 6220
# array(['oiseau', 'autre', 'corneille', 'pigeon', 'pie', 'chat', 'abeille',
#        'chevreuil', 'lapin', 'faisan', 'sanglier', 'cheval'], dtype=object)

# %%
All_Unique=df["class"].unique()
Utilisable=[]
for i in df["class"].unique():
    if df["class"][df["class"]==i].count()>100:
        Utilisable.append(i)
Utilisable
Non_Utilisable=set(All_Unique)-set(Utilisable)
Non_Utilisable
for i in Non_Utilisable:
    df=df[df["class"]!=i]
df=df[df["class"]!="oiseau"]  
df["class"].unique()
# Out:
# array(['autre', 'corneille', 'pigeon', 'chevreuil', 'lapin', 'faisan'],
#       dtype=object)

# %%
os.path.join("/home/marcpozzo/Desktop/c3po/Images_aquises/","Rec_images/DSCF0029_ground_1.JPG")
for i in range(len(df["class"])):
    df["img_paths"].iloc[i]=os.path.join("/home/marcpozzo/Desktop/c3po/Images_aquises/",df["img_paths"].iloc[i])
    
df.head()
# Out:
#        class                                          img_paths
# 1      autre  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 2  corneille  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 3  corneille  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 4     pigeon  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 5      autre  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...

# %%
#df=pd.read_csv("generateur_num.csv",index_col=0)
#(df["class"])=np_utils.to_categorical(df["class"])
df["class"] = df["class"].astype(str)
data_train=df.iloc[:1500]
data_test=df.iloc[1500:]
data_train,data_test=train_test_split(df,test_size=0.25,random_state=42)
data_train.shape
# Out:
# (4475, 2)

# %%
data_train,data_test= train_test_split(df,stratify=df["class"], test_size=0.5,random_state=42)
data_train
# Out:
#           class                                          img_paths
# 4159  corneille  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 5731     pigeon  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 5217     faisan  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 2492      autre  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 4482      autre  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# ...         ...                                                ...
# 5942      autre  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 1800      autre  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 972   corneille  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 4542      autre  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
# 491       autre  /home/marcpozzo/Desktop/c3po/Images_aquises/Re...
#
# [2983 rows x 2 columns]

# %%
print( len(train[train["class"]=="corneille"]) / (len(train  )) ,     len(test[test["class"]=="corneille"]) / (len(test  )       ) )
print( len(train[train["class"]=="pigeon"]) / (len(train  )) ,     len(test[test["class"]=="pigeon"]) / (len(test  )       ) )
print( len(train[train["class"]=="faisan"]) / (len(train  )) ,     len(test[test["class"]=="faisan"]) / (len(test  )       ) )
# Out:
# 0.17997066834276138 0.1800670016750419
# 0.138696836371255 0.1390284757118928
# 0.056149172428242196 0.05611390284757119

# %%
# Out:
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# (4475, 2)

# %%
# Out:
# 0.17997066834276138 0.1800670016750419
# 0.138696836371255 0.1390284757118928
# 0.056149172428242196 0.05611390284757119

# %%
epochs=200
batch_size = 400

train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        zoom_range = 1.1,
        horizontal_flip = False
        )

test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)




train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)


test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)



lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = 0.2)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 6,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation




history=lenet.fit_generator( train_generator,
                           steps_per_epoch=len(data_train)//batch_size,
                           epochs=epochs,
                           workers=-1,
                           validation_data=test_generator,
                           validation_steps=len(data_test)//batch_size)
                          


plt.figure(figsize=(16,12))
#plt.plot(history.history['val_accuracy']);
plt.plot(history.history['accuracy'],label="train");
#plt.labels("entrainement")
plt.plot(history.history['val_accuracy'],label="test");

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title("Accuracy en fonction du nombre d'epoch");
plt.legend();
# Out:
# Found 4773 validated image filenames belonging to 6 classes.
# Found 1194 validated image filenames belonging to 6 classes.
# Epoch 1/200
# 11/11 [==============================] - 4s 406ms/step - loss: 7.9621 - accuracy: 0.3780 - val_loss: 2.1220 - val_accuracy: 0.5725
# Epoch 2/200
# 11/11 [==============================] - 4s 389ms/step - loss: 1.6835 - accuracy: 0.5440 - val_loss: 1.3583 - val_accuracy: 0.6250
# Epoch 3/200
# 11/11 [==============================] - 4s 377ms/step - loss: 1.3526 - accuracy: 0.5941 - val_loss: 1.2398 - val_accuracy: 0.6269
# Epoch 4/200
# 11/11 [==============================] - 4s 381ms/step - loss: 1.2768 - accuracy: 0.6133 - val_loss: 1.0646 - val_accuracy: 0.6775
# Epoch 5/200
# 11/11 [==============================] - 4s 382ms/step - loss: 1.1977 - accuracy: 0.6353 - val_loss: 1.1319 - val_accuracy: 0.6550
# Epoch 6/200
# 11/11 [==============================] - 4s 359ms/step - loss: 1.1337 - accuracy: 0.6540 - val_loss: 1.0647 - val_accuracy: 0.6802
# Epoch 7/200
# 11/11 [==============================] - 4s 369ms/step - loss: 1.0873 - accuracy: 0.6693 - val_loss: 0.9672 - val_accuracy: 0.7000
# Epoch 8/200
# 11/11 [==============================] - 4s 368ms/step - loss: 1.0216 - accuracy: 0.6883 - val_loss: 0.9429 - val_accuracy: 0.7125
# Epoch 9/200
# 11/11 [==============================] - 4s 371ms/step - loss: 1.0195 - accuracy: 0.6981 - val_loss: 0.8893 - val_accuracy: 0.7259
# Epoch 10/200
# 11/11 [==============================] - 4s 368ms/step - loss: 1.0083 - accuracy: 0.6876 - val_loss: 0.8317 - val_accuracy: 0.7575
# Epoch 11/200
# 11/11 [==============================] - 4s 366ms/step - loss: 0.9427 - accuracy: 0.7075 - val_loss: 0.9080 - val_accuracy: 0.7275
# Epoch 12/200
# 11/11 [==============================] - 4s 363ms/step - loss: 0.9221 - accuracy: 0.7164 - val_loss: 0.7638 - val_accuracy: 0.7640
# Epoch 13/200
# 11/11 [==============================] - 4s 368ms/step - loss: 0.9101 - accuracy: 0.7270 - val_loss: 0.7749 - val_accuracy: 0.7550
# Epoch 14/200
# 11/11 [==============================] - 4s 369ms/step - loss: 0.8695 - accuracy: 0.7395 - val_loss: 0.7558 - val_accuracy: 0.7875
# Epoch 15/200
# 11/11 [==============================] - 4s 372ms/step - loss: 0.8588 - accuracy: 0.7366 - val_loss: 0.7822 - val_accuracy: 0.7614
# Epoch 16/200
# 11/11 [==============================] - 4s 366ms/step - loss: 0.8581 - accuracy: 0.7322 - val_loss: 0.7776 - val_accuracy: 0.7800
# Epoch 17/200
# 11/11 [==============================] - 4s 362ms/step - loss: 0
200
# 11/11 [==============================] - 4s 360ms/step - loss: 0.4127 - accuracy: 0.8701 - val_loss: 0.5145 - val_accuracy: 0.8950
# Epoch 150/200
# 11/11 [==============================] - 4s 359ms/step - loss: 0.4033 - accuracy: 0.8724 - val_loss: 0.3475 - val_accuracy: 0.9010
# Epoch 151/200
# 11/11 [==============================] - 4s 357ms/step - loss: 0.3951 - accuracy: 0.8767 - val_loss: 0.4148 - val_accuracy: 0.8900
# Epoch 152/200
# 11/11 [==============================] - 4s 358ms/step - loss: 0.4094 - accuracy: 0.8703 - val_loss: 0.4007 - val_accuracy: 0.9225
# Epoch 153/200
# 11/11 [==============================] - 4s 353ms/step - loss: 0.4277 - accuracy: 0.8619 - val_loss: 0.3278 - val_accuracy: 0.9061
# Epoch 154/200
# 11/11 [==============================] - 4s 368ms/step - loss: 0.3952 - accuracy: 0.8758 - val_loss: 0.5538 - val_accuracy: 0.9150
# Epoch 155/200
# 11/11 [==============================] - 4s 358ms/step - loss: 0.4083 - accuracy: 0.8697 - val_loss: 0.2918 - val_accuracy: 0.9100
# Epoch 156/200
# 11/11 [==============================] - 4s 355ms/step - loss: 0.3784 - accuracy: 0.8802 - val_loss: 0.2905 - val_accuracy: 0.9188
# Epoch 157/200
# 11/11 [==============================] - 4s 365ms/step - loss: 0.3869 - accuracy: 0.8709 - val_loss: 0.2762 - val_accuracy: 0.9075
# Epoch 158/200
# 11/11 [==============================] - 4s 366ms/step - loss: 0.3717 - accuracy: 0.8809 - val_loss: 0.4945 - val_accuracy: 0.9000
# Epoch 159/200
# 11/11 [==============================] - 4s 358ms/step - loss: 0.3958 - accuracy: 0.8740 - val_loss: 0.3988 - val_accuracy: 0.9061
# Epoch 160/200
# 11/11 [==============================] - 4s 364ms/step - loss: 0.3855 - accuracy: 0.8754 - val_loss: 0.3286 - val_accuracy: 0.9075
# Epoch 161/200
# 11/11 [==============================] - 4s 391ms/step - loss: 0.3939 - accuracy: 0.8717 - val_loss: 0.4579 - val_accuracy: 0.9225
# Epoch 162/200
# 11/11 [==============================] - 4s 371ms/step - loss: 0.4050 - accuracy: 0.8701 - val_loss: 0.3285 - val_accuracy: 0.9188
# Epoch 163/200
# 11/11 [==============================] - 4s 371ms/step - loss: 0.3722 - accuracy: 0.8815 - val_loss: 0.3307 - val_accuracy: 0.9300
# Epoch 164/200
# 11/11 [==============================] - 4s 371ms/step - loss: 0.3747 - accuracy: 0.8770 - val_loss: 0.5052 - val_accuracy: 0.8975
# Epoch 165/200
# 11/11 [==============================] - 4s 361ms/step - loss: 0.3662 - accuracy: 0.8847 - val_loss: 0.2689 - val_accuracy: 0.9188
# Epoch 166/200
# 11/11 [==============================] - 4s 372ms/step - loss: 0.3823 - accuracy: 0.8754 - val_loss: 0.3330 - val_accuracy: 0.9100
# Epoch 167/200
# 11/11 [==============================] - 4s 368ms/step - loss: 0.3999 - accuracy: 0.8692 - val_loss: 0.4148 - val_accuracy: 0.9075
# Epoch 168/200
# 11/11 [==============================] - 4s 360ms/step - loss: 0.3791 - accuracy: 0.8829 - val_loss: 0.3427 - val_accuracy: 0.9112
# Epoch 169/200
# 11/11 [==============================] - 4s 387ms/step - loss: 0.4039 - accuracy: 0.8720 - val_loss: 0.3985 - val_accuracy: 0.9225
# Epoch 170/200
# 11/11 [==============================] - 4s 363ms/step - loss: 0.3798 - accuracy: 0.8811 - val_loss: 0.4373 - val_accuracy: 0.9300
# Epoch 171/200
# 11/11 [==============================] - 4s 354ms/step - loss: 0.3741 - accuracy: 0.8777 - val_loss: 0.2489 - val_accuracy: 0.9239
# Epoch 172/200
# 11/11 [==============================] - 4s 361ms/step - loss: 0.3548 - accuracy: 0.8815 - val_loss: 0.4102 - val_accuracy: 0.9050
# Epoch 173/200
# 11/11 [==============================] - 4s 356ms/step - loss: 0.4058 - accuracy: 0.8710 - val_loss: 0.3794 - val_accuracy: 0.8900
# Epoch 174/200
# 11/11 [==============================] - 4s 358ms/step - loss: 0.3832 - accuracy: 0.8799 - val_loss: 0.3172 - val_accuracy: 0.9188
# Epoch 175/200
# 11/11 [==============================] - 4s 364ms/step - loss: 0.4032 - accuracy: 0.8774 - val_loss: 0.4048 - val_accuracy: 0.9175
# Epoch 176/200
# 11/11 [==============================] - 4s 355ms/step - loss: 0.
# Epoch 199/200
# 11/11 [==============================] - 4s 380ms/step - loss: 0.3403 - accuracy: 0.8937 - val_loss: 0.2590 - val_accuracy: 0.9225
# Epoch 200/200
# 11/11 [==============================] - 4s 365ms/step - loss: 0.3550 - accuracy: 0.8870 - val_loss: 0.4615 - val_accuracy: 0.9300

# %%
from keras import optimizers
from tensorflow.keras.optimizers import SGD

# %%
from numpy.random import seed
seed(1)
tensorflow.random.set_seed(2)

epochs=10
batch_size = 400

data_train,data_test= train_test_split(df,stratify=df["class"], test_size=0.2,random_state=42)


train_data_generator = ImageDataGenerator(
        preprocessing_function = preprocess_input,
        # data augmentation
        #rotation_range = 10,
        #zoom_range = 1.1,
        horizontal_flip = False
        )

test_data_generator = ImageDataGenerator(
    preprocessing_function = preprocess_input)




train_generator = train_data_generator.flow_from_dataframe(dataframe=data_train,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)


test_generator = test_data_generator.flow_from_dataframe(dataframe=data_test,
                                                          directory="",
                                                           x_col = "img_paths",
                                                           class_mode ="sparse",
                                                          target_size = (28 , 28), 
                                                          batch_size = batch_size)



lenet = Sequential()

conv_1 = Conv2D(filters = 30,                     # Nombre de filtres
                kernel_size = (5, 5),            # Dimensions du noyau
                padding = 'valid',               # Mode de Dépassement
                input_shape = (28, 28, 3),       # Dimensions de l'image en entrée
                activation = 'relu')             # Fonction d'activation

max_pool_1 = MaxPooling2D(pool_size = (2, 2))

conv_2 = Conv2D(filters = 16,                    
                kernel_size = (3, 3),          
                padding = 'valid',             
                activation = 'relu')

max_pool_2 = MaxPooling2D(pool_size = (2, 2))

flatten = Flatten()

dropout = Dropout(rate = 0.2)

dense_1 = Dense(units = 128,
                activation = 'relu')

dense_2 = Dense(units = 6,
                activation = 'softmax')

lenet.add(conv_1)
lenet.add(max_pool_1)
lenet.add(conv_2)
lenet.add(max_pool_2)
#lenet.add(dropout)
lenet.add(flatten)
lenet.add(dense_1)
lenet.add(dense_2)

# Compilation
lenet.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation




history=lenet.fit_generator( train_generator,
                           steps_per_epoch=len(data_train)//batch_size,
                           epochs=epochs,
                           workers=-1,
                           validation_data=test_generator,
                           validation_steps=len(data_test)//batch_size)
                          


"""plt.figure(figsize=(16,12))
#plt.plot(history.history['val_accuracy']);
plt.plot(history.history['train_acc'],label="train");
#plt.labels("entrainement")
plt.plot(history.history['val_accuracy'],label="test");

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title("Accuracy en fonction du nombre d'epoch");
plt.legend();"""

train_acc=[]
test_acc=[]
train_acc=history.history['accuracy']
test_acc=(history.history['val_accuracy'])
test_acc.insert(0,0)
print( len(test_acc),len(train_acc) )

plt.figure(figsize=(16,12))
plt.plot(train_acc,label="train");
#plt.plot(train_acc,label="train");
#plt.labels("entrainement")
plt.plot(test_acc,label="test");
plt.legend()
print(len(test_acc),len(train_acc))
# Out:
# Found 4773 validated image filenames belonging to 6 classes.
# Found 1194 validated image filenames belonging to 6 classes.
# Epoch 1/10
# 11/11 [==============================] - 3s 263ms/step - loss: 6.0556 - accuracy: 0.4127 - val_loss: 2.2413 - val_accuracy: 0.5188
# Epoch 2/10
# 11/11 [==============================] - 3s 254ms/step - loss: 1.5984 - accuracy: 0.5827 - val_loss: 1.2372 - val_accuracy: 0.6499
# Epoch 3/10
# 11/11 [==============================] - 3s 263ms/step - loss: 1.0792 - accuracy: 0.6760 - val_loss: 1.0281 - val_accuracy: 0.6927
# Epoch 4/10
# 11/11 [==============================] - 3s 258ms/step - loss: 0.8939 - accuracy: 0.7233 - val_loss: 0.8471 - val_accuracy: 0.7113
# Epoch 5/10
# 11/11 [==============================] - 3s 257ms/step - loss: 0.7925 - accuracy: 0.7656 - val_loss: 0.9615 - val_accuracy: 0.7380
# Epoch 6/10
# 11/11 [==============================] - 3s 254ms/step - loss: 0.7284 - accuracy: 0.7679 - val_loss: 0.8298 - val_accuracy: 0.7607
# Epoch 7/10
# 11/11 [==============================] - 3s 265ms/step - loss: 0.6604 - accuracy: 0.7976 - val_loss: 0.8260 - val_accuracy: 0.7663
# Epoch 8/10
# 11/11 [==============================] - 3s 262ms/step - loss: 0.5786 - accuracy: 0.8219 - val_loss: 0.9062 - val_accuracy: 0.7670
# Epoch 9/10
# 11/11 [==============================] - 3s 284ms/step - loss: 0.5280 - accuracy: 0.8365 - val_loss: 0.6964 - val_accuracy: 0.7985
# Epoch 10/10
# 11/11 [==============================] - 3s 282ms/step - loss: 0.5041 - accuracy: 0.8463 - val_loss: 0.7806 - val_accuracy: 0.7987
# 11 10
# 11 10

# %%
0.4714
train_acc=[]
test_acc=[]
train_acc=history.history['accuracy']
test_acc=(history.history['val_accuracy'])
test_acc.insert(0,0)
print( len(test_acc),len(train_acc) )

plt.figure(figsize=(16,12))
plt.plot(train_acc,label="train");
#plt.plot(train_acc,label="train");
#plt.labels("entrainement")
plt.plot(test_acc,label="test");
plt.legend()
print(len(test_acc),len(train_acc))
# Out:
# 11 10
# 11 10

# %%
len(history.history['accuracy'])
# Out:
# 10

# %%
test_acc = []

test_acc=(history.history['val_accuracy'])

test_acc .insert(0, 0)
test_acc 

plt.plot(train_acc);
#plt.plot(train_acc,label="train");
#plt.labels("entrainement")
plt.plot(test_acc,label="test");

# %%
def convert_image(X):
    X_img=[]
    for image in X:
        # Load image
        img=cv2.imread(image)
        # Resize image
        img=cv2.resize(img,(28,28))
        # for the black and white image
        if img.shape==(28, 28):
            img=img.reshape([28,28,1])
            img=np.concatenate([img,img,img],axis=2)
        # cv2 load the image BGR sequence color (not RGB)
        X_img.append(img[...,::-1])
    return np.array(X_img)

# Load the images train
X_train_img = convert_image(data_train.img_paths)
Y_train = data_train['class']

# Load the images test
X_test_img = convert_image(data_test.img_paths)
Y_test = data_test['class']

# %%
intermediate_layer_model = Model(input=lenet.input, output=lenet.layers[-2].output)

X_train_features = intermediate_layer_model.predict(preprocess_input(X_train_img))

X_test_features = intermediate_layer_model.predict(preprocess_input(X_test_img))


y_train=data_train["class"]
y_test=data_test["class"]

lg = linear_model.LogisticRegression(C = 1.0)
lg.fit(X_train_features, y_train);
y_predict=lg.predict(X_test_features)
print(lg.score(X_test_features, y_test))
print(metrics.classification_report(y_test, y_predict))
# Out:
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("co..., outputs=Tensor("de...)`
#   """Entry point for launching an IPython kernel.
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 0.8123953098827471
#               precision    recall  f1-score   support
#
#        autre       0.82      0.95      0.88       684
#    chevreuil       0.62      0.48      0.54        27
#    corneille       0.87      0.87      0.87       215
#       faisan       0.66      0.55      0.60        67
#        lapin       0.40      0.17      0.24        35
#       pigeon       0.82      0.46      0.59       166
#
#     accuracy                           0.81      1194
#    macro avg       0.70      0.58      0.62      1194
# weighted avg       0.80      0.81      0.80      1194

# %%
intermediate_layer_model = Model(input=lenet.input, output=lenet.layers[-2].output)

X_train_features = intermediate_layer_model.predict(preprocess_input(X_train_img))

X_test_features = intermediate_layer_model.predict(preprocess_input(X_test_img))


y_train=data_train["class"]
y_test=data_test["class"]

lg = linear_model.LogisticRegression(C = 1.0)
lg.fit(X_train_features, y_train);
y_predict=lg.predict(X_test_features)
print(lg.score(X_test_features, y_test))
print(metrics.classification_report(y_test, y_predict))
# Out:
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("co..., outputs=Tensor("de...)`
#   """Entry point for launching an IPython kernel.
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 0.9212730318257957
#               precision    recall  f1-score   support
#
#        autre       0.94      0.97      0.96       684
#    chevreuil       0.96      0.85      0.90        27
#    corneille       0.88      0.93      0.90       215
#       faisan       0.87      0.81      0.84        67
#        lapin       0.75      0.60      0.67        35
#       pigeon       0.92      0.83      0.87       166
#
#     accuracy                           0.92      1194
#    macro avg       0.89      0.83      0.86      1194
# weighted avg       0.92      0.92      0.92      1194

# %%
from keras.models import load_model
lenet.save("model.h8")
model = load_model('model.h8')
intermediate_layer_model = Model(input=model.input, output=model.layers[-2].output)
X_test_features = intermediate_layer_model.predict(preprocess_input(X_test_img))
y_predict=lg.predict(X_test_features)
print(lg.score(X_test_features, y_test))
print(metrics.classification_report(y_test, y_predict))
# Out:
# 0.9212730318257957
#               precision    recall  f1-score   support
#
#        autre       0.94      0.97      0.96       684
#    chevreuil       0.96      0.85      0.90        27
#    corneille       0.88      0.93      0.90       215
#       faisan       0.87      0.81      0.84        67
#        lapin       0.75      0.60      0.67        35
#       pigeon       0.92      0.83      0.87       166
#
#     accuracy                           0.92      1194
#    macro avg       0.89      0.83      0.86      1194
# weighted avg       0.92      0.92      0.92      1194
# /home/marcpozzo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("co..., outputs=Tensor("de...)`
#   after removing the cwd from sys.path.
