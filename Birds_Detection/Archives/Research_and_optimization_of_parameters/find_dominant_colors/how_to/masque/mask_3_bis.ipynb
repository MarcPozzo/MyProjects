# %%
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import numpy as np
import numpy
from PIL import Image, ImageDraw
from numpy import savetxt
from numpy import load
from numpy import save
import os
from os import chdir

# %%
chdir("/Users/marcpozzo/Documents/Projet_Git/DonneesPI/timeLapsePhotos_Pi1_3")

# %%
data_path="../../../../../../"
random_image_path=data_path+"DonneesPI/timeLapsePhotos_Pi1_3/image_2019-05-24_15-47-46.jpg"
random_image_path="image_2019-05-24_17-02-57.jpg"
#random_image_path="/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_3/image_2019-05-24_15-47-46.jpg"
random_image=cv2.imread(random_image_path)
random_image.shape
# Out:
# (720, 1280, 3)

# %%
random_image_path
# Out:
# '../../../../../DonneesPI/timeLapsePhotos_Pi1_3/image_2019-05-24_15-47-46.jpg'

# %%
os.getcwd()
# Out:
# '/Users/marcpozzo/Documents/Projet_Git/DonneesPI/timeLapsePhotos_Pi1_3'

# %%
## coordonnee reajustées

# %%
def op_x(coord):
    x=coord[0]

    y=720-coord[1]

    n_coord=(x,y)
    
    return n_coord

#random_image_path=data_path+"DonneesPI/timeLapsePhotos_Pi1_3/image_2019-05-24_15-47-46.jpg"

#random_image_path="/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_3/image_2019-05-24_15-47-46.jpg"
random_image=cv2.imread(random_image_path)

print(random_image.shape)


liste_coord=[[1238.971365,439],[1251.93352,520],[242.064321,379],[5.044752,337],[2.000719,41],[2.999281,284],[3.999429,226],[-0.00049,1],[1277.998849,4],[1279.000326,202],[1270.001871,321],[1238.971365,439]]





coord_1=[liste_coord[0][0],liste_coord[0][1]]
coord_2=[liste_coord[1][0],liste_coord[1][1]]
coord_3=[liste_coord[2][0],liste_coord[2][1]]
coord_4=[liste_coord[3][0],liste_coord[3][1]]
coord_5=[liste_coord[4][0],liste_coord[4][1]]
coord_6=[liste_coord[5][0],liste_coord[5][1]]
coord_7=[liste_coord[6][0],liste_coord[6][1]]
#coord_8=[liste_coord[7][0],liste_coord[7][1]]
coord_8=[liste_coord[7][0],liste_coord[7][1]]
coord_9=[liste_coord[8][0],liste_coord[8][1]]
coord_10=[liste_coord[9][0],liste_coord[9][1]]
coord_11=[liste_coord[10][0],liste_coord[10][1]]



x1= op_x(coord_1)
x2=op_x(coord_2)
x3=op_x(coord_3)
x4=op_x(coord_4)
x5=op_x(coord_5)
x6=op_x(coord_6)
x7=op_x(coord_7)
x8=op_x(coord_8)
x9=op_x(coord_9)
x10=op_x(coord_10)
x11=op_x(coord_11)
#x8=op_x(coord_8)


polygon=[x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11]

random_image=cv2.imread(random_image_path)
n_random_image=cv2.imread(random_image_path)
height = 720
width = 1280
img_1 = Image.new('L', (width, height), 0)
ImageDraw.Draw(img_1).polygon(polygon, outline=1, fill=1)
mask1D = numpy.array(img_1)




mask3D = np.zeros((720,1280,3))
mask3D[:,:,0]=mask1D
mask3D[:,:,1]=mask1D
mask3D[:,:,2]=mask1D

out_arr_1 = np.multiply(mask3D, random_image) 

#Image initiale
plt.figure(figsize=(25,25))
plt.subplot(1,4,1)
plt.imshow(random_image)

#Masque seul
#plt.subplot(1,4,2)
#plt.imshow(mask3D)

#Image masquée
plt.subplot(1,4,3)
out_arr= np.multiply(mask3D, random_image) 
out_arr=out_arr.astype(int)
n_random_image=n_random_image.astype(int)
plt.imshow(out_arr )
# Out:
# (720, 1280, 3)

# %%
#save('mask_3.npy', mask3D)

# %%
cv2.imwrite("pic3_mask.jpg",random_image)
cv2.imwrite("pic3_wout_mask.jpg",out_arr)
# Out:
# True

# %%
os.getcwd()
# Out:
# '/Users/marcpozzo/Documents/Projet_Git/DonneesPI/timeLapsePhotos_Pi1_3'

# %%
cd ..
# Out:
# /Users/marcpozzo/Documents/Projet_Git/DonneesPI

# %%
mask_download=load('mask_2.npy')
out_arr_1 = np.multiply(mask_download, random_image) 

#Image initiale
plt.figure(figsize=(25,25))
plt.subplot(1,4,1)
plt.imshow(random_image)

#Masque seul
plt.subplot(1,4,2)
plt.imshow(mask3D)

#Image masquée
plt.subplot(1,4,3)
out_arr= np.multiply(mask3D, random_image) 
out_arr=out_arr.astype(int)
n_random_image=n_random_image.astype(int)
plt.imshow(out_arr )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-8fe374c7b961> in <module>
#       1 mask_download=load('mask_2.npy')
# ----> 2 out_arr_1 = np.multiply(mask_download, random_image)
#       3
#       4 #Image initiale
#       5 plt.figure(figsize=(25,25))
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'

# %%
import os
os.getcwd()
# Out:
# '/mnt/VegaSlowDataDisk/c3po_interface_mark/find_dominant_colors/how_to/masque'
