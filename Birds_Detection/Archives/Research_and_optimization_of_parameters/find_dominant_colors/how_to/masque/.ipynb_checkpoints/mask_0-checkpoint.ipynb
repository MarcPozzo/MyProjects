# %%
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import numpy as np
import numpy
from PIL import Image, ImageDraw

random_image_path="/home/marcpozzo/Desktop/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_0/image_2019-04-30_17-41-18.jpg"
imgPath="/home/marcpozzo/Desktop/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_0/image_2019-04-30_17-41-18.jpg"

# %%
#[[[8.081365,220],[519.151955,319],[1266.255146,411],[1277.087857,0],[15.99779,20],[8.081365,220]]]


#En haut à gauche
x1= (8,1280-220)
x2=(519,1280-319)
x3=(1266,1280-411)
x4=(1277,1280)
x5=(16,1280-20)
x6=(8,1280-220)
polygon=[x1,x2,x3,x4,x5]

random_image=cv2.imread(random_image_path)
n_random_image=cv2.imread(random_image_path)

# polygon = [(x1,y1),(x2,y2),...] or [x1,y1,x2,y2,...]
width = 1280
height = 1024

img_1 = Image.new('L', (width, height), 0)
ImageDraw.Draw(img_1).polygon(polygon, outline=1, fill=1)
mask1D = numpy.array(img_1)




mask3D = np.zeros((1024,1280,3))
mask3D[:,:,0]=mask1D
mask3D[:,:,1]=mask1D
mask3D[:,:,2]=mask1D

out_arr_1 = np.multiply(mask3D, random_image) 


plt.figure(figsize=(25,25))
plt.subplot(1,4,1)
plt.imshow(random_image)

plt.subplot(1,4,2)
plt.imshow(mask3D)

plt.subplot(1,4,3)
out_arr= np.multiply(mask3D, random_image) 
out_arr=out_arr.astype(int)
n_random_image=n_random_image.astype(int)
plt.imshow(out_arr )

# %%
def op_x(coord):
    x=coord[0]

    y=1024-coord[1]

    n_coord=(x,y)
    
    return n_coord



#[[[8.081365,220],[519.151955,319],[1266.255146,411],[1277.087857,0],[15.99779,20],[8.081365,220]]]

coord_1=[8.081365,220]
coord_1=[1000.081365,22]
coord_2=[519.151955,319]
coord_3=[1266.255146,411]
coord_3=[3000,41]
coord_4=[1277.087857,0]
coord_5=[15.99779,20]
coord_6=[8.081365,220]



#En haut à gauche
x1= op_x(coord_1)
x2=op_x(coord_2)
x3=op_x(coord_3)
x4=op_x(coord_4)
x5=op_x(coord_5)
x6=op_x(coord_6)


#[[[8.081365,220],[519.151955,319],[1266.255146,411],[1277.087857,0],[15.99779,20],[8.081365,220]]]


#En haut à gauche
x1= (0,220)
x2=(519,319)
x3=(1266,411)
x4=(1277,0)
x5=(16,20)
x6=(0,220)


x1= op_x(x1)
x2=op_x(x2)
x3=op_x(x3)
x4=op_x(x4)
x5=op_x(x5)
x6=op_x(x6)

polygon=[x1,x2,x3,x4,x5,x6]




random_image=cv2.imread(random_image_path)
n_random_image=cv2.imread(random_image_path)

# polygon = [(x1,y1),(x2,y2),...] or [x1,y1,x2,y2,...]
width = 1280
height = 1024

img_1 = Image.new('L', (width, height), 0)
ImageDraw.Draw(img_1).polygon(polygon, outline=1, fill=1)
mask1D = numpy.array(img_1)




mask3D = np.zeros((1024,1280,3))
mask3D[:,:,0]=mask1D
mask3D[:,:,1]=mask1D
mask3D[:,:,2]=mask1D

out_arr_1 = np.multiply(mask3D, random_image) 


plt.figure(figsize=(25,25))
plt.subplot(1,4,1)
plt.imshow(random_image)

plt.subplot(1,4,2)
plt.imshow(mask3D)

plt.subplot(1,4,3)
out_arr= np.multiply(mask3D, random_image) 
out_arr=out_arr.astype(int)
n_random_image=n_random_image.astype(int)
plt.imshow(out_arr )

# %%
             
             
             

def op_x(coord):
    x=coord[0]

    y=coord[1]

    n_coord=(x,y)
    
    return n_coord

# %%
liste_coord=[[253.999238,331],[179.999965,369],[302.021267,545],[371.002286,513],[253.999238,331]]

# %%
#[[[8.081365,220],[519.151955,319],[1266.255146,411],[1277.087857,0],[15.99779,20],[8.081365,220]]]


coord_1=[liste_coord[0][0],liste_coord[0][1]]
print(coord_1)
coord_2=[liste_coord[1][0],liste_coord[1][1]]
print(coord_2)
coord_3=[liste_coord[2][0],liste_coord[2][1]]
print(coord_3)
coord_4=[liste_coord[3][0],liste_coord[3][1]]
coord_5=[liste_coord[4][0],liste_coord[4][1]]
#coord_6=[liste_coord[5][0],liste_coord[5][1]]




#En haut à gauche
x1= op_x(coord_1)
x2=op_x(coord_2)
x3=op_x(coord_3)
x4=op_x(coord_4)
x5=op_x(coord_5)
x6=op_x(coord_6)


#[[[8.081365,220],[519.151955,319],[1266.255146,411],[1277.087857,0],[15.99779,20],[8.081365,220]]]





x1= op_x(x1)
x2=op_x(x2)
x3=op_x(x3)
x4=op_x(x4)
x5=op_x(x5)
#x6=op_x(x6)

polygon=[x1,x2,x3,x4,x5]




random_image=cv2.imread(random_image_path)
n_random_image=cv2.imread(random_image_path)

# polygon = [(x1,y1),(x2,y2),...] or [x1,y1,x2,y2,...]
width = 1280
height = 1024

img_1 = Image.new('L', (width, height), 0)
ImageDraw.Draw(img_1).polygon(polygon, outline=1, fill=1)
mask1D = numpy.array(img_1)




mask3D = np.zeros((1024,1280,3))
mask3D[:,:,0]=mask1D
mask3D[:,:,1]=mask1D
mask3D[:,:,2]=mask1D

out_arr_1 = np.multiply(mask3D, random_image) 


plt.figure(figsize=(25,25))
plt.subplot(1,4,1)
plt.imshow(random_image)

plt.subplot(1,4,2)
plt.imshow(mask3D)

plt.subplot(1,4,3)
out_arr= np.multiply(mask3D, random_image) 
out_arr=out_arr.astype(int)
n_random_image=n_random_image.astype(int)
plt.imshow(out_arr )
# Out:
# [253.999238, 331]
# [179.999965, 369]
# [302.021267, 545]

# %%
#[[[8.081365,220],[519.151955,319],[1266.255146,411],[1277.087857,0],[15.99779,20],[8.081365,220]]]


coord_1=[0,1024]
coord_2=[0,650]
coord_3=[500,550]
coord_4=[1280,450]
coord_5=[1280,1024]
#coord_6=[liste_coord[5][0],liste_coord[5][1]]




#En haut à gauche
x1= op_x(coord_1)
x2=op_x(coord_2)
x3=op_x(coord_3)
x4=op_x(coord_4)
x5=op_x(coord_5)
x6=op_x(coord_6)


#[[[8.081365,220],[519.151955,319],[1266.255146,411],[1277.087857,0],[15.99779,20],[8.081365,220]]]





x1= op_x(x1)
x2=op_x(x2)
x3=op_x(x3)
x4=op_x(x4)
x5=op_x(x5)
#x6=op_x(x6)

polygon=[x1,x2,x3,x4,x5]




random_image=cv2.imread(random_image_path)
n_random_image=cv2.imread(random_image_path)

# polygon = [(x1,y1),(x2,y2),...] or [x1,y1,x2,y2,...]
width = 1280
height = 1024

img_1 = Image.new('L', (width, height), 0)
ImageDraw.Draw(img_1).polygon(polygon, outline=1, fill=1)
mask1D = numpy.array(img_1)




mask3D = np.zeros((1024,1280,3))
mask3D[:,:,0]=mask1D
mask3D[:,:,1]=mask1D
mask3D[:,:,2]=mask1D

out_arr_1 = np.multiply(mask3D, random_image) 


plt.figure(figsize=(25,25))
plt.subplot(1,4,1)
plt.imshow(random_image)

plt.subplot(1,4,2)
plt.imshow(mask3D)

plt.subplot(1,4,3)
out_arr= np.multiply(mask3D, random_image) 
out_arr=out_arr.astype(int)
n_random_image=n_random_image.astype(int)
plt.imshow(out_arr )

# %%
random_image_path="/home/marcpozzo/Desktop/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_0/image_2019-05-07_18-18-32.jpg"
#/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_0/

#[[[8.081365,220],[519.151955,319],[1266.255146,411],[1277.087857,0],[15.99779,20],[8.081365,220]]]


coord_1=[0,1024]
coord_2=[0,650]
coord_3=[500,550]
coord_4=[1280,450]
coord_5=[1280,1024]
#coord_6=[liste_coord[5][0],liste_coord[5][1]]




#En haut à gauche
x1= op_x(coord_1)
x2=op_x(coord_2)
x3=op_x(coord_3)
x4=op_x(coord_4)
x5=op_x(coord_5)
x6=op_x(coord_6)


#[[[8.081365,220],[519.151955,319],[1266.255146,411],[1277.087857,0],[15.99779,20],[8.081365,220]]]





x1= op_x(x1)
x2=op_x(x2)
x3=op_x(x3)
x4=op_x(x4)
x5=op_x(x5)
#x6=op_x(x6)

polygon=[x1,x2,x3,x4,x5]




random_image=cv2.imread(random_image_path)
n_random_image=cv2.imread(random_image_path)

# polygon = [(x1,y1),(x2,y2),...] or [x1,y1,x2,y2,...]
width = 1280
height = 1024

img_1 = Image.new('L', (width, height), 0)
ImageDraw.Draw(img_1).polygon(polygon, outline=1, fill=1)
mask1D = numpy.array(img_1)




mask3D = np.zeros((1024,1280,3))
mask3D[:,:,0]=mask1D
mask3D[:,:,1]=mask1D
mask3D[:,:,2]=mask1D

out_arr_1 = np.multiply(mask3D, random_image) 


plt.figure(figsize=(25,25))
plt.subplot(1,4,1)
plt.imshow(random_image)

plt.subplot(1,4,2)
plt.imshow(mask3D)

plt.subplot(1,4,3)
out_arr= np.multiply(mask3D, random_image) 
out_arr=out_arr.astype(int)
n_random_image=n_random_image.astype(int)
plt.imshow(out_arr )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-a253dc93eb57> in <module>
#      61 mask3D[:,:,2]=mask1D
#      62
# ---> 63 out_arr_1 = np.multiply(mask3D, random_image)
#      64
#      65
#
# ValueError: operands could not be broadcast together with shapes (1024,1280,3) (720,1280,3)

# %%
random_image_path=="/home/marcpozzo/Desktop/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_0/image_2019-04-30_17-41-18.jpg"
#random_image_path="/mnt/VegaSlowDataDisk/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_0/image_2019-05-17_20-25-33.jpg"
cv2.imread(random_image_path).shape
# Out:
# (1024, 1280, 3)

# %%
polygon
# Out:
# [(8, 1060), (519, 961), (1266, 869), (1277, 1280), (16, 1260)]

# %%
x1
# Out:
# (8, 1060)

# %%
random_image_path="/home/marcpozzo/Desktop/c3po/Images_aquises/DonneesPI/timeLapsePhotos_Pi1_0/image_2019-05-07_18-18-32.jpg"
image=cv2.imread(random_image_path)
plt.imshow(image)
